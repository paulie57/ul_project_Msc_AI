# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# For inline plots in Jupyter
# %matplotlib inline
import pandas as pd
import matplotlib as plt
import glob
import os
import xml.etree.ElementTree as ET
from datetime import datetime, timezone
from tqdm import tqdm
import codecs
import csv
import openpyxl

# %%
data_directory_weather = "/home/paulharford/college/project/project_data/processed/WEATHERED_warnings_2014-2023_cleaned.csv"
data_directory_ihfd = "/home/paulharford/college/project/project_data/processed/ihfd_clean.csv"
data_directory_census = "/home/paulharford/college/project/project_data/processed/census_estimated_per_region_2014_2023.csv"
full_path_ihfd = os.path.abspath(data_directory_ihfd)
full_path_weather = os.path.abspath(data_directory_weather)
full_path_census = os.path.abspath(data_directory_census)

# %%
df_ihfd = pd.read_csv(full_path_ihfd)
df_weather = pd.read_csv(full_path_weather)
df_census = pd.read_csv(full_path_census)

# %%
df_weather["Valid From"] = pd.to_datetime(df_weather["Valid From"])
df_weather["date"] = df_weather["Valid From"].dt.date
df_weather["date"] = pd.to_datetime(df_weather["date"])
df_weather["Valid To"] = pd.to_datetime(df_weather["Valid To"])

# %%
#add column for lag
df_weather['lag_valid_to'] = df_weather['Valid To'] + pd.Timedelta(hours=12)

# %%
weather_region_cols = [
    "HSE Dublin and North East",
    "HSE Dublin and Midlands",
    "HSE Dublin and South East",
    "HSE Mid West",
    "HSE South West",
    "HSE West and North West",
    # any others you have
]

df_weather_full = df_weather.melt(
    id_vars=["date", "Issue Time", "Valid From", "Valid To", "lag_valid_to", "Warning Colour", 
             "Warning Element", "Warning Text", "Duration_hours"],
    value_vars=weather_region_cols,
    var_name="region",
    value_name="weather_flag"
)

# %%
df_weather_full.head(10)
# Out:
#         date                 Issue Time                Valid From  \
# 0 2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 1 2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 2 2014-01-03  2014-01-02 09:00:00+00:00 2014-01-03 14:00:00+00:00
# 3 2014-01-04  2014-01-04 03:00:00+00:00 2014-01-04 03:00:00+00:00
# 4 2014-01-05  2014-01-04 10:00:00+00:00 2014-01-05 08:00:00+00:00
# 5 2014-01-05  2014-01-04 16:00:00+00:00 2014-01-05 08:00:00+00:00
# 6 2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 7 2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 8 2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 9 2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 12:00:00+00:00
#
#                    Valid To              lag_valid_to Warning Colour  \
# 0 2014-01-03 14:00:00+00:00 2014-01-04 02:00:00+00:00         Orange
# 1 2014-01-03 14:00:00+00:00 2014-01-04 02:00:00+00:00         Yellow
# 2 2014-01-03 19:00:00+00:00 2014-01-04 07:00:00+00:00         Yellow
# 3 2014-01-04 14:00:00+00:00 2014-01-05 02:00:00+00:00         Yellow
# 4 2014-01-05 20:00:00+00:00 2014-01-06 08:00:00+00:00         Yellow
# 5 2014-01-05 18:00:00+00:00 2014-01-06 06:00:00+00:00         Yellow
# 6 2014-01-06 12:00:00+00:00 2014-01-07 00:00:00+00:00         Yellow
# 7 2014-01-06 12:00:00+00:00 2014-01-07 00:00:00+00:00         Yellow
# 8 2014-01-06 12:00:00+00:00 2014-01-07 00:00:00+00:00         Orange
# 9 2014-01-06 12:00:00+00:00 2014-01-07 00:00:00+00:00         Orange
#
#   Warning Element                                       Warning Text  \
# 0            Wind  Becoming stormy this evening and tonight and c...
# 1            Wind  Becoming extremely windy or stormy this evenin...
# 2            Wind  Blustery for the rest of the afternoon with so...
# 3        Snow/Ice  Scattered outbreaks of rain and sleet spreadin...
# 4            Wind  Southeast winds mean speeds of 50 to 65 km/h w...
# 5            Wind  Becoming windy again on Sunday morning with st...
# 6            Wind  UpdateStrong south to southeast winds, with gu...
# 7            Wind  UndateStrong south to southeast winds, with gu...
# 8            Wind  Update Strong south to southeast winds, with g...
# 9            Wind  Update Strong south to southeast winds, with g...
#
#    Duration_hours                     region  weather_flag
# 0            21.0  HSE Dublin and North East             0
# 1            21.0  HSE Dublin and North East             1
# 2             5.0  HSE Dublin and North East             1
# 3            11.0  HSE Dublin and North East             1
# 4            12.0  HSE Dublin and North East             1
# 5            10.0  HSE Dublin and North East             1
# 6            25.0  HSE Dublin and North East             1
# 7            25.0  HSE Dublin and North East             1
# 8            25.0  HSE Dublin and North East             0
# 9            24.0  HSE Dublin and North East             0

# %%
fill_values = {
    'Issue Time': 0,
    'Valid From': 0,
    'Valid To': 0,
    'lag_valid_to': 0,
    'Warning Colour': 0,
    'Warning Element': 0,
    # For text fields you want a specific string, e.g. 'noevent':
    'Warning Text': 'noevent',
    'Duration_hours': 0,
    'region': 'noevent',
    'weather_flag': 2.0
}

# Fill NaN values for these columns using fillna().
df_weather_full.fillna(value=fill_values, inplace=True)

# %%
df_weather_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16398 entries, 0 to 16397
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             16398 non-null  datetime64[ns]
#  1   Issue Time       16398 non-null  object
#  2   Valid From       16398 non-null  datetime64[ns, UTC]
#  3   Valid To         16398 non-null  object
#  4   lag_valid_to     16398 non-null  object
#  5   Warning Colour   16398 non-null  object
#  6   Warning Element  16398 non-null  object
#  7   Warning Text     16398 non-null  object
#  8   Duration_hours   16398 non-null  float64
#  9   region           16398 non-null  object
#  10  weather_flag     16398 non-null  int64
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 1.4+ MB

# %%
df_weather_full.head(15)
# Out:
#          date                 Issue Time                Valid From  \
# 0  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 1  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 2  2014-01-03  2014-01-02 09:00:00+00:00 2014-01-03 14:00:00+00:00
# 3  2014-01-04  2014-01-04 03:00:00+00:00 2014-01-04 03:00:00+00:00
# 4  2014-01-05  2014-01-04 10:00:00+00:00 2014-01-05 08:00:00+00:00
# 5  2014-01-05  2014-01-04 16:00:00+00:00 2014-01-05 08:00:00+00:00
# 6  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 7  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 8  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 9  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 12:00:00+00:00
# 10 2014-01-05  2014-01-05 12:00:00+00:00 2014-01-05 12:00:00+00:00
# 11 2014-01-05  2014-01-05 12:00:00+00:00 2014-01-05 12:00:00+00:00
# 12 2014-01-06  2014-01-06 09:00:00+00:00 2014-01-06 09:00:00+00:00
# 13 2014-01-06  2014-01-06 19:00:00+00:00 2014-01-06 19:00:00+00:00
# 14 2014-01-06  2014-01-06 21:00:00+00:00 2014-01-06 21:00:00+00:00
#
#                      Valid To               lag_valid_to Warning Colour  \
# 0   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 1   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
# 2   2014-01-03 19:00:00+00:00  2014-01-04 07:00:00+00:00         Yellow
# 3   2014-01-04 14:00:00+00:00  2014-01-05 02:00:00+00:00         Yellow
# 4   2014-01-05 20:00:00+00:00  2014-01-06 08:00:00+00:00         Yellow
# 5   2014-01-05 18:00:00+00:00  2014-01-06 06:00:00+00:00         Yellow
# 6   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 7   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 8   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Orange
# 9   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Orange
# 10  2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 11  2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 12  2014-01-06 19:00:00+00:00  2014-01-07 07:00:00+00:00         Orange
# 13  2014-01-06 23:59:00+00:00  2014-01-07 11:59:00+00:00         Yellow
# 14  2014-01-07 05:00:00+00:00  2014-01-07 17:00:00+00:00         Yellow
#
#    Warning Element                                       Warning Text  \
# 0             Wind  Becoming stormy this evening and tonight and c...
# 1             Wind  Becoming extremely windy or stormy this evenin...
# 2             Wind  Blustery for the rest of the afternoon with so...
# 3         Snow/Ice  Scattered outbreaks of rain and sleet spreadin...
# 4             Wind  Southeast winds mean speeds of 50 to 65 km/h w...
# 5             Wind  Becoming windy again on Sunday morning with st...
# 6             Wind  UpdateStrong south to southeast winds, with gu...
# 7             Wind  UndateStrong south to southeast winds, with gu...
# 8             Wind  Update Strong south to southeast winds, with g...
# 9             Wind  Update Strong south to southeast winds, with g...
# 10            Wind  UpdateStrong south to southeast winds, with gu...
# 11            Wind  Update Strong south to southeast winds, with g...
# 12            Wind  Widespread gales continuing today with gusts r...
# 13            Wind  Widespread gales continuing this evening and t...
# 14            Wind  Strong to gale force south to southwest winds ...
#
#     Duration_hours                     region  weather_flag
# 0        21.000000  HSE Dublin and North East             0
# 1        21.000000  HSE Dublin and North East             1
# 2         5.000000  HSE Dublin and North East             1
# 3        11.000000  HSE Dublin and North East             1
# 4        12.000000  HSE Dublin and North East             1
# 5        10.000000  HSE Dublin and North East             1
# 6        25.000000  HSE Dublin and North East             1
# 7        25.000000  HSE Dublin and North East             1
# 8        25.000000  HSE Dublin and North East             0
# 9        24.000000  HSE Dublin and North East             0
# 10       24.000000  HSE Dublin and North East             1
# 11       24.000000  HSE Dublin and North East             0
# 12       10.000000  HSE Dublin and North East             1
# 13        4.983333  HSE Dublin and North East             1
# 14        8.000000  HSE Dublin and North East             0

# %% [markdown]
# ## Hip Data

# %%
df_ihfd.rename(columns={"New Health Regions": "region"}, inplace=True)

# %%
df_ihfd["Adm_First_Pres_Hosp_DateTime"] = pd.to_datetime(df_ihfd["Adm_First_Pres_Hosp_DateTime"])
df_ihfd["date"] = df_ihfd["Adm_First_Pres_Hosp_DateTime"].dt.date
# convert to a pandas datetime if you prefer consistency
df_ihfd["date"] = pd.to_datetime(df_ihfd["date"])

# %%
df_ihfd.sort_values('date', ascending=True, inplace=True)

# %%
df_ihfd.head()
# Out:
#                           region NOCA_TraumaPeriodDay  \
# 20304               HSE Mid West                   AM
# 13462    HSE West and North West                   AM
# 8392   HSE Dublin and North East                   AM
# 9817   HSE Dublin and North East                   AM
# 11672  HSE Dublin and North East                   PM
#
#       Adm_First_Pres_Hosp_DateTime NOCA_FirstPresPeriodDay NOCA_AgeRange  \
# 20304                   2007-05-04                      PM         85-89
# 13462                   2007-09-04                      PM         75-79
# 8392                    2012-09-24                      AM         85-89
# 9817                    2012-12-30                      AM         85-89
# 11672                   2013-01-01                      PM         85-89
#
#       NOCA_Gender  LOS  Adm_Trauma_TYPE  Adm_Ward_Type  Adm_Pre_Frac_Indoor  \
# 20304      Female   60              2.0            1.0                  2.0
# 13462      Female    8              2.0            1.0                  2.0
# 8392         Male   11              2.0            1.0                  0.0
# 9817       Female   34              2.0            1.0                  0.0
# 11672      Female   22              2.0            1.0                  0.0
#
#        ...  Adm_Operation  Adm_Asa_Grade  Adm_Anaesthesia  \
# 20304  ...            3.0            2.0              5.0
# 13462  ...            9.0            2.0              1.0
# 8392   ...            0.0            3.0              5.0
# 9817   ...            7.0            4.0              5.0
# 11672  ...            1.0            3.0              1.0
#
#        Adm_Surgery_Delay_Reason  Adm_Mobilised  Adm_Pressure_Ulcers  \
# 20304                       0.0            2.0                  2.0
# 13462                       0.0            1.0                  2.0
# 8392                        0.0            0.0                  2.0
# 9817                        0.0            0.0                  2.0
# 11672                       2.0            0.0                  2.0
#
#        Adm_Spec_Falls_Assess  Adm_Bone_Protect_Med  Adm_Multi_Rehab_Assess  \
# 20304                    1.0                   1.0                     1.0
# 13462                    0.0                   1.0                     1.0
# 8392                     0.0                   0.0                     1.0
# 9817                     1.0                   0.0                     1.0
# 11672                    1.0                   0.0                     1.0
#
#             date
# 20304 2007-05-04
# 13462 2007-09-04
# 8392  2012-09-24
# 9817  2012-12-30
# 11672 2013-01-01
#
# [5 rows x 28 columns]

# %%
df_ihfd_filtered = df_ihfd[
    (df_ihfd['date'] >= '2014-01-01') & 
    (df_ihfd['date'] <= '2023-12-31').copy()
]

# %%
##check ihfd data has all dates 
df_ihfd['Adm_First_Pres_Hosp_DateTime'] = pd.to_datetime(df_ihfd['Adm_First_Pres_Hosp_DateTime']).dt.normalize()

# Generate the full calendar date range for the period 2014 to 2023
full_range = pd.date_range(start='2014-01-01', end='2023-12-31', freq='D')

# Get the unique dates from your DataFrame
unique_dates = pd.to_datetime(df_ihfd['Adm_First_Pres_Hosp_DateTime'].unique()).normalize()

# Find dates in full_range that are not present in unique_dates
missing_dates = full_range.difference(unique_dates)

# Check if any dates are missing
if missing_dates.empty:
    print("All calendar days are present in the dataset.")
else:
    print("The following dates are missing from the dataset:")
    print(missing_dates)
# Out:
# All calendar days are present in the dataset.

# %%
df_ihfd_season = df_ihfd_filtered.copy()

# %%
def month_to_season(month):
    # Convert month to an integer if it isn't already.
    month = int(month)
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Autumn'
    else:
        return 'unknown'

# %%
df_ihfd_season['month'] = df_ihfd_season['date'].dt.month

# %%
df_weather_full['month'] = df_weather_full['date'].dt.month

# %%
df_weather_full['season'] = df_weather_full['month'].apply(month_to_season)

# %%
df_ihfd_season['season'] = df_ihfd_season['month'].apply(month_to_season)

# %%
print(df_ihfd_season['season'].unique())
# Out:
# ['Winter' 'Spring' 'Summer' 'Autumn']

# %%
print(df_weather_full['season'].unique())
# Out:
# ['Winter' 'Spring' 'Summer' 'Autumn']

# %%
print(df_weather_full['season'].value_counts())
# Out:
# season
# Winter    6666
# Autumn    4740
# Summer    2664
# Spring    2328
# Name: count, dtype: int64

# %%
print(df_ihfd_season['season'].value_counts())
# Out:
# season
# Winter    9251
# Spring    8766
# Summer    8604
# Autumn    8600
# Name: count, dtype: int64

# %%
nan_counts = df_ihfd_season.isna().sum()
print(nan_counts)
# Out:
# region                          0
# NOCA_TraumaPeriodDay            0
# Adm_First_Pres_Hosp_DateTime    0
# NOCA_FirstPresPeriodDay         0
# NOCA_AgeRange                   0
# NOCA_Gender                     0
# LOS                             0
# Adm_Trauma_TYPE                 0
# Adm_Ward_Type                   0
# Adm_Pre_Frac_Indoor             0
# Adm_PRE_Frac_Outdoor            0
# Adm_Pre_Frac_Shop               0
# Adm_Pre_Frac_Number             0
# Adm_Fracture_Type               0
# Adm_Pathological                0
# Adm_Fragility                   0
# Adm_Pre_OP_Med_Assess           0
# Adm_Ger_Acute_Assess            0
# Adm_Operation                   0
# Adm_Asa_Grade                   0
# Adm_Anaesthesia                 0
# Adm_Surgery_Delay_Reason        0
# Adm_Mobilised                   0
# Adm_Pressure_Ulcers             0
# Adm_Spec_Falls_Assess           0
# Adm_Bone_Protect_Med            0
# Adm_Multi_Rehab_Assess          0
# date                            0
# month                           0
# season                          0
# dtype: int64

# %% [markdown]
# ## merging

# %%
hip_agg = (
    df_ihfd_season
    .groupby(['region', 'date','season'])
    .agg(hip_fracture_count=('date', 'count'))
    .reset_index()
)

# %%
hip_agg.head()
# Out:
#                     region       date  season  hip_fracture_count
# 0  HSE Dublin and Midlands 2014-01-02  Winter                   1
# 1  HSE Dublin and Midlands 2014-01-04  Winter                   5
# 2  HSE Dublin and Midlands 2014-01-06  Winter                   1
# 3  HSE Dublin and Midlands 2014-01-07  Winter                   1
# 4  HSE Dublin and Midlands 2014-01-08  Winter                   2

# %%
##add full date calandar to the aggregation 
# 1a. Identify all unique regions
regions = hip_agg['region'].unique()

# 1b. Identify the full date range
min_date = hip_agg['date'].min()
max_date = hip_agg['date'].max()

# %%
all_dates = pd.date_range(start=min_date, end=max_date, freq='D')

multi_index = pd.MultiIndex.from_product([regions, all_dates], names=['region', 'date'])
df_region_date = pd.DataFrame(index=multi_index).reset_index()

# %%
df_region_date.head(15)
# Out:
#                      region       date
# 0   HSE Dublin and Midlands 2014-01-01
# 1   HSE Dublin and Midlands 2014-01-02
# 2   HSE Dublin and Midlands 2014-01-03
# 3   HSE Dublin and Midlands 2014-01-04
# 4   HSE Dublin and Midlands 2014-01-05
# 5   HSE Dublin and Midlands 2014-01-06
# 6   HSE Dublin and Midlands 2014-01-07
# 7   HSE Dublin and Midlands 2014-01-08
# 8   HSE Dublin and Midlands 2014-01-09
# 9   HSE Dublin and Midlands 2014-01-10
# 10  HSE Dublin and Midlands 2014-01-11
# 11  HSE Dublin and Midlands 2014-01-12
# 12  HSE Dublin and Midlands 2014-01-13
# 13  HSE Dublin and Midlands 2014-01-14
# 14  HSE Dublin and Midlands 2014-01-15

# %%
df_hip_final = pd.merge(
    df_region_date,          # all region-date combos
    hip_agg,               # your aggregated counts
    on=['region', 'date'],   # merge keys
    how='left'               # left-join so we keep all rows from df_region_date
)

# %%
df_hip_final['month'] = df_hip_final['date'].dt.month

# %%
df_hip_final['season'] = df_hip_final['month'].apply(month_to_season)

# %%
df_hip_final['hip_fracture_count'] = df_hip_final['hip_fracture_count'].fillna(0)

# %%
df_hip_final.head(15)
# Out:
#                      region       date  season  hip_fracture_count  month
# 0   HSE Dublin and Midlands 2014-01-01  Winter                 0.0      1
# 1   HSE Dublin and Midlands 2014-01-02  Winter                 1.0      1
# 2   HSE Dublin and Midlands 2014-01-03  Winter                 0.0      1
# 3   HSE Dublin and Midlands 2014-01-04  Winter                 5.0      1
# 4   HSE Dublin and Midlands 2014-01-05  Winter                 0.0      1
# 5   HSE Dublin and Midlands 2014-01-06  Winter                 1.0      1
# 6   HSE Dublin and Midlands 2014-01-07  Winter                 1.0      1
# 7   HSE Dublin and Midlands 2014-01-08  Winter                 2.0      1
# 8   HSE Dublin and Midlands 2014-01-09  Winter                 2.0      1
# 9   HSE Dublin and Midlands 2014-01-10  Winter                 1.0      1
# 10  HSE Dublin and Midlands 2014-01-11  Winter                 2.0      1
# 11  HSE Dublin and Midlands 2014-01-12  Winter                 0.0      1
# 12  HSE Dublin and Midlands 2014-01-13  Winter                 0.0      1
# 13  HSE Dublin and Midlands 2014-01-14  Winter                 2.0      1
# 14  HSE Dublin and Midlands 2014-01-15  Winter                 4.0      1

# %%
df_hip_final['year'] = df_hip_final['date'].dt.year

# %%
severity_map = {
    'Yellow': 1,
    'Orange': 2,
    'Red': 3
}

df_weather_full['severity_num'] = df_weather_full['Warning Colour'].map(severity_map)

# %%
df_weather_full['severity_num'] = df_weather_full['severity_num'].fillna(0)

# %%
df_weather_full.head(15)
# Out:
#          date                 Issue Time                Valid From  \
# 0  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 1  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 2  2014-01-03  2014-01-02 09:00:00+00:00 2014-01-03 14:00:00+00:00
# 3  2014-01-04  2014-01-04 03:00:00+00:00 2014-01-04 03:00:00+00:00
# 4  2014-01-05  2014-01-04 10:00:00+00:00 2014-01-05 08:00:00+00:00
# 5  2014-01-05  2014-01-04 16:00:00+00:00 2014-01-05 08:00:00+00:00
# 6  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 7  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 8  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 9  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 12:00:00+00:00
# 10 2014-01-05  2014-01-05 12:00:00+00:00 2014-01-05 12:00:00+00:00
# 11 2014-01-05  2014-01-05 12:00:00+00:00 2014-01-05 12:00:00+00:00
# 12 2014-01-06  2014-01-06 09:00:00+00:00 2014-01-06 09:00:00+00:00
# 13 2014-01-06  2014-01-06 19:00:00+00:00 2014-01-06 19:00:00+00:00
# 14 2014-01-06  2014-01-06 21:00:00+00:00 2014-01-06 21:00:00+00:00
#
#                      Valid To               lag_valid_to Warning Colour  \
# 0   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 1   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
# 2   2014-01-03 19:00:00+00:00  2014-01-04 07:00:00+00:00         Yellow
# 3   2014-01-04 14:00:00+00:00  2014-01-05 02:00:00+00:00         Yellow
# 4   2014-01-05 20:00:00+00:00  2014-01-06 08:00:00+00:00         Yellow
# 5   2014-01-05 18:00:00+00:00  2014-01-06 06:00:00+00:00         Yellow
# 6   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 7   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 8   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Orange
# 9   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Orange
# 10  2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 11  2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 12  2014-01-06 19:00:00+00:00  2014-01-07 07:00:00+00:00         Orange
# 13  2014-01-06 23:59:00+00:00  2014-01-07 11:59:00+00:00         Yellow
# 14  2014-01-07 05:00:00+00:00  2014-01-07 17:00:00+00:00         Yellow
#
#    Warning Element                                       Warning Text  \
# 0             Wind  Becoming stormy this evening and tonight and c...
# 1             Wind  Becoming extremely windy or stormy this evenin...
# 2             Wind  Blustery for the rest of the afternoon with so...
# 3         Snow/Ice  Scattered outbreaks of rain and sleet spreadin...
# 4             Wind  Southeast winds mean speeds of 50 to 65 km/h w...
# 5             Wind  Becoming windy again on Sunday morning with st...
# 6             Wind  UpdateStrong south to southeast winds, with gu...
# 7             Wind  UndateStrong south to southeast winds, with gu...
# 8             Wind  Update Strong south to southeast winds, with g...
# 9             Wind  Update Strong south to southeast winds, with g...
# 10            Wind  UpdateStrong south to southeast winds, with gu...
# 11            Wind  Update Strong south to southeast winds, with g...
# 12            Wind  Widespread gales continuing today with gusts r...
# 13            Wind  Widespread gales continuing this evening and t...
# 14            Wind  Strong to gale force south to southwest winds ...
#
#     Duration_hours                     region  weather_flag  month  season  \
# 0        21.000000  HSE Dublin and North East             0      1  Winter
# 1        21.000000  HSE Dublin and North East             1      1  Winter
# 2         5.000000  HSE Dublin and North East             1      1  Winter
# 3        11.000000  HSE Dublin and North East             1      1  Winter
# 4        12.000000  HSE Dublin and North East             1      1  Winter
# 5        10.000000  HSE Dublin and North East             1      1  Winter
# 6        25.000000  HSE Dublin and North East             1      1  Winter
# 7        25.000000  HSE Dublin and North East             1      1  Winter
# 8        25.000000  HSE Dublin and North East             0      1  Winter
# 9        24.000000  HSE Dublin and North East             0      1  Winter
# 10       24.000000  HSE Dublin and North East             1      1  Winter
# 11       24.000000  HSE Dublin and North East             0      1  Winter
# 12       10.000000  HSE Dublin and North East             1      1  Winter
# 13        4.983333  HSE Dublin and North East             1      1  Winter
# 14        8.000000  HSE Dublin and North East             0      1  Winter
#
#     severity_num
# 0            2.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# 5            1.0
# 6            1.0
# 7            1.0
# 8            2.0
# 9            2.0
# 10           1.0
# 11           1.0
# 12           2.0
# 13           1.0
# 14           1.0

# %%
df_weather_full.query(
    "date == '2014-01-02'"
)
# Out:
# /tmp/ipykernel_191901/1394423637.py:1: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   df_weather_full.query(
#             date                 Issue Time                Valid From  \
# 0     2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 1     2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 2733  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 2734  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 5466  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 5467  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 8199  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 8200  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 10932 2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 10933 2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 13665 2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 13666 2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
#
#                         Valid To               lag_valid_to Warning Colour  \
# 0      2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 1      2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
# 2733   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 2734   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
# 5466   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 5467   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
# 8199   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 8200   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
# 10932  2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 10933  2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
# 13665  2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 13666  2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
#
#       Warning Element                                       Warning Text  \
# 0                Wind  Becoming stormy this evening and tonight and c...
# 1                Wind  Becoming extremely windy or stormy this evenin...
# 2733             Wind  Becoming stormy this evening and tonight and c...
# 2734             Wind  Becoming extremely windy or stormy this evenin...
# 5466             Wind  Becoming stormy this evening and tonight and c...
# 5467             Wind  Becoming extremely windy or stormy this evenin...
# 8199             Wind  Becoming stormy this evening and tonight and c...
# 8200             Wind  Becoming extremely windy or stormy this evenin...
# 10932            Wind  Becoming stormy this evening and tonight and c...
# 10933            Wind  Becoming extremely windy or stormy this evenin...
# 13665            Wind  Becoming stormy this evening and tonight and c...
# 13666            Wind  Becoming extremely windy or stormy this evenin...
#
#        Duration_hours                     region  weather_flag  month  season  \
# 0                21.0  HSE Dublin and North East             0      1  Winter
# 1                21.0  HSE Dublin and North East             1      1  Winter
# 2733             21.0    HSE Dublin and Midlands             0      1  Winter
# 2734             21.0    HSE Dublin and Midlands             1      1  Winter
# 5466             21.0  HSE Dublin and South East             0      1  Winter
# 5467             21.0  HSE Dublin and South East             1      1  Winter
# 8199             21.0               HSE Mid West             1      1  Winter
# 8200             21.0               HSE Mid West             1      1  Winter
# 10932            21.0             HSE South West             1      1  Winter
# 10933            21.0             HSE South West             0      1  Winter
# 13665            21.0    HSE West and North West             1      1  Winter
# 13666            21.0    HSE West and North West             0      1  Winter
#
#        severity_num
# 0               2.0
# 1               1.0
# 2733            2.0
# 2734            1.0
# 5466            2.0
# 5467            1.0
# 8199            2.0
# 8200            1.0
# 10932           2.0
# 10933           1.0
# 13665           2.0
# 13666           1.0

# %%
df_weather_final = (
    df_weather_full
    .groupby(['region', 'date', 'severity_num'], as_index=False)
    .agg({
        'weather_flag': 'max',  # any day with a warning => 1
        'Warning Element': lambda s: list(s.unique())
    })
)

# %%
df_weather_final.head(15)
# Out:
#                      region       date  severity_num  weather_flag  \
# 0   HSE Dublin and Midlands 2014-01-02           1.0             1
# 1   HSE Dublin and Midlands 2014-01-02           2.0             0
# 2   HSE Dublin and Midlands 2014-01-03           1.0             1
# 3   HSE Dublin and Midlands 2014-01-04           1.0             1
# 4   HSE Dublin and Midlands 2014-01-05           1.0             1
# 5   HSE Dublin and Midlands 2014-01-05           2.0             0
# 6   HSE Dublin and Midlands 2014-01-06           1.0             1
# 7   HSE Dublin and Midlands 2014-01-06           2.0             1
# 8   HSE Dublin and Midlands 2014-01-12           1.0             1
# 9   HSE Dublin and Midlands 2014-01-16           2.0             1
# 10  HSE Dublin and Midlands 2014-01-25           1.0             1
# 11  HSE Dublin and Midlands 2014-01-25           2.0             0
# 12  HSE Dublin and Midlands 2014-01-26           1.0             1
# 13  HSE Dublin and Midlands 2014-01-26           2.0             0
# 14  HSE Dublin and Midlands 2014-01-31           1.0             1
#
#             Warning Element
# 0                    [Wind]
# 1                    [Wind]
# 2                    [Wind]
# 3                [Snow/Ice]
# 4                    [Wind]
# 5                    [Wind]
# 6                    [Wind]
# 7                    [Wind]
# 8              [Rain, Wind]
# 9   [Fog (or freezing fog)]
# 10                   [Wind]
# 11                   [Wind]
# 12                   [Wind]
# 13                   [Wind]
# 14             [Wind, Rain]

# %%
merged = pd.merge(hip_agg, df_weather_final , on=['region', 'date'], how='left')

# %%
# Fill missing weather_flag values with 0 (indicating no adverse weather event)
merged['weather_flag'] = merged['weather_flag'].fillna(0)
merged['severity_num'] = merged['severity_num'].fillna(0)
merged['Warning Element'] = merged['Warning Element'].fillna('Unknown')

# %% [markdown]
# merged['hip_adv_event'] = ((merged['hip_fracture_count'] > 0) & (merged['weather_flag'] == 1)).astype(int)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17725 entries, 0 to 17724
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   region              17725 non-null  object
#  1   date                17725 non-null  datetime64[ns]
#  2   season              17725 non-null  object
#  3   hip_fracture_count  17725 non-null  int64
#  4   severity_num        17725 non-null  float64
#  5   weather_flag        17725 non-null  float64
#  6   Warning Element     17725 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 969.5+ KB

# %%
merged.isna().sum()
# Out:
# region                0
# date                  0
# season                0
# hip_fracture_count    0
# severity_num          0
# weather_flag          0
# Warning Element       0
# dtype: int64

# %%
print(merged['season'].value_counts())
# Out:
# season
# Winter    4739
# Autumn    4351
# Spring    4347
# Summer    4288
# Name: count, dtype: int64

# %%
merged.head(10)
# Out:
#                     region       date  season  hip_fracture_count  \
# 0  HSE Dublin and Midlands 2014-01-02  Winter                   1
# 1  HSE Dublin and Midlands 2014-01-02  Winter                   1
# 2  HSE Dublin and Midlands 2014-01-04  Winter                   5
# 3  HSE Dublin and Midlands 2014-01-06  Winter                   1
# 4  HSE Dublin and Midlands 2014-01-06  Winter                   1
# 5  HSE Dublin and Midlands 2014-01-07  Winter                   1
# 6  HSE Dublin and Midlands 2014-01-08  Winter                   2
# 7  HSE Dublin and Midlands 2014-01-09  Winter                   2
# 8  HSE Dublin and Midlands 2014-01-10  Winter                   1
# 9  HSE Dublin and Midlands 2014-01-11  Winter                   2
#
#    severity_num  weather_flag Warning Element
# 0           1.0           1.0          [Wind]
# 1           2.0           0.0          [Wind]
# 2           1.0           1.0      [Snow/Ice]
# 3           1.0           1.0          [Wind]
# 4           2.0           1.0          [Wind]
# 5           0.0           0.0         Unknown
# 6           0.0           0.0         Unknown
# 7           0.0           0.0         Unknown
# 8           0.0           0.0         Unknown
# 9           0.0           0.0         Unknown

# %%
merged['year'] = merged['date'].dt.year

# %%
# Create a subset DataFrame containing only rows for the Mid West
df_mid_west = merged[merged['region'] == 'HSE Mid West']


df_mid_west.isna().any(axis=1).sum()
# Out:
# 0

# %%
df_census.rename(columns={'HSE Regions': 'region'}, inplace=True)

# %%
df_census.rename(columns={'Year': 'year'}, inplace=True)

# %%
df_census.rename(columns={'Population (Linear Est)': 'population'}, inplace=True)

# %%
df_census['region'] = df_census['region'].replace('HSE Midwest', 'HSE Mid West')

# %%
df_with_pop = pd.merge(
    merged,     # your merged daily data (weather + hip fractures)
    df_census,     # population per region-year
    how='left', # keep all rows from merged even if no match found
    on=['region','year']
)

# %%
df_with_pop['log_population'] = np.log(df_with_pop['population'])

# %%
df_with_pop[df_with_pop['region'] == 'HSE Mid West'].head(15)
# Out:
#             region       date  season  hip_fracture_count  severity_num  \
# 9701  HSE Mid West 2014-01-03  Winter                   2           1.0
# 9702  HSE Mid West 2014-01-05  Winter                   3           1.0
# 9703  HSE Mid West 2014-01-05  Winter                   3           2.0
# 9704  HSE Mid West 2014-01-06  Winter                   2           1.0
# 9705  HSE Mid West 2014-01-06  Winter                   2           2.0
# 9706  HSE Mid West 2014-01-08  Winter                   2           0.0
# 9707  HSE Mid West 2014-01-09  Winter                   1           0.0
# 9708  HSE Mid West 2014-01-11  Winter                   1           0.0
# 9709  HSE Mid West 2014-01-12  Winter                   1           1.0
# 9710  HSE Mid West 2014-01-13  Winter                   1           0.0
# 9711  HSE Mid West 2014-01-15  Winter                   1           0.0
# 9712  HSE Mid West 2014-01-20  Winter                   1           0.0
# 9713  HSE Mid West 2014-01-22  Winter                   1           0.0
# 9714  HSE Mid West 2014-01-23  Winter                   2           0.0
# 9715  HSE Mid West 2014-01-26  Winter                   1           1.0
#
#       weather_flag Warning Element  year  population  log_population
# 9701           1.0          [Wind]  2014      152114       11.932386
# 9702           1.0          [Wind]  2014      152114       11.932386
# 9703           1.0          [Wind]  2014      152114       11.932386
# 9704           1.0          [Wind]  2014      152114       11.932386
# 9705           1.0          [Wind]  2014      152114       11.932386
# 9706           0.0         Unknown  2014      152114       11.932386
# 9707           0.0         Unknown  2014      152114       11.932386
# 9708           0.0         Unknown  2014      152114       11.932386
# 9709           1.0    [Rain, Wind]  2014      152114       11.932386
# 9710           0.0         Unknown  2014      152114       11.932386
# 9711           0.0         Unknown  2014      152114       11.932386
# 9712           0.0         Unknown  2014      152114       11.932386
# 9713           0.0         Unknown  2014      152114       11.932386
# 9714           0.0         Unknown  2014      152114       11.932386
# 9715           1.0          [Wind]  2014      152114       11.932386

# %%
df_with_pop[df_with_pop['region'] == 'HSE Dublin and Midlands'].head(15)
# Out:
#                      region       date  season  hip_fracture_count  \
# 0   HSE Dublin and Midlands 2014-01-02  Winter                   1
# 1   HSE Dublin and Midlands 2014-01-02  Winter                   1
# 2   HSE Dublin and Midlands 2014-01-04  Winter                   5
# 3   HSE Dublin and Midlands 2014-01-06  Winter                   1
# 4   HSE Dublin and Midlands 2014-01-06  Winter                   1
# 5   HSE Dublin and Midlands 2014-01-07  Winter                   1
# 6   HSE Dublin and Midlands 2014-01-08  Winter                   2
# 7   HSE Dublin and Midlands 2014-01-09  Winter                   2
# 8   HSE Dublin and Midlands 2014-01-10  Winter                   1
# 9   HSE Dublin and Midlands 2014-01-11  Winter                   2
# 10  HSE Dublin and Midlands 2014-01-14  Winter                   2
# 11  HSE Dublin and Midlands 2014-01-15  Winter                   4
# 12  HSE Dublin and Midlands 2014-01-16  Winter                   2
# 13  HSE Dublin and Midlands 2014-01-17  Winter                   3
# 14  HSE Dublin and Midlands 2014-01-18  Winter                   1
#
#     severity_num  weather_flag          Warning Element  year  population  \
# 0            1.0           1.0                   [Wind]  2014      317830
# 1            2.0           0.0                   [Wind]  2014      317830
# 2            1.0           1.0               [Snow/Ice]  2014      317830
# 3            1.0           1.0                   [Wind]  2014      317830
# 4            2.0           1.0                   [Wind]  2014      317830
# 5            0.0           0.0                  Unknown  2014      317830
# 6            0.0           0.0                  Unknown  2014      317830
# 7            0.0           0.0                  Unknown  2014      317830
# 8            0.0           0.0                  Unknown  2014      317830
# 9            0.0           0.0                  Unknown  2014      317830
# 10           0.0           0.0                  Unknown  2014      317830
# 11           0.0           0.0                  Unknown  2014      317830
# 12           2.0           1.0  [Fog (or freezing fog)]  2014      317830
# 13           0.0           0.0                  Unknown  2014      317830
# 14           0.0           0.0                  Unknown  2014      317830
#
#     log_population
# 0        12.669272
# 1        12.669272
# 2        12.669272
# 3        12.669272
# 4        12.669272
# 5        12.669272
# 6        12.669272
# 7        12.669272
# 8        12.669272
# 9        12.669272
# 10       12.669272
# 11       12.669272
# 12       12.669272
# 13       12.669272
# 14       12.669272

# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
print(merged['severity_num'].apply(type).value_counts())
# Out:
# severity_num
# <class 'float'>    17725
# Name: count, dtype: int64

# %%
import statsmodels.formula.api as smf

# Expanded formula with additional predictors and an interaction term.
formula = "hip_fracture_count ~ weather_flag * + C(season) +C(region)"

# Fit the Poisson regression model (without an offset for this example)
poisson_model = smf.glm(formula=formula, data=df_with_pop, family=sm.families.Poisson(),offset=df_with_pop['log_population']).fit()


# Print the summary of the model
print("Poisson Regression Results:")
print(poisson_model.summary())

# Optionally, check for overdispersion:
print("Residual Deviance:", poisson_model.deviance)
print("Degrees of Freedom:", poisson_model.df_resid)
# Out:
# Poisson Regression Results:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     hip_fracture_count   No. Observations:                17725
# Model:                            GLM   Df Residuals:                    17712
# Model Family:                 Poisson   Df Model:                           12
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -27483.
# Date:                Wed, 12 Feb 2025   Deviance:                       10092.
# Time:                        07:47:13   Pearson chi2:                 1.10e+04
# No. Iterations:                     4   Pseudo R-squ. (CS):            0.02426
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                -12.0313      0.016   -743.839      0.000     -12.063     -12.000
# C(season)[T.Spring]                        0.0099      0.016      0.621      0.535      -0.021       0.041
# C(season)[T.Summer]                        0.0009      0.016      0.056      0.955      -0.031       0.032
# C(season)[T.Winter]                        0.0434      0.016      2.652      0.008       0.011       0.076
# C(region)[T.HSE Dublin and North East]     0.0438      0.017      2.621      0.009       0.011       0.077
# C(region)[T.HSE Dublin and South East]     0.0939      0.017      5.492      0.000       0.060       0.127
# C(region)[T.HSE Mid West]                  0.4325      0.022     19.872      0.000       0.390       0.475
# C(region)[T.HSE South West]                0.1273      0.018      6.902      0.000       0.091       0.163
# C(region)[T.HSE West and North West]       0.0707      0.018      3.938      0.000       0.036       0.106
# weather_flag                               0.0318      0.030      1.061      0.289      -0.027       0.090
# weather_flag:C(season)[T.Spring]          -0.0340      0.046     -0.740      0.460      -0.124       0.056
# weather_flag:C(season)[T.Summer]          -0.0326      0.045     -0.717      0.473      -0.122       0.056
# weather_flag:C(season)[T.Winter]       -7.241e-05      0.037     -0.002      0.998      -0.072       0.072
# ==========================================================================================================
# Residual Deviance: 10092.210386234805
# Degrees of Freedom: 17712

# %%
import statsmodels.formula.api as smf

# Define the model formula
formula = "hip_fracture_count ~ weather_flag * + C(season) + C(region)"

# Fit the Negative Binomial model
nb_model = smf.glm(formula=formula, data=df_with_pop,
                   family=sm.families.NegativeBinomial()).fit()

# Print the summary of the model
print(nb_model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     hip_fracture_count   No. Observations:                17725
# Model:                            GLM   Df Residuals:                    17712
# Model Family:        NegativeBinomial   Df Model:                           12
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -34379.
# Date:                Wed, 12 Feb 2025   Deviance:                       3236.0
# Time:                        10:47:52   Pearson chi2:                 3.57e+03
# No. Iterations:                     5   Pseudo R-squ. (CS):            0.01384
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                  0.7076      0.028     24.992      0.000       0.652       0.763
# C(season)[T.Spring]                        0.0092      0.028      0.330      0.741      -0.046       0.064
# C(season)[T.Summer]                       -0.0004      0.028     -0.013      0.989      -0.055       0.055
# C(season)[T.Winter]                        0.0428      0.029      1.479      0.139      -0.014       0.100
# C(region)[T.HSE Dublin and North East]     0.1892      0.030      6.290      0.000       0.130       0.248
# C(region)[T.HSE Dublin and South East]     0.1048      0.030      3.446      0.001       0.045       0.164
# C(region)[T.HSE Mid West]                 -0.3159      0.036     -8.845      0.000      -0.386      -0.246
# C(region)[T.HSE South West]               -0.0498      0.032     -1.555      0.120      -0.112       0.013
# C(region)[T.HSE West and North West]      -0.0301      0.031     -0.961      0.337      -0.091       0.031
# weather_flag                               0.0212      0.053      0.402      0.687      -0.082       0.124
# weather_flag:C(season)[T.Spring]          -0.0346      0.081     -0.430      0.667      -0.193       0.123
# weather_flag:C(season)[T.Summer]          -0.0174      0.080     -0.218      0.827      -0.174       0.139
# weather_flag:C(season)[T.Winter]           0.0015      0.065      0.023      0.981      -0.127       0.130
# ==========================================================================================================
# /home/paulharford/anaconda3/envs/msc/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
