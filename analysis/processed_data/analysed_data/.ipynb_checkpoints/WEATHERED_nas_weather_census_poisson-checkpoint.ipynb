# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import seaborn as sns
sns.set_palette('colorblind')
from matplotlib.pyplot import tight_layout
# ##SETTING PARAMS FOR MATPLOTLIB FIGURES
plt.rcParams.update({"figure.figsize": (6, 6),
                 "axes.facecolor": "white",
                 "axes.edgecolor": "black"})
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=sns.color_palette('colorblind'))
##set font size
font = {'family': 'sans-serif',
       'weight': 'normal',
       'size': 14}
plt.rc('font', **font)
# ##PANDAS PLOTTING
pd.plotting.register_matplotlib_converters()

# %% [markdown]
# ### Step 1: save environment file

# %%
# !conda env export > quasi_poisson_environment.yml

# %% [markdown]
# ### Step 2: import modules

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.regression.mixed_linear_model import MixedLM
import re
import patsy

# Function to parse model summary text and extract coefficients

# For inline plots in Jupyter
# %matplotlib inline
import pandas as pd
import matplotlib as plt
import glob
import os
import xml.etree.ElementTree as ET
from datetime import datetime, timezone
from tqdm import tqdm
import codecs
import csv
import openpyxl

# %% [markdown]
# ### Step 3 : Import files

# %%
data_directory_weather = "/home/paulharford/college/project/project_data/processed/WEATHERED_warnings_2014-2023_cleaned_v4.csv"
data_directory_nas = "/home/paulharford/college/project/project_data/nas/WEATHERED_nas_clean_v1.csv"
data_directory_census = "/home/paulharford/college/project/project_data/processed/WEATHERED_census_pop_age_grp_gender_region.csv"
full_path_nas = os.path.abspath(data_directory_nas)
full_path_weather = os.path.abspath(data_directory_weather)
full_path_census = os.path.abspath(data_directory_census)

# %%
df_nas = pd.read_csv(full_path_nas)
df_weather = pd.read_csv(full_path_weather)
df_census = pd.read_csv(full_path_census)

# %%
df_weather["Valid From"] = pd.to_datetime(df_weather["Valid From"])
df_weather["date"] = df_weather["Valid From"].dt.date
df_weather["date"] = pd.to_datetime(df_weather["date"])
df_weather["Valid To"] = pd.to_datetime(df_weather["Valid To"])

# %% [markdown]
# ### Step 3: Create full dates range for 2014 to 2023 to merge with datasets

# %%
##add full date calandar to the aggregation 
# 1a. Identify all unique regions
regions = df_weather['region'].unique()

# 1b. Identify the full date range
min_date = df_weather['date'].min()
max_date = df_weather['date'].max()

# %%
##create all dates for all years to merge with datasets so we can have days with and without events 
all_dates = pd.date_range(start=min_date, end=max_date, freq='D')

multi_index = pd.MultiIndex.from_product([regions, all_dates], names=['region', 'date'])
df_region_date = pd.DataFrame(index=multi_index).reset_index()

# %%
##copy full date range for hip and weather data
df_region_date_nas = df_region_date.copy()

# %%
df_region_date_weather = df_region_date.copy()

# %%
df_region_date_census = df_region_date.copy()

# %%
df_region_date.head()
# Out:
#                     region       date
# 0  HSE Dublin and Midlands 2014-01-02
# 1  HSE Dublin and Midlands 2014-01-03
# 2  HSE Dublin and Midlands 2014-01-04
# 3  HSE Dublin and Midlands 2014-01-05
# 4  HSE Dublin and Midlands 2014-01-06

# %% [markdown]
# ### Step 4: Weather data

# %% [markdown]
# ### Step 4.1: Map weather severtiy to numeric value and aggregate weather data

# %%
severity_mapping = {
    'Yellow': 1,
    'Orange': 2,
    'Red': 3
}

df_weather['warning_severity_numeric'] = df_weather['warning_severity'].map(severity_mapping)

# %%
def aggregate_weather_data(df_weather, keep_columns=None):
    """
    Aggregate weather data by region, date, weather_type, and warning_severity while
    preserving specified additional columns.
    
    Args:
        df_weather: DataFrame containing weather data
        keep_columns: List of additional columns to preserve (beyond the groupby columns)
        
    Returns:
        Aggregated DataFrame with one row per unique region-date-weather_type-warning_severity combination
    """
    # Define default columns to keep if none provided
    if keep_columns is None:
        keep_columns = [
            'counties_in_region', 	
            'county_weight'	
         ]
    
    # Define all columns to group by
    group_cols = ['region', 'date', 'warning_phenomenon', 'warning_severity']
    
    # Define aggregation functions for numeric and other columns
    agg_dict = {
        'warning_severity_numeric': 'max'
    }
    
    # Add aggregation functions for additional columns to preserve
    for col in keep_columns:
        if col in df_weather.columns:
            # For string columns, take the first value (assuming they're the same within groups)
            if df_weather[col].dtype == 'object':
                agg_dict[col] = 'first'
            # For boolean or integer flags (like has_multiple_events, warning_upgraded)
            elif df_weather[col].dtype in ['bool', 'int64', 'int32']:
                agg_dict[col] = 'max'
            # For numeric columns, take the max
            elif pd.api.types.is_numeric_dtype(df_weather[col]):
                agg_dict[col] = 'max'
            # For datetime columns
            elif pd.api.types.is_datetime64_dtype(df_weather[col]):
                agg_dict[col] = 'max'
            # Default to first value for any other types
            else:
                agg_dict[col] = 'first'
    
    # Group by the specified columns and aggregate
    weather_agg = df_weather.groupby(group_cols, as_index=False).agg(agg_dict)
    
    # Add the weather flag column (set to 1 if there is any event)
    weather_agg['weather_event'] = 1
    
    return weather_agg

# %%
weather_agg = aggregate_weather_data(df_weather)

# %%
weather_agg.head()
# Out:
#                     region       date warning_phenomenon warning_severity  \
# 0  HSE Dublin and Midlands 2014-01-02               Wind           Yellow
# 1  HSE Dublin and Midlands 2014-01-03               Wind           Yellow
# 2  HSE Dublin and Midlands 2014-01-04           Snow_Ice           Yellow
# 3  HSE Dublin and Midlands 2014-01-05               Wind           Yellow
# 4  HSE Dublin and Midlands 2014-01-06               Wind           Orange
#
#    warning_severity_numeric  counties_in_region  county_weight  weather_event
# 0                         1                   7       0.142857              1
# 1                         1                   7       0.142857              1
# 2                         1                   7       0.142857              1
# 3                         1                   7       0.142857              1
# 4                         2                   7       0.142857              1

# %% [markdown]
# ### Step 4.2: Merge aggregated weather data with all date ranges so we have alldates with or without adverse weather events.

# %%
df_weather_final = pd.merge(
    df_region_date_weather,          # all region-date combos
    weather_agg,               # your aggregated counts
    on=['region', 'date'],   # merge keys
    how='left'               # left-join so we keep all rows from df_region_date
)

# %% [markdown]
# ### Step 4.3: Resolve any missing values after merge and aggregation steps

# %%
##after joing wetaher data to full fate range there and NaN values, whixh is expected as not all days have weather events
df_weather_final['warning_severity_numeric'] = df_weather_final['warning_severity_numeric'].fillna(0)

# %%
df_weather_final['warning_phenomenon'] = df_weather_final['warning_phenomenon'].fillna('no_weather_type')

# %%
df_weather_final['warning_severity'] = df_weather_final['warning_severity'].fillna('no_weather_severity')

# %% [markdown]
# ### Step 4.4: Add county count and county weight as not all regions have the same number of counties.

# %%
# Define your HSE region mapping.
hse_regions = {
    'HSE Dublin and North East': ['Cavan', 'Monaghan', 'Louth', 'Meath', 'Dublin'],
    'HSE Dublin and Midlands': ['Kildare', 'Wicklow', 'Laois', 'Offaly', 'Longford', 'Westmeath', 'Dublin'],
    'HSE Dublin and South East': ['Carlow', 'Kilkenny', 'Tipperary', 'Waterford', 'Wexford', 'Wicklow', 'Dublin'],
    'HSE Mid West': ['Clare', 'Limerick', 'Tipperary'],
    'HSE South West': ['Cork', 'Kerry'],
    'HSE West and North West': ['Donegal', 'Sligo', 'Leitrim', 'Mayo', 'Galway', 'Roscommon']
}

# List of all county columns
county_cols = [
    "Clare", "Cork", "Kerry", "Limerick", "Tipperary", "Waterford",
    "Carlow", "Dublin", "Kildare", "Kilkenny", "Laois", "Longford",
    "Louth", "Meath", "Offaly", "Westmeath", "Wexford", "Wicklow",
    "Cavan", "Donegal", "Monaghan", "Galway", "Leitrim", "Mayo",
    "Roscommon", "Sligo"
]

# %%
if df_weather_final['counties_in_region'].isna().any() or df_weather_final['county_weight'].isna().any():
    # Fill counties_in_region with correct values from your mapping
    df_weather_final['counties_in_region'] = df_weather_final['region'].map(
        {region: len(counties) for region, counties in hse_regions.items()}
    )
    
    # Recalculate county_weight
    df_weather_final['county_weight'] = 1 / df_weather_final['counties_in_region']

# %%
df_weather_final['weather_event'] = df_weather_final['weather_event'].fillna(0)

# %%
df_weather_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22511 entries, 0 to 22510
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   region                    22511 non-null  object
#  1   date                      22511 non-null  datetime64[ns]
#  2   warning_phenomenon        22511 non-null  object
#  3   warning_severity          22511 non-null  object
#  4   warning_severity_numeric  22511 non-null  float64
#  5   counties_in_region        22511 non-null  int64
#  6   county_weight             22511 non-null  float64
#  7   weather_event             22511 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Step 5: NAS Data

# %% [markdown]
# ### Step 5.1: Prepare NAS data

# %%
df_nas["date"] = pd.to_datetime(df_nas["date"])

# %%
df_nas.head()
# Out:
#         date Time of Day         PickupTown DespatchCode  \
# 0 2016-01-01       Night            DUNGLOE       17B01P
# 1 2016-01-01       Night  BEAUMONT DUBLIN 9       17B01G
# 2 2016-01-01       Night           DROGHEDA        17B01
# 3 2016-01-01       Night        BORRISOKANE       17B01P
# 4 2016-01-01       Night            WEXFORD       17B01G
#
#                                  DespCodeDescription  \
# 0  Falls - Possibly Dangerous body Area - Public ...
# 1  Falls - Possibly Dangerous body Area - On the ...
# 2             Falls - Possibly Dangerous body Area -
# 3  Falls - Possibly Dangerous body Area - Public ...
# 4  Falls - Possibly Dangerous body Area - On the ...
#
#               Hospital Attended                     region
# 0  LETTERKENNY GENERAL HOSPITAL    HSE West and North West
# 1             BEAUMONT HOSPITAL  HSE Dublin and North East
# 2     LOURDES HOSPITAL DROGHEDA  HSE Dublin and North East
# 3  PORTIUNCULA GENERAL HOSPITAL    HSE West and North West
# 4              unknown_hospital  HSE Dublin and South East

# %%
# Drop Northern Ireland
df_nas.drop(df_nas[df_nas['region'] == 'Northern Ireland'].index, inplace=True)

# %%
df_nas_filtered = df_nas[
    (df_nas['date'] >= '2016-01-01') & 
    (df_nas['date'] <= '2023-12-31').copy()
]

# %% [markdown]
# ### Step 5.2: View and catergorise NAS fall codes

# %%
code_to_description = dict(zip(df_nas_filtered['DespatchCode'], df_nas_filtered['DespCodeDescription']))
for code, desc in sorted(code_to_description.items()):
    print(f"{code}: {desc}")
# Out:
# 17A00: Falls - Alpha Override
# 17A00A: Falls - Alpha Override - Accessibility concerns/difficulty
# 17A00G: Falls -  Alpha Override - On the ground or floor
# 17A00H: Falls - Alpha Override
# 17A00P: Falls -  Alpha Override - Public place (street, carpark, market)
# 17A01: Falls - Not Dangerous Proximal/distal body area with deformity
# 17A01A: Falls - Not Dangerous Proximal/distal body area with deformity - Accessibility concerns/difficulty
# 17A01E: Falls - Not Dangerous Proximal/distal body area with deformity - Environmental problems (rain, heat, cold)
# 17A01G: Falls - Not Dangerous Proximal/distal body area with deformity - On the ground or floor
# 17A01H: Falls - Not Dangerous Proximal/distal body area with deformity
# 17A01I: Falls - Not Dangerous Proximal/distal body area with deformity
# 17A01P: Falls - Not Dangerous Proximal/ distal body area with deformity - Public place (street, carpark, market)
# 17A02: Fall - Not Dangerous Proximal body area
# 17A02A: Fall - Not Dangerous Proximal body area - Accessibility concerns/difficulty
# 17A02D: Fall - Not Dangerous Proximal body area
# 17A02E: Fall - Not Dangerous Proximal body area - Environmental problems (rain, heat, cold)
# 17A02G: Fall - Not Dangerous Proximal body area - On the ground or floor
# 17A02H: Fall - Not Dangerous Proximal body area
# 17A02I: Fall - Not Dangerous Proximal body area
# 17A02L: Fall - Not Dangerous Proximal body area
# 17A02P: Fall - Not Dangerous Proximal body area - Public place (street, carpark, market)
# 17A02U: Fall - Not Dangerous Proximal body area
# 17A03: Falls - (>=6hrs) Injuries except Distal body area (without Priority symptoms)
# 17A03A: Falls - (>=6hrs) Injuries except Distal body area (without Priority symptoms) - Accessibility concerns/difficulty
# 17A03E: Falls -(>=6hrs) Injuries except Distal body area (without Priority symptoms) - Environmental problems (rain, heat, cold)
# 17A03G: Falls - (>=6hrs) Injuries except Distal body area (without Priority symptoms) - On the ground or floor
# 17A03I: Falls - (>=6hrs) Injuries except Distal body area (without Priority symptoms)
# 17A03L: Falls - (>=6hrs) Injuries except Distal body area (without Priority symptoms)
# 17A03P: Falls - (>=6hrs) Injuries except Distal body area (without Priority symptoms) - Public place (street, carpark, market)
# 17A04: Falls - Public assistance (No injuries or prioirty symptons)
# 17A04A: Falls - Public assistance (No injuries or priority symptons) - Accessibility concerns/difficulty
# 17A04E: Falls - Public assistance (No injuries or priority symptons) - Environmental problems (rain, heat, cold)
# 17A04G: Falls - Public assistance (No injuries or priority symptons) - On the ground or floor
# 17A04H: Falls - Public assistance (No injuries or prioirty symptons)
# 17A04I: Falls - Public assistance (No injuries or prioirty symptons)
# 17A04P: Falls - Public assistance (No injuries or priority symptons)  - Public place (street, carpark, market)
# 17B00: Falls - Bravo Override
# 17B00A: Falls - Bravo Override  - Accessibility concerns/difficulty
# 17B00E: Falls - Bravo Override  - Environmental problems (rain, heat, cold)
# 17B00G: Falls - Bravo Override  - On the ground or floor
# 17B00H: Falls - Bravo Override
# 17B00I: Falls - Bravo Override
# 17B00L: Falls - Bravo Override
# 17B00P: Falls - Bravo Override  - Public place (street, carpark, market)
# 17B01: Falls - Possibly Dangerous body Area -
# 17B01A: Falls - Possibly Dangerous body Area - Accessibility concerns/difficulty
# 17B01E: Falls - Possibly Dangerous body Area - Environmental problems (rain, heat, cold)
# 17B01G: Falls - Possibly Dangerous body Area - On the ground or floor
# 17B01H: Falls - Possibly Dangerous body Area -
# 17B01I: Falls - Possibly Dangerous body Area -
# 17B01L: Falls - Possibly Dangerous body Area -
# 17B01M: Falls - Possibly Dangerous body Area -
# 17B01P: Falls - Possibly Dangerous body Area - Public place (street, carpark, market)
# 17B01S: Falls - Possibly Dangerous body Area -
# 17B01T: Falls - Possibly Dangerous body Area -
# 17B02: Falls - Serious Haemorrhage
# 17B02A: Falls - Serious Haemorrhage  - Accessibility concerns/difficulty
# 17B02E: Falls - Serious Haemorrhage - Environmental problems (rain, heat, cold)
# 17B02G: Falls - Serious Haemorrhage - On the ground or floor
# 17B02H: Falls - Serious Haemorrhage
# 17B02P: Falls - Serious Haemorrhage - Public place (street, carpark, market)
# 17B03: Falls - Unknown Status other codes not applicable
# 17B03A: Falls - Unknown Status other codes not applicable   - Accessibility concerns/difficulty
# 17B03E: Falls - Unknown Status other codes not applicable - Environmental problems (rain, heat, cold)
# 17B03G: Falls - Unknown Status other codes not applicable - On the ground or floor
# 17B03H: Falls - Unknown Status other codes not applicable
# 17B03I: Falls - Unknown Status other codes not applicable
# 17B03P: Falls - Unknown Status other codes not applicable - Public place (street, carpark, market)
# 17B04: Falls - Unknown Status other codes not applicable
# 17B04A: Falls - Unknown Status other codes not applicable - Accessibility concerns/difficulty
# 17B04E: Falls - Unknown Status other codes not applicable - Enviromental Problems (Rain/Heat/Cold)
# 17B04G: Falls - Unknown Status other codes not applicable - On the Ground/Floor
# 17B04H: Falls - Unknown Status other codes not applicable
# 17B04I: Falls - Unknown Status other codes not applicable
# 17B04L: Falls - Unknown Status other codes not applicable
# 17B04P: Falls - Unknown Status other codes not applicable - Public Place (Street/Market/Carpark)
# 17D00: Falls - Delta Override
# 17D00A: Falls - Delta Override  - Accessibility concerns/difficulty
# 17D00E: Falls - Delta Override - Environmental problems (rain, heat, cold)
# 17D00G: Falls - Delta Override - On the ground or floor
# 17D00I: Falls - Delta Override
# 17D00P: Falls - Delta Override - Public place (street, carpark, market)
# 17D01: Falls - Extreme fall - (>30ft)
# 17D01A: Falls - Extreme fall - (>30ft)  - Accessibility concerns/difficulty
# 17D01E: Falls - Extreme fall - (>30ft) - Environmental problems (rain, heat, cold)
# 17D01G: Falls - Extreme fall - (>30ft) - On the ground or floor
# 17D01P: Falls - Extreme fall - (>30ft) - Public place (street, carpark, market)
# 17D02: Falls - Arrest
# 17D02A: Falls - Arrest  - Accessibility concerns/difficulty
# 17D02E: Falls - Arrest - Environmental problems (rain, heat, cold)
# 17D02G: Falls - Arrest - On the ground or floor
# 17D02P: Falls - Arrest ) - Public place (street, carpark, market)
# 17D03: Falls - Unconscious
# 17D03A: Falls - Unconscious  - Accessibility concerns/difficulty
# 17D03E: Falls - Unconscious - Environmental problems (rain, heat, cold)
# 17D03G: Falls - Unconscious - On the ground or floor
# 17D03P: Falls - Unconscious - Public place (street, carpark, market)
# 17D04: Falls - Not Alert
# 17D04A: Falls - Not Alert - Accessibility concerns/difficulty
# 17D04B: Falls - Not Alert
# 17D04C: Falls - Not Alert
# 17D04E: Falls - Not Alert - Environmental problems (rain, heat, cold)
# 17D04G: Falls - Not Alert - On the ground or floor
# 17D04H: Falls - Not Alert
# 17D04I: Falls - Not Alert
# 17D04L: Falls - Not Alert
# 17D04O: Falls - Not Alert
# 17D04P: Falls - Not Alert - Public place (street, carpark, market)
# 17D05: Falls - Chest/Neck Injury - Diff in breathing
# 17D05A: Falls - Chest/Neck Injury - Diff in breathing - Accessibility concerns/difficulty
# 17D05E: Falls - Chest/Neck Injury - Diff in breathing  - Environmental problems (rain, heat, cold)
# 17D05G: Falls - Chest/Neck Injury - Diff in breathing -   On the ground or floor
# 17D05H: Falls - Chest/Neck Injury - Diff in breathing
# 17D05I: Falls - Chest/Neck Injury - Diff in breathing
# 17D05P: Falls - Chest/Neck Injury - Diff in breathing - - Public place (street, carpark, market)
# 17D06: Falls - Long Fall
# 17D06A: Falls - Long Fall - Accessibility concerns/difficulty
# 17D06E: Falls - Long Fall - Environmental problems (rain, heat, cold)
# 17D06G: Falls - Long Fall  - On the ground or floor
# 17D06P: Falls - Long Fall - Public place (street, carpark, market)
# 17O01: Falls - Not Dangerous Distal body area
# 17O01A: Falls - Not Dangerous Distal body area - Accessibility concern/difficulty
# 17O01E: Falls - Not Dangerous Distal body area - Environmental problems (rain, heat, cold)
# 17O01G: Falls - Not Dangerous Distal body area - on the ground or floor
# 17O01H: Falls - Not Dangerous Distal body area
# 17O01I: Falls - Not Dangerous Distal body area
# 17O01P: Falls - Not Dangerous Distal body area  - Public place (Street, carpark, market)
# 17O02: Falls (>=6hrs) Injuries to Distal body area (without Priority symptoms)
# 17O02A: Falls (>=6hrs) Injuries to Distal body area (without Priority symptoms) - Accessibility concern/difficulty
# 17O02E: Falls (>=6hrs) Injuries to Distal body area (without Priority symptoms)- Environmental problems (rain, heat, cold)
# 17O02G: Falls (>=6hrs) Injuries to Distal body area (without Priority symptoms) - on the ground or floor
# 30A01: Traumatic injuries - Not Dangerous Proximal or Distal  body area without deformity
# 30A02: Traumatic injuries - Not Dangerous Proximal body area
# 30A03: Traumatic injuries - Non recent (>=6 hrs) Injuries except distal body area (without priority symptons)
# 30B00: Traumatic Injuries (Specific) -  Bravo Override
# 30B01: Traumatic Injuries - Possibly Dangerous Body Area
# 30B03: Traumatic Injuries - Unknown body area (remote patient location)
# 30D00: Traumatic Injuries (Specific) Delta Override
# 30D02: Traumatic Injuries - Unconscious with Traumatic injuries
# 30D03: Traumatic Injuries - Not Alert with Traumatic Injuries

# %%
def categorize_fall_code(code):
    # Grouping based on the base code prefix.
    if code.startswith("17A00"):
        return "17A00_alpha_override"
    elif code.startswith("17A01"):
        return "17A01_not_dangerous_deformity"
    elif code.startswith("17A02"):
        return "17A02_not_dangerous_proximal"
    elif code.startswith("17A03"):
        return "17A03_injuries_excluding_distal"
    elif code.startswith("17A04"):
        return "17A04_public_assistance"
    elif code.startswith("17B00"):
        return "17B00_bravo_override"
    elif code.startswith("17B01"):
        return "17B01_possibly_dangerous"
    elif code.startswith("17B02"):
        return "17B02_serious_haemorrhage"
    elif code.startswith("17B03"):
        return "17B03_unknown_status"
    elif code.startswith("17B04"):
        return "17B04_unknown_status"
    elif code.startswith("17D00"):
        return "17D00_delta_override"
    elif code.startswith("17D01"):
        return "17D01_extreme_fall"
    elif code.startswith("17D02"):
        return "17D02_arrest"
    elif code.startswith("17D03"):
        return "17D03_unconscious"
    elif code.startswith("17D04"):
        return "17D04_not_alert"
    elif code.startswith("17D05"):
        return "17D05_chest_neck_injury"
    elif code.startswith("17D06"):
        return "17D06_long_fall"
    elif code.startswith("17O01"):
        return "17O01_not_dangerous_distal"
    elif code.startswith("17O02"):
        return "17O02_injuries_distal"
    elif code.startswith("30A01"):
        return "30A01_traumatic_not_dangerous"
    elif code.startswith("30A02"):
        return "30A02_traumatic_proximal"
    elif code.startswith("30A03"):
        return "30A03_traumatic_non_recent"
    elif code.startswith("30B00"):
        return "30B00_bravo_override_traumatic"
    elif code.startswith("30B01"):
        return "30B01_traumatic_possibly_dangerous"
    elif code.startswith("30B03"):
        return "30B03_traumatic_unknown"
    elif code.startswith("30D00"):
        return "30D00_delta_override_traumatic"
    elif code.startswith("30D02"):
        return "30D02_traumatic_unconscious"
    elif code.startswith("30D03"):
        return "30D03_traumatic_not_alert"
    else:
        return "other"


# DataFrame has a column 'DespatchCode' that is a list or string.
df_nas_filtered['fall_category_group'] = df_nas_filtered['DespatchCode'].apply(categorize_fall_code)

# Check the distribution of the new groups:
print(df_nas_filtered['fall_category_group'].value_counts())
# Out:
# fall_category_group
# 17B01_possibly_dangerous              45537
# 17A02_not_dangerous_proximal          23402
# 17B00_bravo_override                  19851
# 17D04_not_alert                       19433
# 17A03_injuries_excluding_distal        7850
# 17A04_public_assistance                7155
# 30A03_traumatic_non_recent             6698
# 17B04_unknown_status                   4974
# 30B00_bravo_override_traumatic         4178
# 30B01_traumatic_possibly_dangerous     4008
# 30D03_traumatic_not_alert              1859
# 17D05_chest_neck_injury                1680
# 17B02_serious_haemorrhage              1362
# 17B03_unknown_status                   1323
# 17O01_not_dangerous_distal             1159
# 17D03_unconscious                       913
# 30A02_traumatic_proximal                745
# 17D00_delta_override                    637
# 17A01_not_dangerous_deformity           625
# 17O02_injuries_distal                   574
# 17D06_long_fall                         474
# 17D02_arrest                            289
# 30A01_traumatic_not_dangerous           145
# 17A00_alpha_override                    120
# 30D00_delta_override_traumatic           64
# 30D02_traumatic_unconscious              56
# 17D01_extreme_fall                       33
# 30B03_traumatic_unknown                   5
# Name: count, dtype: int64

# %%
df_nas_filtered.head(10)
# Out:
#         date Time of Day             PickupTown DespatchCode  \
# 0 2016-01-01       Night                DUNGLOE       17B01P
# 1 2016-01-01       Night      BEAUMONT DUBLIN 9       17B01G
# 2 2016-01-01       Night               DROGHEDA        17B01
# 3 2016-01-01       Night            BORRISOKANE       17B01P
# 4 2016-01-01       Night                WEXFORD       17B01G
# 5 2016-01-01       Night              KILLARNEY       17D04G
# 6 2016-01-01       Night  RATHNEENY WEST LAGHEY        17B01
# 7 2016-01-01     Morning             GLENAGEARY       17B00G
# 8 2016-01-01     Morning                DUNDALK        17B01
# 9 2016-01-01     Morning               CAUSEWAY       17B01G
#
#                                  DespCodeDescription  \
# 0  Falls - Possibly Dangerous body Area - Public ...
# 1  Falls - Possibly Dangerous body Area - On the ...
# 2             Falls - Possibly Dangerous body Area -
# 3  Falls - Possibly Dangerous body Area - Public ...
# 4  Falls - Possibly Dangerous body Area - On the ...
# 5         Falls - Not Alert - On the ground or floor
# 6             Falls - Possibly Dangerous body Area -
# 7   Falls - Bravo Override  - On the ground or floor
# 8             Falls - Possibly Dangerous body Area -
# 9  Falls - Possibly Dangerous body Area - On the ...
#
#               Hospital Attended                     region  \
# 0  LETTERKENNY GENERAL HOSPITAL    HSE West and North West
# 1             BEAUMONT HOSPITAL  HSE Dublin and North East
# 2     LOURDES HOSPITAL DROGHEDA  HSE Dublin and North East
# 3  PORTIUNCULA GENERAL HOSPITAL    HSE West and North West
# 4              unknown_hospital  HSE Dublin and South East
# 5     KERRY UNIVERSITY HOSPITAL             HSE South West
# 6        SLIGO GENERAL HOSPITAL    HSE West and North West
# 7          ST VINCENTS HOSPITAL  HSE Dublin and South East
# 8     LOURDES HOSPITAL DROGHEDA  HSE Dublin and North East
# 9     KERRY UNIVERSITY HOSPITAL             HSE South West
#
#         fall_category_group
# 0  17B01_possibly_dangerous
# 1  17B01_possibly_dangerous
# 2  17B01_possibly_dangerous
# 3  17B01_possibly_dangerous
# 4  17B01_possibly_dangerous
# 5           17D04_not_alert
# 6  17B01_possibly_dangerous
# 7      17B00_bravo_override
# 8  17B01_possibly_dangerous
# 9  17B01_possibly_dangerous

# %%
nan_counts = df_nas_filtered.isna().sum()
print(nan_counts)
# Out:
# date                   0
# Time of Day            0
# PickupTown             0
# DespatchCode           0
# DespCodeDescription    0
# Hospital Attended      0
# region                 0
# fall_category_group    0
# dtype: int64

# %% [markdown]
# ### Step 5.3: Aggregate NAS data

# %%
nas_detailed = (
    df_nas_filtered
    .groupby(['region', 'date', 'fall_category_group'])
    .size()
    .reset_index(name='callout_count')
)

# %%
nas_detailed.head(10)
# Out:
#                     region       date              fall_category_group  \
# 0  HSE Dublin and Midlands 2016-01-01     17A02_not_dangerous_proximal
# 1  HSE Dublin and Midlands 2016-01-01             17B00_bravo_override
# 2  HSE Dublin and Midlands 2016-01-01         17B01_possibly_dangerous
# 3  HSE Dublin and Midlands 2016-01-01                  17D04_not_alert
# 4  HSE Dublin and Midlands 2016-01-01          17D05_chest_neck_injury
# 5  HSE Dublin and Midlands 2016-01-01       17O01_not_dangerous_distal
# 6  HSE Dublin and Midlands 2016-01-01       30A03_traumatic_non_recent
# 7  HSE Dublin and Midlands 2016-01-02  17A03_injuries_excluding_distal
# 8  HSE Dublin and Midlands 2016-01-02             17B00_bravo_override
# 9  HSE Dublin and Midlands 2016-01-02                  17D04_not_alert
#
#    callout_count
# 0              1
# 1              1
# 2              3
# 3              1
# 4              1
# 5              1
# 6              1
# 7              2
# 8              2
# 9              1

# %% [markdown]
# ### Step 5.4: Merge NAS data with all dates dataframe

# %%
#Identify all unique regions
regions = nas_detailed['region'].unique()

#Identify the full date range
min_date = nas_detailed['date'].min()
max_date = nas_detailed['date'].max()

# %%
all_dates = pd.date_range(start=min_date, end=max_date, freq='D')

multi_index = pd.MultiIndex.from_product([regions, all_dates], names=['region', 'date'])
df_region_date = pd.DataFrame(index=multi_index).reset_index()

# %%
df_region_date.head(15)
# Out:
#                      region       date
# 0   HSE Dublin and Midlands 2016-01-01
# 1   HSE Dublin and Midlands 2016-01-02
# 2   HSE Dublin and Midlands 2016-01-03
# 3   HSE Dublin and Midlands 2016-01-04
# 4   HSE Dublin and Midlands 2016-01-05
# 5   HSE Dublin and Midlands 2016-01-06
# 6   HSE Dublin and Midlands 2016-01-07
# 7   HSE Dublin and Midlands 2016-01-08
# 8   HSE Dublin and Midlands 2016-01-09
# 9   HSE Dublin and Midlands 2016-01-10
# 10  HSE Dublin and Midlands 2016-01-11
# 11  HSE Dublin and Midlands 2016-01-12
# 12  HSE Dublin and Midlands 2016-01-13
# 13  HSE Dublin and Midlands 2016-01-14
# 14  HSE Dublin and Midlands 2016-01-15

# %%
df_nas_final = pd.merge(
    df_region_date,          # all region-date combos
    nas_detailed,               # your aggregated counts
    on=['region', 'date'],   # merge keys
    how='left'               # left-join so we keep all rows from df_region_date
)

# %%
df_nas_final.head(10)
# Out:
#                     region       date              fall_category_group  \
# 0  HSE Dublin and Midlands 2016-01-01     17A02_not_dangerous_proximal
# 1  HSE Dublin and Midlands 2016-01-01             17B00_bravo_override
# 2  HSE Dublin and Midlands 2016-01-01         17B01_possibly_dangerous
# 3  HSE Dublin and Midlands 2016-01-01                  17D04_not_alert
# 4  HSE Dublin and Midlands 2016-01-01          17D05_chest_neck_injury
# 5  HSE Dublin and Midlands 2016-01-01       17O01_not_dangerous_distal
# 6  HSE Dublin and Midlands 2016-01-01       30A03_traumatic_non_recent
# 7  HSE Dublin and Midlands 2016-01-02  17A03_injuries_excluding_distal
# 8  HSE Dublin and Midlands 2016-01-02             17B00_bravo_override
# 9  HSE Dublin and Midlands 2016-01-02                  17D04_not_alert
#
#    callout_count
# 0            1.0
# 1            1.0
# 2            3.0
# 3            1.0
# 4            1.0
# 5            1.0
# 6            1.0
# 7            2.0
# 8            2.0
# 9            1.0

# %%
df_nas_final['year'] = df_nas_final['date'].dt.year

# %% [markdown]
# ### Step 5.5: Merge NAS data with weather data

# %%
merged = pd.merge(df_nas_final, df_weather_final , on=['region', 'date'], how='left')

# %%
if merged['counties_in_region'].isna().any() or merged['county_weight'].isna().any():
    # Fill counties_in_region with correct values from your mapping
    merged['counties_in_region'] = merged['region'].map(
        {region: len(counties) for region, counties in hse_regions.items()}
    )
    
    # Recalculate county_weight
    merged['county_weight'] = 1 / merged['counties_in_region']

# %%
merged.head(10)
# Out:
#                     region       date              fall_category_group  \
# 0  HSE Dublin and Midlands 2016-01-01     17A02_not_dangerous_proximal
# 1  HSE Dublin and Midlands 2016-01-01             17B00_bravo_override
# 2  HSE Dublin and Midlands 2016-01-01         17B01_possibly_dangerous
# 3  HSE Dublin and Midlands 2016-01-01                  17D04_not_alert
# 4  HSE Dublin and Midlands 2016-01-01          17D05_chest_neck_injury
# 5  HSE Dublin and Midlands 2016-01-01       17O01_not_dangerous_distal
# 6  HSE Dublin and Midlands 2016-01-01       30A03_traumatic_non_recent
# 7  HSE Dublin and Midlands 2016-01-02  17A03_injuries_excluding_distal
# 8  HSE Dublin and Midlands 2016-01-02             17B00_bravo_override
# 9  HSE Dublin and Midlands 2016-01-02                  17D04_not_alert
#
#    callout_count  year warning_phenomenon     warning_severity  \
# 0            1.0  2016           Rainfall               Yellow
# 1            1.0  2016           Rainfall               Yellow
# 2            3.0  2016           Rainfall               Yellow
# 3            1.0  2016           Rainfall               Yellow
# 4            1.0  2016           Rainfall               Yellow
# 5            1.0  2016           Rainfall               Yellow
# 6            1.0  2016           Rainfall               Yellow
# 7            2.0  2016    no_weather_type  no_weather_severity
# 8            2.0  2016    no_weather_type  no_weather_severity
# 9            1.0  2016    no_weather_type  no_weather_severity
#
#    warning_severity_numeric  counties_in_region  county_weight  weather_event
# 0                       1.0                   7       0.142857            1.0
# 1                       1.0                   7       0.142857            1.0
# 2                       1.0                   7       0.142857            1.0
# 3                       1.0                   7       0.142857            1.0
# 4                       1.0                   7       0.142857            1.0
# 5                       1.0                   7       0.142857            1.0
# 6                       1.0                   7       0.142857            1.0
# 7                       0.0                   7       0.142857            0.0
# 8                       0.0                   7       0.142857            0.0
# 9                       0.0                   7       0.142857            0.0

# %%
merged = merged[merged['fall_category_group'].notna()]

# %%
missing_categories = df_nas_filtered[df_nas_filtered['fall_category_group'].isnull()]
missing_categories.head()
# Out:
# Empty DataFrame
# Columns: [date, Time of Day, PickupTown, DespatchCode, DespCodeDescription, Hospital Attended, region, fall_category_group]
# Index: []

# %% [markdown]
# ### Step 5.6: Resolve any missing values after merge and aggregation steps

# %%
# Fill missing weather_flag values with 0 (indicating no adverse weather event)
merged['warning_severity_numeric'] = merged['warning_severity_numeric'].fillna(0)
merged['weather_event'] = merged['weather_event'].fillna(0)
merged['warning_phenomenon'] = merged['warning_phenomenon'].fillna('no_weather_type')
merged['warning_severity'] = merged['warning_severity'].fillna('no_weather_severity')

# %%
nan_counts = merged.isna().sum()
print(nan_counts)
# Out:
# region                      0
# date                        0
# fall_category_group         0
# callout_count               0
# year                        0
# warning_phenomenon          0
# warning_severity            0
# warning_severity_numeric    0
# counties_in_region          0
# county_weight               0
# weather_event               0
# dtype: int64

# %%
merged.head(10)
# Out:
#                     region       date              fall_category_group  \
# 0  HSE Dublin and Midlands 2016-01-01     17A02_not_dangerous_proximal
# 1  HSE Dublin and Midlands 2016-01-01             17B00_bravo_override
# 2  HSE Dublin and Midlands 2016-01-01         17B01_possibly_dangerous
# 3  HSE Dublin and Midlands 2016-01-01                  17D04_not_alert
# 4  HSE Dublin and Midlands 2016-01-01          17D05_chest_neck_injury
# 5  HSE Dublin and Midlands 2016-01-01       17O01_not_dangerous_distal
# 6  HSE Dublin and Midlands 2016-01-01       30A03_traumatic_non_recent
# 7  HSE Dublin and Midlands 2016-01-02  17A03_injuries_excluding_distal
# 8  HSE Dublin and Midlands 2016-01-02             17B00_bravo_override
# 9  HSE Dublin and Midlands 2016-01-02                  17D04_not_alert
#
#    callout_count  year warning_phenomenon     warning_severity  \
# 0            1.0  2016           Rainfall               Yellow
# 1            1.0  2016           Rainfall               Yellow
# 2            3.0  2016           Rainfall               Yellow
# 3            1.0  2016           Rainfall               Yellow
# 4            1.0  2016           Rainfall               Yellow
# 5            1.0  2016           Rainfall               Yellow
# 6            1.0  2016           Rainfall               Yellow
# 7            2.0  2016    no_weather_type  no_weather_severity
# 8            2.0  2016    no_weather_type  no_weather_severity
# 9            1.0  2016    no_weather_type  no_weather_severity
#
#    warning_severity_numeric  counties_in_region  county_weight  weather_event
# 0                       1.0                   7       0.142857            1.0
# 1                       1.0                   7       0.142857            1.0
# 2                       1.0                   7       0.142857            1.0
# 3                       1.0                   7       0.142857            1.0
# 4                       1.0                   7       0.142857            1.0
# 5                       1.0                   7       0.142857            1.0
# 6                       1.0                   7       0.142857            1.0
# 7                       0.0                   7       0.142857            0.0
# 8                       0.0                   7       0.142857            0.0
# 9                       0.0                   7       0.142857            0.0

# %%
merged['year'] = merged['date'].dt.year

# %% [markdown]
# ### Step 8: Census Data

# %%
df_census.head()
# Out:
#                     region        date age_group  female   male  total  year
# 0  HSE Dublin and Midlands  2014-01-01   60 - 64   23070  23499  46569  2014
# 1  HSE Dublin and Midlands  2014-01-02   60 - 64   23070  23499  46569  2014
# 2  HSE Dublin and Midlands  2014-01-03   60 - 64   23070  23499  46569  2014
# 3  HSE Dublin and Midlands  2014-01-04   60 - 64   23070  23499  46569  2014
# 4  HSE Dublin and Midlands  2014-01-05   60 - 64   23070  23499  46569  2014

# %%
##NAS dataset doesnt have gender or age_group so dropping them from  the census data 
census_totals = (
    df_census
    .groupby(['region', 'date'])
    .agg(
        population=('total', 'sum')  
    )
    .reset_index()
)

# %%
# Convert date columns to the same type before merging
merged['date'] = pd.to_datetime(merged['date'])
census_totals['date'] = pd.to_datetime(census_totals['date'])

# %% [markdown]
# ### Step 6: Merge census data with NAS_Weather data

# %%
df_with_pop = pd.merge(
    merged,     
    census_totals,     # population per region-year
    how='left', # keep all rows from merged even if no match found
    on=['region','date']
)

# %%
df_with_pop.head(15)
# Out:
#                      region       date              fall_category_group  \
# 0   HSE Dublin and Midlands 2016-01-01     17A02_not_dangerous_proximal
# 1   HSE Dublin and Midlands 2016-01-01             17B00_bravo_override
# 2   HSE Dublin and Midlands 2016-01-01         17B01_possibly_dangerous
# 3   HSE Dublin and Midlands 2016-01-01                  17D04_not_alert
# 4   HSE Dublin and Midlands 2016-01-01          17D05_chest_neck_injury
# 5   HSE Dublin and Midlands 2016-01-01       17O01_not_dangerous_distal
# 6   HSE Dublin and Midlands 2016-01-01       30A03_traumatic_non_recent
# 7   HSE Dublin and Midlands 2016-01-02  17A03_injuries_excluding_distal
# 8   HSE Dublin and Midlands 2016-01-02             17B00_bravo_override
# 9   HSE Dublin and Midlands 2016-01-02                  17D04_not_alert
# 10  HSE Dublin and Midlands 2016-01-03         17B01_possibly_dangerous
# 11  HSE Dublin and Midlands 2016-01-04     17A02_not_dangerous_proximal
# 12  HSE Dublin and Midlands 2016-01-04  17A03_injuries_excluding_distal
# 13  HSE Dublin and Midlands 2016-01-04         17B01_possibly_dangerous
# 14  HSE Dublin and Midlands 2016-01-04             17B03_unknown_status
#
#     callout_count  year warning_phenomenon     warning_severity  \
# 0             1.0  2016           Rainfall               Yellow
# 1             1.0  2016           Rainfall               Yellow
# 2             3.0  2016           Rainfall               Yellow
# 3             1.0  2016           Rainfall               Yellow
# 4             1.0  2016           Rainfall               Yellow
# 5             1.0  2016           Rainfall               Yellow
# 6             1.0  2016           Rainfall               Yellow
# 7             2.0  2016    no_weather_type  no_weather_severity
# 8             2.0  2016    no_weather_type  no_weather_severity
# 9             1.0  2016    no_weather_type  no_weather_severity
# 10            2.0  2016    no_weather_type  no_weather_severity
# 11            1.0  2016    no_weather_type  no_weather_severity
# 12            3.0  2016    no_weather_type  no_weather_severity
# 13            2.0  2016    no_weather_type  no_weather_severity
# 14            1.0  2016    no_weather_type  no_weather_severity
#
#     warning_severity_numeric  counties_in_region  county_weight  \
# 0                        1.0                   7       0.142857
# 1                        1.0                   7       0.142857
# 2                        1.0                   7       0.142857
# 3                        1.0                   7       0.142857
# 4                        1.0                   7       0.142857
# 5                        1.0                   7       0.142857
# 6                        1.0                   7       0.142857
# 7                        0.0                   7       0.142857
# 8                        0.0                   7       0.142857
# 9                        0.0                   7       0.142857
# 10                       0.0                   7       0.142857
# 11                       0.0                   7       0.142857
# 12                       0.0                   7       0.142857
# 13                       0.0                   7       0.142857
# 14                       0.0                   7       0.142857
#
#     weather_event  population
# 0             1.0      177614
# 1             1.0      177614
# 2             1.0      177614
# 3             1.0      177614
# 4             1.0      177614
# 5             1.0      177614
# 6             1.0      177614
# 7             0.0      177614
# 8             0.0      177614
# 9             0.0      177614
# 10            0.0      177614
# 11            0.0      177614
# 12            0.0      177614
# 13            0.0      177614
# 14            0.0      177614

# %%
# Count entries with either 'Hospital Unknown' or 'Unknown'
count = df_with_pop[df_with_pop['region'].isin(['Hospital Unknown', 'Unknown'])].shape[0]
print("Count of entries with 'Hospital Unknown' or 'Unknown':", count)
# Out:
# Count of entries with 'Hospital Unknown' or 'Unknown': 0

# %% [markdown]
# ### Step 6.1: add log of popultion value

# %%
df_with_pop['log_population'] = np.log(df_with_pop['population'])

# %% [markdown]
# ### Step 6.2: Add additional features to help improve model

# %%
# Add month number
df_with_pop['month'] = pd.DatetimeIndex(df_with_pop['date']).month

# Create seasons (meteorological seasons)
def assign_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:  # months 9, 10, 11
        return 'Autumn'

df_with_pop['season'] = df_with_pop['month'].apply(assign_season)

# Create dummy variables for seasons
df_with_pop['is_winter'] = (df_with_pop['season'] == 'Winter').astype(int)
df_with_pop['is_spring'] = (df_with_pop['season'] == 'Spring').astype(int)
df_with_pop['is_summer'] = (df_with_pop['season'] == 'Summer').astype(int)
df_with_pop['is_autumn'] = (df_with_pop['season'] == 'Autumn').astype(int)

# %%
nan_counts = df_with_pop.isna().sum()
print(nan_counts)
# Out:
# region                      0
# date                        0
# fall_category_group         0
# callout_count               0
# year                        0
# warning_phenomenon          0
# warning_severity            0
# warning_severity_numeric    0
# counties_in_region          0
# county_weight               0
# weather_event               0
# population                  0
# log_population              0
# month                       0
# season                      0
# is_winter                   0
# is_spring                   0
# is_summer                   0
# is_autumn                   0
# dtype: int64

# %% [markdown]
# ### Step 7: Final dataset, check for correlating features

# %%
import matplotlib.pyplot as plt
numeric_cols = df_with_pop.select_dtypes(include=[np.number]).columns.tolist()

if 'callout_count' not in numeric_cols:
    print("Warning: callout_count not found in numeric columns")
else:
    # Create a correlation matrix
    corr_matrix = df_with_pop[numeric_cols].corr(method='pearson')
    
    # Sort correlations with hip_fracture_count
    hip_correlations = corr_matrix['callout_count'].sort_values(ascending=False)
    print("Correlations with NAS callout:")
    print(hip_correlations)
    
    # Plot heatmap of correlations
    plt.figure(figsize=(12, 10))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, fmt='.2f')
    plt.title('Correlation Matrix of Numeric Variables')
    plt.tight_layout()
    plt.show()
    
    # Create a bar plot of correlations with hip_fracture_callout
    plt.figure(figsize=(10, 8))
    hip_correlations.drop('callout_count').plot(kind='barh', color=sns.color_palette("coolwarm", len(hip_correlations)))
    plt.title('Variables Correlated with NAS callout')
    plt.xlabel('Correlation Coefficient')
    plt.axvline(x=0, color='black', linestyle='-', alpha=0.3)
    plt.grid(axis='x', linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()
    
    # Optional: Create pairplots for top correlated variables
    top_correlated = hip_correlations.drop('callout_count').abs().nlargest(5).index.tolist()
    top_vars = ['callout_count'] + top_correlated
    
    plt.figure(figsize=(15, 10))
    sns.pairplot(df_with_pop[top_vars], height=2.5)
    plt.suptitle('Pairwise Relationships Between Hip Fracture Count and Top Correlated Variables', y=1.02)
    plt.tight_layout()
    plt.show()
# Out:
# Correlations with NAS callout:
# callout_count               1.000000
# year                        0.075007
# log_population              0.072953
# county_weight               0.057165
# population                  0.055315
# month                       0.030474
# weather_event               0.019263
# warning_severity_numeric    0.017076
# is_summer                   0.011119
# is_autumn                   0.005354
# is_winter                   0.004213
# is_spring                  -0.020966
# counties_in_region         -0.033592
# Name: callout_count, dtype: float64

# %%
df_with_pop.head()
# Out:
#                     region       date           fall_category_group  \
# 0  HSE Dublin and Midlands 2016-01-01  17A02_not_dangerous_proximal
# 1  HSE Dublin and Midlands 2016-01-01          17B00_bravo_override
# 2  HSE Dublin and Midlands 2016-01-01      17B01_possibly_dangerous
# 3  HSE Dublin and Midlands 2016-01-01               17D04_not_alert
# 4  HSE Dublin and Midlands 2016-01-01       17D05_chest_neck_injury
#
#    callout_count  year warning_phenomenon warning_severity  \
# 0            1.0  2016           Rainfall           Yellow
# 1            1.0  2016           Rainfall           Yellow
# 2            3.0  2016           Rainfall           Yellow
# 3            1.0  2016           Rainfall           Yellow
# 4            1.0  2016           Rainfall           Yellow
#
#    warning_severity_numeric  counties_in_region  county_weight  weather_event  \
# 0                       1.0                   7       0.142857            1.0
# 1                       1.0                   7       0.142857            1.0
# 2                       1.0                   7       0.142857            1.0
# 3                       1.0                   7       0.142857            1.0
# 4                       1.0                   7       0.142857            1.0
#
#    population  log_population  month  season  is_winter  is_spring  is_summer  \
# 0      177614       12.087368      1  Winter          1          0          0
# 1      177614       12.087368      1  Winter          1          0          0
# 2      177614       12.087368      1  Winter          1          0          0
# 3      177614       12.087368      1  Winter          1          0          0
# 4      177614       12.087368      1  Winter          1          0          0
#
#    is_autumn
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
## naroow done fall categories 
# Define the categories to keep (high a,d moderate frequency)
high_moderate_categories = [
'17B01_possibly_dangerous',           
'17A02_not_dangerous_proximal',     
'17B00_bravo_override',              
'17D04_not_alert',                     
'17A03_injuries_excluding_distal',    
'17A04_public_assistance'               
#'30A03_traumatic_non_recent'                     
]

# Filter the dataframe to keep only these categories
df_filtered = df_with_pop[df_with_pop['fall_category_group'].isin(high_moderate_categories)]

# Verify the filtering worked
print(f"Original dataframe size: {len(df_with_pop)}")
print(f"Filtered dataframe size: {len(df_filtered)}")
print(f"Categories removed: {len(df_with_pop) - len(df_filtered)} rows")

# You can also check the remaining categories
print(df_filtered['fall_category_group'].value_counts())
# Out:
# Original dataframe size: 91656
# Filtered dataframe size: 63478
# Categories removed: 28178 rows
# fall_category_group
# 17B01_possibly_dangerous           15965
# 17A02_not_dangerous_proximal       12584
# 17B00_bravo_override               11478
# 17D04_not_alert                    11367
# 17A03_injuries_excluding_distal     6334
# 17A04_public_assistance             5750
# Name: count, dtype: int64

# %%
### Step 10: MixedLM modeling

# %%
# Extract all unique regions from your dataset
all_regions = df_with_pop['region'].unique().tolist()

# Print the regions to verify
print("HSE Regions included in analysis:")
for region in all_regions:
    print(f"- {region}")
# Out:
# HSE Regions included in analysis:
# - HSE Dublin and Midlands
# - HSE Dublin and North East
# - HSE Dublin and South East
# - HSE Mid West
# - HSE South West
# - HSE West and North West

# %%
df_filtered.head()
# Out:
#                     region       date              fall_category_group  \
# 0  HSE Dublin and Midlands 2016-01-01     17A02_not_dangerous_proximal
# 1  HSE Dublin and Midlands 2016-01-01             17B00_bravo_override
# 2  HSE Dublin and Midlands 2016-01-01         17B01_possibly_dangerous
# 3  HSE Dublin and Midlands 2016-01-01                  17D04_not_alert
# 7  HSE Dublin and Midlands 2016-01-02  17A03_injuries_excluding_distal
#
#    callout_count  year warning_phenomenon     warning_severity  \
# 0            1.0  2016           Rainfall               Yellow
# 1            1.0  2016           Rainfall               Yellow
# 2            3.0  2016           Rainfall               Yellow
# 3            1.0  2016           Rainfall               Yellow
# 7            2.0  2016    no_weather_type  no_weather_severity
#
#    warning_severity_numeric  counties_in_region  county_weight  weather_event  \
# 0                       1.0                   7       0.142857            1.0
# 1                       1.0                   7       0.142857            1.0
# 2                       1.0                   7       0.142857            1.0
# 3                       1.0                   7       0.142857            1.0
# 7                       0.0                   7       0.142857            0.0
#
#    population  log_population  month  season  is_winter  is_spring  is_summer  \
# 0      177614       12.087368      1  Winter          1          0          0
# 1      177614       12.087368      1  Winter          1          0          0
# 2      177614       12.087368      1  Winter          1          0          0
# 3      177614       12.087368      1  Winter          1          0          0
# 7      177614       12.087368      1  Winter          1          0          0
#
#    is_autumn
# 0          0
# 1          0
# 2          0
# 3          0
# 7          0

# %%
import statsmodels
print(f"statsmodels version: {statsmodels.__version__}")
# Out:
# statsmodels version: 0.14.4

# %%
df_model.to_csv('/home/paulharford/college/project/project_data/processed/WEATHERED_nas_merged_v2.csv', index=False)

# %%
# Imports
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
import patsy
from statsmodels.discrete.discrete_model import GeneralizedPoisson
import seaborn as sns
from scipy import stats

# Make a copy of your data
df_model = df_filtered.copy()

# Create custom interaction variables for the most significant effects
# 1. Weather-fall category interactions
# 7-day lag (weekly pattern)
df_model['callout_count_lag7'] = df_model.groupby('region')['callout_count'].shift(7)
# 30-day lag (monthly pattern)
df_model['callout_count_lag30'] = df_model.groupby('region')['callout_count'].shift(30)

# Create the design matrices
y, X = patsy.dmatrices(
    "callout_count ~ C(year) + C(month) + C(region) + C(fall_category_group) + "
    "warning_severity:C(fall_category_group) +" 
    "C(region):C(fall_category_group) +"
    "C(year):C(region) +"
    "callout_count_lag30",
    data=df_model,
    return_type='dataframe'
)

# Define the offset - using the indices from y to ensure alignment
offset = df_model.loc[y.index, "log_population"]

# Fit Poisson model
poisson_model = sm.GLM(y, X, family=sm.families.Poisson(), offset=offset)
poisson_results = poisson_model.fit()

### 1. Fit Poisson Model (Baseline)
print("="*60)
print("FITTING POISSON MODEL (BASELINE)")
print("="*60)

# Dispersion estimate
dispersion = poisson_results.deviance / poisson_results.df_resid
print(f"\nPoisson Dispersion parameter: {dispersion:.4f}")
print("\nPoisson Model Summary:")
print(poisson_results.summary())

### 2. Fit Generalized Poisson Model (For Underdispersion)
print("\n" + "="*60)
print("FITTING GENERALIZED POISSON MODEL (FOR UNDERDISPERSION)")
print("="*60)

# Convert y to 1D array
y_array = np.asarray(y).flatten()

try:
    gp_model = GeneralizedPoisson(endog=y_array, exog=X, offset=offset)
    gp_results = gp_model.fit(maxiter=1000, disp=False)
    
    print("\nGeneralized Poisson Model Summary:")
    print(gp_results.summary())
    gp_fitted = True
except Exception as e:
    print(f"\nGeneralized Poisson model failed: {e}")
    gp_fitted = False

### 3. Fit Negative Binomial Model (For Comparison)
print("\n" + "="*60)
print("FITTING NEGATIVE BINOMIAL MODEL (FOR COMPARISON)")
print("="*60)

try:
    nb_model = sm.GLM(y, X, family=sm.families.NegativeBinomial(), offset=offset)
    nb_results = nb_model.fit(disp=False)
    
    print("\nNegative Binomial Model Summary:")
    print(nb_results.summary())
    nb_fitted = True
except Exception as e:
    print(f"\nNegative Binomial model failed (expected for underdispersed data): {e}")
    nb_fitted = False

### 4. Functions to Calculate MSE and MAPE
def calculate_metrics(y_true, y_pred):
    """
    Calculate MSE and MAPE for model evaluation
    """
    # Ensure arrays are flattened
    y_true = np.asarray(y_true).flatten()
    y_pred = np.asarray(y_pred).flatten()
    
    # MSE
    mse = np.mean((y_true - y_pred)**2)
    
    # MAPE - handle zero values
    mask = y_true != 0
    if np.sum(mask) > 0:
        mape = np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100
    else:
        mape = np.nan
    
    # RMSE
    rmse = np.sqrt(mse)
    
    # MAE
    mae = np.mean(np.abs(y_true - y_pred))
    
    return mse, mape, rmse, mae

### 5. Get predictions and calculate metrics for each model
# IMPORTANT: Get actual values using the same indices as the model
y_actual = df_model.loc[y.index, 'callout_count'].values

# Initialize lists to store results
models_list = []
predictions_list = []
metrics_dict = {}

# Poisson predictions
poisson_pred = poisson_results.predict()
poisson_mse, poisson_mape, poisson_rmse, poisson_mae = calculate_metrics(y_actual, poisson_pred)
models_list.append('Poisson')
predictions_list.append(poisson_pred)
metrics_dict['Poisson'] = (poisson_mse, poisson_mape, poisson_rmse, poisson_mae)

# Generalized Poisson predictions
if gp_fitted:
    gp_pred = gp_results.predict()
    gp_mse, gp_mape, gp_rmse, gp_mae = calculate_metrics(y_actual, gp_pred)
    models_list.append('Generalized Poisson')
    predictions_list.append(gp_pred)
    metrics_dict['Generalized Poisson'] = (gp_mse, gp_mape, gp_rmse, gp_mae)

# Negative Binomial predictions
if nb_fitted:
    nb_pred = nb_results.predict()
    nb_mse, nb_mape, nb_rmse, nb_mae = calculate_metrics(y_actual, nb_pred)
    models_list.append('Negative Binomial')
    predictions_list.append(nb_pred)
    metrics_dict['Negative Binomial'] = (nb_mse, nb_mape, nb_rmse, nb_mae)

# Print comparison
print("\n" + "="*60)
print("MODEL COMPARISON - PREDICTION METRICS")
print("="*60)
for model_name, (mse, mape, rmse, mae) in metrics_dict.items():
    print(f"\n{model_name} Model:")
    print(f"  MSE: {mse:.4f}, RMSE: {rmse:.4f}")
    print(f"  MAE: {mae:.4f}, MAPE: {mape:.2f}%")

# Check if predictions are different
print("\n" + "="*60)
print("CHECKING PREDICTION DIFFERENCES")
print("="*60)

if len(predictions_list) > 1:
    for i in range(len(predictions_list)-1):
        for j in range(i+1, len(predictions_list)):
            diff = np.mean(np.abs(predictions_list[i] - predictions_list[j]))
            max_diff = np.max(np.abs(predictions_list[i] - predictions_list[j]))
            print(f"\n{models_list[i]} vs {models_list[j]}:")
            print(f"  Mean absolute difference: {diff:.6f}")
            print(f"  Max absolute difference: {max_diff:.6f}")

### 6. Visualization Suite
# Create a figure with multiple subplots
n_models = len(models_list)
fig = plt.figure(figsize=(18, 12))

# Define colors for consistency
colors = ['steelblue', 'seagreen', 'coral'][:n_models]

# 1. Metrics Comparison Bar Plot - MSE and RMSE
ax1 = plt.subplot(2, 3, 1)
x = np.arange(len(models_list))
width = 0.35

mse_values = [metrics_dict[m][0] for m in models_list]
rmse_values = [metrics_dict[m][2] for m in models_list]

bars1 = ax1.bar(x - width/2, mse_values, width, label='MSE', color='steelblue', alpha=0.8)
bars2 = ax1.bar(x + width/2, rmse_values, width, label='RMSE', color='darkblue', alpha=0.8)

ax1.set_ylabel('Error', fontsize=12)
ax1.set_title('MSE & RMSE Comparison (lower is better)', fontsize=14)
ax1.set_xticks(x)
ax1.set_xticklabels(models_list, rotation=15, ha='right')
ax1.legend()

# Add value labels on bars
for bars in [bars1, bars2]:
    for bar in bars:
        height = bar.get_height()
        ax1.text(bar.get_x() + bar.get_width()/2., height,
                 f'{height:.3f}', ha='center', va='bottom', fontsize=9)

# 2. MAPE and MAE Comparison
ax2 = plt.subplot(2, 3, 2)
mape_values = [metrics_dict[m][1] for m in models_list]
mae_values = [metrics_dict[m][3] for m in models_list]

bars3 = ax2.bar(x - width/2, mape_values, width, label='MAPE (%)', color='coral', alpha=0.8)
bars4 = ax2.bar(x + width/2, mae_values, width, label='MAE', color='orangered', alpha=0.8)

ax2.set_ylabel('Error', fontsize=12)
ax2.set_title('MAPE & MAE Comparison (lower is better)', fontsize=14)
ax2.set_xticks(x)
ax2.set_xticklabels(models_list, rotation=15, ha='right')
ax2.legend()

# Add value labels
for bar in bars3:
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.1f}%', ha='center', va='bottom', fontsize=9)
for bar in bars4:
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.3f}', ha='center', va='bottom', fontsize=9)

# 3. Combined Metrics Heatmap
ax3 = plt.subplot(2, 3, 3)
metrics_data = np.array([[metrics_dict[m][0], metrics_dict[m][2], metrics_dict[m][3], metrics_dict[m][1]] 
                         for m in models_list])

# Normalize each metric to 0-1 scale for visualization
metrics_normalized = metrics_data.copy()
for i in range(metrics_data.shape[1]):
    col = metrics_data[:, i]
    if col.max() != col.min():
        metrics_normalized[:, i] = (col - col.min()) / (col.max() - col.min())
    else:
        metrics_normalized[:, i] = 0

sns.heatmap(metrics_normalized, 
            xticklabels=['MSE', 'RMSE', 'MAE', 'MAPE'],
            yticklabels=models_list,
            annot=metrics_data, fmt='.3f', cmap='RdYlGn_r', ax=ax3,
            cbar_kws={'label': 'Normalized Score'})
ax3.set_title('Normalized Metrics Heatmap\n(darker = worse performance)', fontsize=14)

# 4-6. Actual vs Predicted Scatter Plots
for idx, (pred, model_name, color) in enumerate(zip(predictions_list[:3], models_list[:3], colors)):
    ax = plt.subplot(2, 3, 4 + idx)
    ax.scatter(y_actual, pred, alpha=0.5, s=30, color=color)
    
    # Add perfect prediction line
    max_val = max(y_actual.max(), pred.max())
    ax.plot([0, max_val], [0, max_val], 'r--', lw=2, label='Perfect Prediction')
    
    # Add correlation coefficient
    corr = np.corrcoef(y_actual, pred)[0, 1]
    ax.text(0.05, 0.95, f'Correlation: {corr:.3f}', 
            transform=ax.transAxes, verticalalignment='top',
            bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    ax.set_xlabel('Actual Count', fontsize=11)
    ax.set_ylabel('Predicted Count', fontsize=11)
    ax.set_title(f'{model_name}: Actual vs Predicted', fontsize=12)
    ax.legend()
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Additional diagnostic plots
fig2, axes = plt.subplots(2, 3, figsize=(18, 10))

# 1-3. Residual Plots
for idx, (pred, model_name, color) in enumerate(zip(predictions_list[:3], models_list[:3], colors)):
    if idx < len(axes[0]):
        ax = axes[0, idx]
        residuals = y_actual - pred
        
        ax.scatter(pred, residuals, alpha=0.5, s=30, color=color)
        ax.axhline(y=0, color='r', linestyle='--', lw=2)
        
        # Add residual statistics
        res_std = np.std(residuals)
        ax.axhline(y=2*res_std, color='orange', linestyle=':', alpha=0.7, label='±2 SD')
        ax.axhline(y=-2*res_std, color='orange', linestyle=':', alpha=0.7)
        
        ax.set_xlabel('Predicted Count', fontsize=11)
        ax.set_ylabel('Residuals', fontsize=11)
        ax.set_title(f'{model_name}: Residual Plot', fontsize=12)
        ax.legend()
        ax.grid(True, alpha=0.3)

# 4. Q-Q plot for residuals
ax = axes[1, 0]
for idx, (pred, model_name, color) in enumerate(zip(predictions_list, models_list, colors)):
    residuals = y_actual - pred
    stats.probplot(residuals, dist="norm", plot=None)
    theoretical_quantiles = stats.norm.ppf(np.linspace(0.01, 0.99, len(residuals)))
    theoretical_quantiles.sort()
    residuals_sorted = np.sort(residuals)
    ax.plot(theoretical_quantiles, residuals_sorted, 'o', alpha=0.6, label=model_name, 
            color=color, markersize=4)

ax.plot([-3, 3], [-3*np.std(y_actual), 3*np.std(y_actual)], 'k--', lw=2, label='Reference line')
ax.set_xlabel('Theoretical Quantiles')
ax.set_ylabel('Sample Quantiles')
ax.set_title('Q-Q Plot: Residual Normality Check')
ax.legend()
ax.grid(True, alpha=0.3)

# 5. Distribution of predictions
ax = axes[1, 1]
ax.hist(y_actual, bins=30, alpha=0.7, label='Actual', color='black', density=True)
for idx, (pred, model_name, color) in enumerate(zip(predictions_list, models_list, colors)):
    ax.hist(pred, bins=30, alpha=0.5, label=model_name, color=color, density=True)
ax.set_xlabel('Count')
ax.set_ylabel('Density')
ax.set_title('Distribution of Actual vs Predicted Counts')
ax.legend()

# 6. Model performance by prediction magnitude
ax = axes[1, 2]
n_bins = 10
for idx, (pred, model_name, color) in enumerate(zip(predictions_list, models_list, colors)):
    # Create bins based on actual values
    bin_edges = np.percentile(y_actual[y_actual > 0], np.linspace(0, 100, n_bins + 1))
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    mape_by_bin = []
    for i in range(n_bins):
        mask = (y_actual >= bin_edges[i]) & (y_actual < bin_edges[i+1]) & (y_actual > 0)
        if np.sum(mask) > 0:
            bin_mape = np.mean(np.abs((y_actual[mask] - pred[mask]) / y_actual[mask])) * 100
            mape_by_bin.append(bin_mape)
        else:
            mape_by_bin.append(np.nan)
    
    ax.plot(bin_centers, mape_by_bin, 'o-', label=model_name, color=color, 
            linewidth=2, markersize=8)

ax.set_xlabel('Actual Count (bin center)')
ax.set_ylabel('MAPE (%)')
ax.set_title('MAPE by Actual Count Magnitude')
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Summary statistics table
print("\n" + "="*60)
print("DETAILED MODEL DIAGNOSTICS")
print("="*60)

for pred, model_name in zip(predictions_list, models_list):
    residuals = y_actual - pred
    print(f"\n{model_name} Model:")
    print(f"  Mean Residual: {np.mean(residuals):.4f}")
    print(f"  Std Dev of Residuals: {np.std(residuals):.4f}")
    print(f"  Min/Max Residual: {np.min(residuals):.4f} / {np.max(residuals):.4f}")
    print(f"  % Predictions within ±1 of actual: {np.mean(np.abs(residuals) <= 1)*100:.1f}%")
    print(f"  % Predictions within ±2 of actual: {np.mean(np.abs(residuals) <= 2)*100:.1f}%")
    
# Dispersion analysis
print("\n" + "="*60)
print("DISPERSION ANALYSIS")
print("="*60)
print(f"Poisson model dispersion parameter: {dispersion:.4f}")

if dispersion < 0.8:
    print("Strong evidence of underdispersion - Generalized Poisson should perform better than standard Poisson")
elif dispersion < 1.0:
    print("Moderate underdispersion detected - Generalized Poisson may improve model fit")
elif dispersion > 1.2:
    print("Overdispersion detected - Negative Binomial might be appropriate")
else:
    print("Little evidence of over/underdispersion - Poisson model may be adequate")

# Model selection recommendation
print("\n" + "="*60)
print("MODEL SELECTION RECOMMENDATION")
print("="*60)

best_model = min(metrics_dict.items(), key=lambda x: x[1][0])[0]  # Based on MSE
print(f"\nBased on MSE, the best model is: {best_model}")

best_model_mape = min(metrics_dict.items(), key=lambda x: x[1][1])[0]  # Based on MAPE
print(f"Based on MAPE, the best model is: {best_model_mape}")

if gp_fitted:
    # Extract dispersion parameter from Generalized Poisson
    try:
        gp_alpha = gp_results.params[-1]  # Last parameter is usually dispersion
        print(f"\nGeneralized Poisson dispersion parameter (alpha): {gp_alpha:.4f}")
        if gp_alpha < 0:
            print("Negative alpha confirms underdispersion in the data")
        elif gp_alpha > 0:
            print("Positive alpha indicates overdispersion")
        else:
            print("Alpha ≈ 0 indicates equidispersion (similar to Poisson)")
    except:
        pass
# Out:
# ============================================================
# FITTING POISSON MODEL (BASELINE)
# ============================================================
#
# Poisson Dispersion parameter: 0.5085
#
# Poisson Model Summary:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:          callout_count   No. Observations:                63298
# Model:                            GLM   Df Residuals:                    63190
# Model Family:                 Poisson   Df Model:                          107
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -94165.
# Date:                Sun, 06 Jul 2025   Deviance:                       32134.
# Time:                        16:55:22   Pearson chi2:                 3.52e+04
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2518
# Covariance Type:            nonrobust
# ====================================================================================================================================================================
#                                                                                                        coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                          -11.7708      0.050   -236.630      0.000     -11.868     -11.673
# C(year)[T.2017]                                                                                      0.0649      0.035      1.876      0.061      -0.003       0.133
# C(year)[T.2018]                                                                                      0.0895      0.034      2.645      0.008       0.023       0.156
# C(year)[T.2019]                                                                                      0.1205      0.033      3.623      0.000       0.055       0.186
# C(year)[T.2020]                                                                                      0.1141      0.033      3.445      0.001       0.049       0.179
# C(year)[T.2021]                                                                                      0.0815      0.033      2.464      0.014       0.017       0.146
# C(year)[T.2022]                                                                                      0.1637      0.032      5.102      0.000       0.101       0.227
# C(year)[T.2023]                                                                                      0.2193      0.031      6.967      0.000       0.158       0.281
# C(month)[T.2]                                                                                        0.0007      0.014      0.046      0.964      -0.027       0.029
# C(month)[T.3]                                                                                       -0.0065      0.014     -0.459      0.646      -0.034       0.021
# C(month)[T.4]                                                                                       -0.0066      0.014     -0.457      0.648      -0.035       0.022
# C(month)[T.5]                                                                                        0.0198      0.014      1.394      0.163      -0.008       0.048
# C(month)[T.6]                                                                                        0.0450      0.014      3.190      0.001       0.017       0.073
# C(month)[T.7]                                                                                        0.0540      0.014      3.867      0.000       0.027       0.081
# C(month)[T.8]                                                                                        0.0691      0.014      4.990      0.000       0.042       0.096
# C(month)[T.9]                                                                                        0.0570      0.014      4.089      0.000       0.030       0.084
# C(month)[T.10]                                                                                       0.0376      0.014      2.701      0.007       0.010       0.065
# C(month)[T.11]                                                                                       0.0391      0.014      2.794      0.005       0.012       0.066
# C(month)[T.12]                                                                                       0.1229      0.013      9.252      0.000       0.097       0.149
# C(region)[T.HSE Dublin and North East]                                                              -0.1399      0.042     -3.347      0.001      -0.222      -0.058
# C(region)[T.HSE Dublin and South East]                                                               0.0758      0.040      1.900      0.057      -0.002       0.154
# C(region)[T.HSE Mid West]                                                                            0.6115      0.050     12.124      0.000       0.513       0.710
# C(region)[T.HSE South West]                                                                          0.4422      0.038     11.671      0.000       0.368       0.516
# C(region)[T.HSE West and North West]                                                                 0.3508      0.038      9.118      0.000       0.275       0.426
# C(fall_category_group)[T.17A03_injuries_excluding_distal]                                           -0.3779      0.080     -4.701      0.000      -0.536      -0.220
# C(fall_category_group)[T.17A04_public_assistance]                                                   -0.3582      0.083     -4.331      0.000      -0.520      -0.196
# C(fall_category_group)[T.17B00_bravo_override]                                                       0.0256      0.059      0.435      0.664      -0.090       0.141
# C(fall_category_group)[T.17B01_possibly_dangerous]                                                   0.4013      0.051      7.899      0.000       0.302       0.501
# C(fall_category_group)[T.17D04_not_alert]                                                           -0.0330      0.061     -0.544      0.586      -0.152       0.086
# warning_severity[T.Red]:C(fall_category_group)[17A02_not_dangerous_proximal]                        -0.1502      0.136     -1.106      0.269      -0.416       0.116
# warning_severity[T.Yellow]:C(fall_category_group)[17A02_not_dangerous_proximal]                     -0.0267      0.042     -0.640      0.522      -0.108       0.055
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17A02_not_dangerous_proximal]         0.0054      0.039      0.139      0.890      -0.072       0.082
# warning_severity[T.Red]:C(fall_category_group)[17A03_injuries_excluding_distal]                      0.0426      0.223      0.191      0.848      -0.394       0.479
# warning_severity[T.Yellow]:C(fall_category_group)[17A03_injuries_excluding_distal]                   0.0258      0.069      0.375      0.708      -0.109       0.160
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17A03_injuries_excluding_distal]      0.0375      0.065      0.579      0.563      -0.090       0.165
# warning_severity[T.Red]:C(fall_category_group)[17A04_public_assistance]                              0.1741      0.219      0.795      0.427      -0.255       0.604
# warning_severity[T.Yellow]:C(fall_category_group)[17A04_public_assistance]                           0.0374      0.072      0.518      0.604      -0.104       0.179
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17A04_public_assistance]              0.0502      0.068      0.735      0.462      -0.083       0.184
# warning_severity[T.Red]:C(fall_category_group)[17B00_bravo_override]                                -0.0313      0.115     -0.271      0.786      -0.258       0.195
# warning_severity[T.Yellow]:C(fall_category_group)[17B00_bravo_override]                             -0.0772      0.041     -1.895      0.058      -0.157       0.003
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17B00_bravo_override]                -0.1175      0.038     -3.061      0.002      -0.193      -0.042
# warning_severity[T.Red]:C(fall_category_group)[17B01_possibly_dangerous]                            -0.2392      0.101     -2.375      0.018      -0.437      -0.042
# warning_severity[T.Yellow]:C(fall_category_group)[17B01_possibly_dangerous]                          0.0107      0.029      0.375      0.708      -0.045       0.067
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17B01_possibly_dangerous]            -0.0021      0.027     -0.078      0.938      -0.055       0.051
# warning_severity[T.Red]:C(fall_category_group)[17D04_not_alert]                                     -0.0289      0.134     -0.215      0.830      -0.292       0.234
# warning_severity[T.Yellow]:C(fall_category_group)[17D04_not_alert]                                   0.0012      0.044      0.028      0.978      -0.085       0.087
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17D04_not_alert]                     -0.0234      0.041     -0.564      0.573      -0.105       0.058
# C(region)[T.HSE Dublin and North East]:C(fall_category_group)[T.17A03_injuries_excluding_distal]     0.0032      0.047      0.068      0.946      -0.088       0.094
# C(region)[T.HSE Dublin and South East]:C(fall_category_group)[T.17A03_injuries_excluding_distal]    -0.0594      0.048     -1.244      0.214      -0.153       0.034
# C(region)[T.HSE Mid West]:C(fall_category_group)[T.17A03_injuries_excluding_distal]                  0.1082      0.057      1.899      0.058      -0.003       0.220
# C(region)[T.HSE South West]:C(fall_category_group)[T.17A03_injuries_excluding_distal]               -0.2141      0.043     -4.963      0.000      -0.299      -0.130
# C(region)[T.HSE West and North West]:C(fall_category_group)[T.17A03_injuries_excluding_distal]      -0.1723      0.043     -4.017      0.000      -0.256      -0.088
# C(region)[T.HSE Dublin and North East]:C(fall_category_group)[T.17A04_public_assistance]            -0.0340      0.046     -0.731      0.465      -0.125       0.057
# C(region)[T.HSE Dublin and South East]:C(fall_category_group)[T.17A04_public_assistance]            -0.0101      0.044     -0.231      0.817      -0.095       0.075
# C(region)[T.HSE Mid West]:C(fall_category_group)[T.17A04_public_assistance]                          0.0614      0.060      1.019      0.308      -0.057       0.179
# C(region)[T.HSE South West]:C(fall_category_group)[T.17A04_public_assistance]                       -0.3409      0.046     -7.379      0.000      -0.431      -0.250
# C(region)[T.HSE West and North West]:C(fall_category_group)[T.17A04_public_assistance]              -0.2435      0.043     -5.659      0.000      -0.328      -0.159
# C(region)[T.HSE Dublin and North East]:C(fall_category_group)[T.17B00_bravo_override]                0.0228      0.036      0.642      0.521      -0.047       0.093
# C(region)[T.HSE Dublin and South East]:C(fall_category_group)[T.17B00_bravo_override]               -0.0116      0.035     -0.332      0.740      -0.080       0.057
# C(region)[T.HSE Mid West]:C(fall_category_group)[T.17B00_bravo_override]                             0.0344      0.042      0.821      0.411      -0.048       0.116
# C(region)[T.HSE South West]:C(fall_category_group)[T.17B00_bravo_override]                           0.0724      0.032      2.286      0.022       0.010       0.135
# C(region)[T.HSE West and North West]:C(fall_category_group)[T.17B00_bravo_override]                 -0.1300      0.033     -3.938      0.000      -0.195      -0.065
# C(region)[T.HSE Dublin and North East]:C(fall_category_group)[T.17B01_possibly_dangerous]            0.0810      0.029      2.766      0.006       0.024       0.138
# C(region)[T.HSE Dublin and South East]:C(fall_category_group)[T.17B01_possibly_dangerous]            0.1600      0.029      5.573      0.000       0.104       0.216
# C(region)[T.HSE Mid West]:C(fall_category_group)[T.17B01_possibly_dangerous]                        -0.2061      0.035     -5.825      0.000      -0.275      -0.137
# C(region)[T.HSE South West]:C(fall_category_group)[T.17B01_possibly_dangerous]                       0.0386      0.027      1.439      0.150      -0.014       0.091
# C(region)[T.HSE West and North West]:C(fall_category_group)[T.17B01_possibly_dangerous]              0.0055      0.027      0.202      0.840      -0.048       0.058
# C(region)[T.HSE Dublin and North East]:C(fall_category_group)[T.17D04_not_alert]                    -0.0190      0.035     -0.540      0.589      -0.088       0.050
# C(region)[T.HSE Dublin and South East]:C(fall_category_group)[T.17D04_not_alert]                     0.0205      0.034      0.596      0.551      -0.047       0.088
# C(region)[T.HSE Mid West]:C(fall_category_group)[T.17D04_not_alert]                                 -0.0080      0.042     -0.192      0.848      -0.090       0.074
# C(region)[T.HSE South West]:C(fall_category_group)[T.17D04_not_alert]                               -0.0539      0.032     -1.697      0.090      -0.116       0.008
# C(region)[T.HSE West and North West]:C(fall_category_group)[T.17D04_not_alert]                      -0.1755      0.033     -5.359      0.000      -0.240      -0.111
# C(year)[T.2017]:C(region)[T.HSE Dublin and North East]                                              -0.0208      0.048     -0.429      0.668      -0.116       0.074
# C(year)[T.2018]:C(region)[T.HSE Dublin and North East]                                              -0.0004      0.047     -0.008      0.994      -0.093       0.092
# C(year)[T.2019]:C(region)[T.HSE Dublin and North East]                                               0.0002      0.046      0.005      0.996      -0.091       0.091
# C(year)[T.2020]:C(region)[T.HSE Dublin and North East]                                              -0.0048      0.046     -0.103      0.918      -0.095       0.086
# C(year)[T.2021]:C(region)[T.HSE Dublin and North East]                                               0.0454      0.046      0.992      0.321      -0.044       0.135
# C(year)[T.2022]:C(region)[T.HSE Dublin and North East]                                               0.0416      0.044      0.936      0.349      -0.046       0.129
# C(year)[T.2023]:C(region)[T.HSE Dublin and North East]                                               0.0054      0.044      0.124      0.901      -0.080       0.091
# C(year)[T.2017]:C(region)[T.HSE Dublin and South East]                                              -0.0494      0.046     -1.075      0.282      -0.140       0.041
# C(year)[T.2018]:C(region)[T.HSE Dublin and South East]                                               0.0214      0.045      0.481      0.631      -0.066       0.109
# C(year)[T.2019]:C(region)[T.HSE Dublin and South East]                                               0.0056      0.044      0.129      0.898      -0.080       0.092
# C(year)[T.2020]:C(region)[T.HSE Dublin and South East]                                              -0.0365      0.044     -0.831      0.406      -0.123       0.050
# C(year)[T.2021]:C(region)[T.HSE Dublin and South East]                                               0.0195      0.044      0.445      0.656      -0.066       0.105
# C(year)[T.2022]:C(region)[T.HSE Dublin and South East]                                               0.0010      0.043      0.023      0.982      -0.082       0.084
# C(year)[T.2023]:C(region)[T.HSE Dublin and South East]                                              -0.0533      0.042     -1.267      0.205      -0.136       0.029
# C(year)[T.2017]:C(region)[T.HSE Mid West]                                                           -0.0528      0.059     -0.901      0.368      -0.168       0.062
# C(year)[T.2018]:C(region)[T.HSE Mid West]                                                           -0.0359      0.057     -0.630      0.529      -0.147       0.076
# C(year)[T.2019]:C(region)[T.HSE Mid West]                                                           -0.0941      0.057     -1.656      0.098      -0.206       0.017
# C(year)[T.2020]:C(region)[T.HSE Mid West]                                                           -0.0676      0.056     -1.208      0.227      -0.177       0.042
# C(year)[T.2021]:C(region)[T.HSE Mid West]                                                           -0.0149      0.055     -0.271      0.786      -0.123       0.093
# C(year)[T.2022]:C(region)[T.HSE Mid West]                                                           -0.0382      0.054     -0.712      0.477      -0.143       0.067
# C(year)[T.2023]:C(region)[T.HSE Mid West]                                                           -0.1291      0.053     -2.416      0.016      -0.234      -0.024
# C(year)[T.2017]:C(region)[T.HSE South West]                                                         -0.0358      0.044     -0.815      0.415      -0.122       0.050
# C(year)[T.2018]:C(region)[T.HSE South West]                                                          0.0170      0.043      0.397      0.691      -0.067       0.101
# C(year)[T.2019]:C(region)[T.HSE South West]                                                          0.0400      0.042      0.951      0.342      -0.042       0.122
# C(year)[T.2020]:C(region)[T.HSE South West]                                                          0.0147      0.042      0.349      0.727      -0.068       0.097
# C(year)[T.2021]:C(region)[T.HSE South West]                                                          0.0872      0.042      2.091      0.037       0.005       0.169
# C(year)[T.2022]:C(region)[T.HSE South West]                                                          0.0821      0.041      2.024      0.043       0.003       0.161
# C(year)[T.2023]:C(region)[T.HSE South West]                                                          0.0926      0.040      2.330      0.020       0.015       0.170
# C(year)[T.2017]:C(region)[T.HSE West and North West]                                                -0.0057      0.045     -0.128      0.898      -0.093       0.082
# C(year)[T.2018]:C(region)[T.HSE West and North West]                                                 0.0087      0.044      0.199      0.843      -0.077       0.095
# C(year)[T.2019]:C(region)[T.HSE West and North West]                                                 0.0560      0.043      1.300      0.193      -0.028       0.140
# C(year)[T.2020]:C(region)[T.HSE West and North West]                                                 0.0332      0.043      0.775      0.438      -0.051       0.117
# C(year)[T.2021]:C(region)[T.HSE West and North West]                                                 0.0857      0.043      2.012      0.044       0.002       0.169
# C(year)[T.2022]:C(region)[T.HSE West and North West]                                                 0.0936      0.041      2.266      0.023       0.013       0.175
# C(year)[T.2023]:C(region)[T.HSE West and North West]                                                 0.0552      0.041      1.353      0.176      -0.025       0.135
# callout_count_lag30                                                                                  0.0023      0.002      1.126      0.260      -0.002       0.006
# ====================================================================================================================================================================
#
# ============================================================
# FITTING GENERALIZED POISSON MODEL (FOR UNDERDISPERSION)
# ============================================================
#
# Generalized Poisson Model Summary:
#                     GeneralizedPoisson Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                63298
# Model:             GeneralizedPoisson   Df Residuals:                    63190
# Method:                           MLE   Df Model:                          107
# Date:                Sun, 06 Jul 2025   Pseudo R-squ.:                  0.1237
# Time:                        16:55:31   Log-Likelihood:                -90501.
# converged:                       True   LL-Null:                   -1.0328e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ====================================================================================================================================================================
#                                                                                                        coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                          -11.8050      0.039   -304.623      0.000     -11.881     -11.729
# C(year)[T.2017]                                                                                      0.0965      0.027      3.610      0.000       0.044       0.149
# C(year)[T.2018]                                                                                      0.1095      0.027      4.064      0.000       0.057       0.162
# C(year)[T.2019]                                                                                      0.1442      0.026      5.445      0.000       0.092       0.196
# C(year)[T.2020]                                                                                      0.1358      0.026      5.138      0.000       0.084       0.188
# C(year)[T.2021]                                                                                      0.1176      0.026      4.520      0.000       0.067       0.169
# C(year)[T.2022]                                                                                      0.1957      0.026      7.643      0.000       0.146       0.246
# C(year)[T.2023]                                                                                      0.2649      0.025     10.591      0.000       0.216       0.314
# C(month)[T.2]                                                                                       -0.0023      0.011     -0.205      0.838      -0.024       0.020
# C(month)[T.3]                                                                                       -0.0089      0.011     -0.800      0.424      -0.031       0.013
# C(month)[T.4]                                                                                       -0.0011      0.011     -0.095      0.924      -0.023       0.021
# C(month)[T.5]                                                                                        0.0264      0.011      2.402      0.016       0.005       0.048
# C(month)[T.6]                                                                                        0.0429      0.011      3.887      0.000       0.021       0.064
# C(month)[T.7]                                                                                        0.0579      0.011      5.320      0.000       0.037       0.079
# C(month)[T.8]                                                                                        0.0746      0.011      6.916      0.000       0.053       0.096
# C(month)[T.9]                                                                                        0.0621      0.011      5.710      0.000       0.041       0.083
# C(month)[T.10]                                                                                       0.0410      0.011      3.779      0.000       0.020       0.062
# C(month)[T.11]                                                                                       0.0436      0.011      3.998      0.000       0.022       0.065
# C(month)[T.12]                                                                                       0.1396      0.010     13.560      0.000       0.119       0.160
# C(region)[T.HSE Dublin and North East]                                                              -0.1458      0.033     -4.434      0.000      -0.210      -0.081
# C(region)[T.HSE Dublin and South East]                                                               0.1017      0.031      3.289      0.001       0.041       0.162
# C(region)[T.HSE Mid West]                                                                            0.5598      0.041     13.653      0.000       0.479       0.640
# C(region)[T.HSE South West]                                                                          0.4830      0.029     16.378      0.000       0.425       0.541
# C(region)[T.HSE West and North West]                                                                 0.3920      0.030     13.146      0.000       0.334       0.450
# C(fall_category_group)[T.17A03_injuries_excluding_distal]                                           -0.4548      0.064     -7.052      0.000      -0.581      -0.328
# C(fall_category_group)[T.17A04_public_assistance]                                                   -0.4397      0.069     -6.388      0.000      -0.575      -0.305
# C(fall_category_group)[T.17B00_bravo_override]                                                       0.0109      0.046      0.240      0.811      -0.078       0.100
# C(fall_category_group)[T.17B01_possibly_dangerous]                                                   0.4321      0.039     11.047      0.000       0.355       0.509
# C(fall_category_group)[T.17D04_not_alert]                                                           -0.0641      0.048     -1.346      0.178      -0.157       0.029
# warning_severity[T.Red]:C(fall_category_group)[17A02_not_dangerous_proximal]                        -0.1879      0.110     -1.714      0.086      -0.403       0.027
# warning_severity[T.Yellow]:C(fall_category_group)[17A02_not_dangerous_proximal]                     -0.0279      0.032     -0.864      0.387      -0.091       0.035
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17A02_not_dangerous_proximal]         0.0139      0.030      0.458      0.647      -0.046       0.073
# warning_severity[T.Red]:C(fall_category_group)[17A03_injuries_excluding_distal]                      0.0301      0.187      0.161      0.872      -0.337       0.397
# warning_severity[T.Yellow]:C(fall_category_group)[17A03_injuries_excluding_distal]                   0.0280      0.055      0.505      0.613      -0.081       0.137
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17A03_injuries_excluding_distal]      0.0193      0.052      0.370      0.712      -0.083       0.122
# warning_severity[T.Red]:C(fall_category_group)[17A04_public_assistance]                              0.1951      0.184      1.060      0.289      -0.166       0.556
# warning_severity[T.Yellow]:C(fall_category_group)[17A04_public_assistance]                           0.0533      0.061      0.868      0.385      -0.067       0.174
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17A04_public_assistance]              0.0644      0.058      1.106      0.269      -0.050       0.178
# warning_severity[T.Red]:C(fall_category_group)[17B00_bravo_override]                                -0.0094      0.087     -0.108      0.914      -0.179       0.160
# warning_severity[T.Yellow]:C(fall_category_group)[17B00_bravo_override]                             -0.0741      0.031     -2.373      0.018      -0.135      -0.013
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17B00_bravo_override]                -0.1290      0.030     -4.366      0.000      -0.187      -0.071
# warning_severity[T.Red]:C(fall_category_group)[17B01_possibly_dangerous]                            -0.2705      0.080     -3.400      0.001      -0.426      -0.115
# warning_severity[T.Yellow]:C(fall_category_group)[17B01_possibly_dangerous]                          0.0006      0.022      0.025      0.980      -0.042       0.044
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17B01_possibly_dangerous]            -0.0065      0.021     -0.315      0.753      -0.047       0.034
# warning_severity[T.Red]:C(fall_category_group)[17D04_not_alert]                                     -0.0356      0.107     -0.332      0.740      -0.246       0.175
# warning_severity[T.Yellow]:C(fall_category_group)[17D04_not_alert]                                   0.0085      0.035      0.245      0.806      -0.060       0.077
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17D04_not_alert]                     -0.0107      0.033     -0.325      0.745      -0.075       0.054
# C(region)[T.HSE Dublin and North East]:C(fall_category_group)[T.17A03_injuries_excluding_distal]     0.0269      0.038      0.700      0.484      -0.048       0.102
# C(region)[T.HSE Dublin and South East]:C(fall_category_group)[T.17A03_injuries_excluding_distal]    -0.0658      0.040     -1.665      0.096      -0.143       0.012
# C(region)[T.HSE Mid West]:C(fall_category_group)[T.17A03_injuries_excluding_distal]                  0.1184      0.048      2.466      0.014       0.024       0.213
# C(region)[T.HSE South West]:C(fall_category_group)[T.17A03_injuries_excluding_distal]               -0.2114      0.035     -6.004      0.000      -0.280      -0.142
# C(region)[T.HSE West and North West]:C(fall_category_group)[T.17A03_injuries_excluding_distal]      -0.1569      0.035     -4.499      0.000      -0.225      -0.089
# C(region)[T.HSE Dublin and North East]:C(fall_category_group)[T.17A04_public_assistance]            -0.0419      0.038     -1.101      0.271      -0.116       0.033
# C(region)[T.HSE Dublin and South East]:C(fall_category_group)[T.17A04_public_assistance]            -0.0152      0.035     -0.434      0.665      -0.084       0.054
# C(region)[T.HSE Mid West]:C(fall_category_group)[T.17A04_public_assistance]                          0.0296      0.052      0.568      0.570      -0.072       0.132
# C(region)[T.HSE South West]:C(fall_category_group)[T.17A04_public_assistance]                       -0.3847      0.038    -10.226      0.000      -0.458      -0.311
# C(region)[T.HSE West and North West]:C(fall_category_group)[T.17A04_public_assistance]              -0.2759      0.035     -7.898      0.000      -0.344      -0.207
# C(region)[T.HSE Dublin and North East]:C(fall_category_group)[T.17B00_bravo_override]                0.0501      0.028      1.811      0.070      -0.004       0.104
# C(region)[T.HSE Dublin and South East]:C(fall_category_group)[T.17B00_bravo_override]                0.0010      0.027      0.036      0.971      -0.052       0.054
# C(region)[T.HSE Mid West]:C(fall_category_group)[T.17B00_bravo_override]                             0.0382      0.034      1.134      0.257      -0.028       0.104
# C(region)[T.HSE South West]:C(fall_category_group)[T.17B00_bravo_override]                           0.0939      0.024      3.847      0.000       0.046       0.142
# C(region)[T.HSE West and North West]:C(fall_category_group)[T.17B00_bravo_override]                 -0.1181      0.025     -4.645      0.000      -0.168      -0.068
# C(region)[T.HSE Dublin and North East]:C(fall_category_group)[T.17B01_possibly_dangerous]            0.0903      0.022      4.015      0.000       0.046       0.134
# C(region)[T.HSE Dublin and South East]:C(fall_category_group)[T.17B01_possibly_dangerous]            0.1514      0.022      6.917      0.000       0.108       0.194
# C(region)[T.HSE Mid West]:C(fall_category_group)[T.17B01_possibly_dangerous]                        -0.1812      0.028     -6.569      0.000      -0.235      -0.127
# C(region)[T.HSE South West]:C(fall_category_group)[T.17B01_possibly_dangerous]                       0.0116      0.020      0.572      0.568      -0.028       0.051
# C(region)[T.HSE West and North West]:C(fall_category_group)[T.17B01_possibly_dangerous]             -0.0222      0.021     -1.079      0.281      -0.062       0.018
# C(region)[T.HSE Dublin and North East]:C(fall_category_group)[T.17D04_not_alert]                    -0.0059      0.028     -0.214      0.830      -0.060       0.048
# C(region)[T.HSE Dublin and South East]:C(fall_category_group)[T.17D04_not_alert]                     0.0328      0.027      1.232      0.218      -0.019       0.085
# C(region)[T.HSE Mid West]:C(fall_category_group)[T.17D04_not_alert]                                  0.0010      0.033      0.031      0.975      -0.064       0.066
# C(region)[T.HSE South West]:C(fall_category_group)[T.17D04_not_alert]                               -0.0495      0.025     -2.019      0.043      -0.097      -0.001
# C(region)[T.HSE West and North West]:C(fall_category_group)[T.17D04_not_alert]                      -0.1742      0.025     -6.901      0.000      -0.224      -0.125
# C(year)[T.2017]:C(region)[T.HSE Dublin and North East]                                              -0.0466      0.038     -1.228      0.220      -0.121       0.028
# C(year)[T.2018]:C(region)[T.HSE Dublin and North East]                                              -0.0021      0.037     -0.055      0.956      -0.075       0.071
# C(year)[T.2019]:C(region)[T.HSE Dublin and North East]                                              -0.0011      0.037     -0.030      0.976      -0.073       0.071
# C(year)[T.2020]:C(region)[T.HSE Dublin and North East]                                              -0.0081      0.037     -0.222      0.825      -0.080       0.064
# C(year)[T.2021]:C(region)[T.HSE Dublin and North East]                                               0.0306      0.036      0.844      0.398      -0.040       0.102
# C(year)[T.2022]:C(region)[T.HSE Dublin and North East]                                               0.0388      0.035      1.096      0.273      -0.031       0.108
# C(year)[T.2023]:C(region)[T.HSE Dublin and North East]                                               0.0059      0.035      0.169      0.866      -0.062       0.074
# C(year)[T.2017]:C(region)[T.HSE Dublin and South East]                                              -0.0944      0.036     -2.635      0.008      -0.165      -0.024
# C(year)[T.2018]:C(region)[T.HSE Dublin and South East]                                               0.0121      0.035      0.345      0.730      -0.057       0.081
# C(year)[T.2019]:C(region)[T.HSE Dublin and South East]                                              -0.0064      0.035     -0.184      0.854      -0.074       0.061
# C(year)[T.2020]:C(region)[T.HSE Dublin and South East]                                              -0.0574      0.035     -1.652      0.098      -0.126       0.011
# C(year)[T.2021]:C(region)[T.HSE Dublin and South East]                                              -0.0042      0.034     -0.124      0.901      -0.071       0.063
# C(year)[T.2022]:C(region)[T.HSE Dublin and South East]                                              -0.0108      0.034     -0.323      0.747      -0.077       0.055
# C(year)[T.2023]:C(region)[T.HSE Dublin and South East]                                              -0.0731      0.033     -2.211      0.027      -0.138      -0.008
# C(year)[T.2017]:C(region)[T.HSE Mid West]                                                           -0.0749      0.047     -1.579      0.114      -0.168       0.018
# C(year)[T.2018]:C(region)[T.HSE Mid West]                                                           -0.0311      0.046     -0.670      0.503      -0.122       0.060
# C(year)[T.2019]:C(region)[T.HSE Mid West]                                                           -0.0954      0.046     -2.060      0.039      -0.186      -0.005
# C(year)[T.2020]:C(region)[T.HSE Mid West]                                                           -0.0403      0.045     -0.893      0.372      -0.129       0.048
# C(year)[T.2021]:C(region)[T.HSE Mid West]                                                           -0.0223      0.045     -0.499      0.618      -0.110       0.065
# C(year)[T.2022]:C(region)[T.HSE Mid West]                                                           -0.0154      0.044     -0.354      0.723      -0.101       0.070
# C(year)[T.2023]:C(region)[T.HSE Mid West]                                                           -0.1173      0.043     -2.711      0.007      -0.202      -0.032
# C(year)[T.2017]:C(region)[T.HSE South West]                                                         -0.0569      0.034     -1.679      0.093      -0.123       0.010
# C(year)[T.2018]:C(region)[T.HSE South West]                                                          0.0058      0.034      0.173      0.863      -0.060       0.072
# C(year)[T.2019]:C(region)[T.HSE South West]                                                          0.0321      0.033      0.970      0.332      -0.033       0.097
# C(year)[T.2020]:C(region)[T.HSE South West]                                                          0.0001      0.033      0.004      0.997      -0.065       0.065
# C(year)[T.2021]:C(region)[T.HSE South West]                                                          0.0627      0.033      1.916      0.055      -0.001       0.127
# C(year)[T.2022]:C(region)[T.HSE South West]                                                          0.0856      0.032      2.690      0.007       0.023       0.148
# C(year)[T.2023]:C(region)[T.HSE South West]                                                          0.0747      0.031      2.388      0.017       0.013       0.136
# C(year)[T.2017]:C(region)[T.HSE West and North West]                                                -0.0372      0.035     -1.075      0.282      -0.105       0.031
# C(year)[T.2018]:C(region)[T.HSE West and North West]                                                -0.0067      0.035     -0.193      0.847      -0.074       0.061
# C(year)[T.2019]:C(region)[T.HSE West and North West]                                                 0.0393      0.034      1.159      0.246      -0.027       0.106
# C(year)[T.2020]:C(region)[T.HSE West and North West]                                                 0.0263      0.034      0.778      0.436      -0.040       0.092
# C(year)[T.2021]:C(region)[T.HSE West and North West]                                                 0.0660      0.033      1.984      0.047       0.001       0.131
# C(year)[T.2022]:C(region)[T.HSE West and North West]                                                 0.0871      0.033      2.677      0.007       0.023       0.151
# C(year)[T.2023]:C(region)[T.HSE West and North West]                                                 0.0341      0.032      1.066      0.286      -0.029       0.097
# callout_count_lag30                                                                                  0.0021      0.002      1.331      0.183      -0.001       0.005
# alpha                                                                                               -0.1934      0.002   -119.941      0.000      -0.197      -0.190
# ====================================================================================================================================================================
#
# ============================================================
# FITTING NEGATIVE BINOMIAL MODEL (FOR COMPARISON)
# ============================================================
# /home/paulharford/anaconda3/envs/msc/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# Negative Binomial Model Summary:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:          callout_count   No. Observations:                63298
# Model:                            GLM   Df Residuals:                    63190
# Model Family:        NegativeBinomial   Df Model:                          107
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.1850e+05
# Date:                Sun, 06 Jul 2025   Deviance:                       9924.6
# Time:                        16:55:32   Pearson chi2:                 1.12e+04
# No. Iterations:                     6   Pseudo R-squ. (CS):            0.08900
# Covariance Type:            nonrobust
# ====================================================================================================================================================================
#                                                                                                        coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                          -11.7449      0.084   -139.619      0.000     -11.910     -11.580
# C(year)[T.2017]                                                                                      0.0643      0.056      1.149      0.251      -0.045       0.174
# C(year)[T.2018]                                                                                      0.0828      0.055      1.499      0.134      -0.025       0.191
# C(year)[T.2019]                                                                                      0.1144      0.055      2.096      0.036       0.007       0.221
# C(year)[T.2020]                                                                                      0.1045      0.054      1.923      0.054      -0.002       0.211
# C(year)[T.2021]                                                                                      0.0723      0.054      1.340      0.180      -0.033       0.178
# C(year)[T.2022]                                                                                      0.1512      0.053      2.854      0.004       0.047       0.255
# C(year)[T.2023]                                                                                      0.1989      0.052      3.805      0.000       0.096       0.301
# C(month)[T.2]                                                                                       -0.0032      0.025     -0.128      0.898      -0.052       0.046
# C(month)[T.3]                                                                                       -0.0119      0.025     -0.486      0.627      -0.060       0.036
# C(month)[T.4]                                                                                       -0.0104      0.025     -0.415      0.678      -0.059       0.039
# C(month)[T.5]                                                                                        0.0083      0.025      0.335      0.738      -0.040       0.057
# C(month)[T.6]                                                                                        0.0306      0.025      1.242      0.214      -0.018       0.079
# C(month)[T.7]                                                                                        0.0380      0.024      1.554      0.120      -0.010       0.086
# C(month)[T.8]                                                                                        0.0511      0.024      2.106      0.035       0.004       0.099
# C(month)[T.9]                                                                                        0.0424      0.024      1.738      0.082      -0.005       0.090
# C(month)[T.10]                                                                                       0.0253      0.024      1.044      0.296      -0.022       0.073
# C(month)[T.11]                                                                                       0.0288      0.024      1.182      0.237      -0.019       0.077
# C(month)[T.12]                                                                                       0.1082      0.023      4.626      0.000       0.062       0.154
# C(region)[T.HSE Dublin and North East]                                                              -0.1364      0.068     -2.011      0.044      -0.269      -0.003
# C(region)[T.HSE Dublin and South East]                                                               0.0822      0.065      1.256      0.209      -0.046       0.210
# C(region)[T.HSE Mid West]                                                                            0.6030      0.078      7.682      0.000       0.449       0.757
# C(region)[T.HSE South West]                                                                          0.4494      0.063      7.099      0.000       0.325       0.573
# C(region)[T.HSE West and North West]                                                                 0.3485      0.064      5.455      0.000       0.223       0.474
# C(fall_category_group)[T.17A03_injuries_excluding_distal]                                           -0.3777      0.126     -3.007      0.003      -0.624      -0.132
# C(fall_category_group)[T.17A04_public_assistance]                                                   -0.3561      0.130     -2.746      0.006      -0.610      -0.102
# C(fall_category_group)[T.17B00_bravo_override]                                                       0.0189      0.101      0.187      0.852      -0.180       0.218
# C(fall_category_group)[T.17B01_possibly_dangerous]                                                   0.3926      0.092      4.263      0.000       0.212       0.573
# C(fall_category_group)[T.17D04_not_alert]                                                           -0.0457      0.103     -0.443      0.658      -0.248       0.157
# warning_severity[T.Red]:C(fall_category_group)[17A02_not_dangerous_proximal]                        -0.1374      0.222     -0.619      0.536      -0.573       0.298
# warning_severity[T.Yellow]:C(fall_category_group)[17A02_not_dangerous_proximal]                     -0.0249      0.072     -0.345      0.730      -0.166       0.117
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17A02_not_dangerous_proximal]         0.0029      0.068      0.043      0.966      -0.130       0.136
# warning_severity[T.Red]:C(fall_category_group)[17A03_injuries_excluding_distal]                      0.0353      0.338      0.105      0.917      -0.626       0.697
# warning_severity[T.Yellow]:C(fall_category_group)[17A03_injuries_excluding_distal]                   0.0236      0.103      0.228      0.820      -0.179       0.226
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17A03_injuries_excluding_distal]      0.0332      0.097      0.341      0.733      -0.158       0.224
# warning_severity[T.Red]:C(fall_category_group)[17A04_public_assistance]                              0.1700      0.348      0.488      0.625      -0.512       0.852
# warning_severity[T.Yellow]:C(fall_category_group)[17A04_public_assistance]                           0.0345      0.109      0.316      0.752      -0.179       0.248
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17A04_public_assistance]              0.0464      0.103      0.450      0.653      -0.156       0.249
# warning_severity[T.Red]:C(fall_category_group)[17B00_bravo_override]                                -0.0048      0.200     -0.024      0.981      -0.397       0.388
# warning_severity[T.Yellow]:C(fall_category_group)[17B00_bravo_override]                             -0.0803      0.071     -1.129      0.259      -0.220       0.059
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17B00_bravo_override]                -0.1171      0.067     -1.747      0.081      -0.248       0.014
# warning_severity[T.Red]:C(fall_category_group)[17B01_possibly_dangerous]                            -0.2510      0.188     -1.338      0.181      -0.619       0.117
# warning_severity[T.Yellow]:C(fall_category_group)[17B01_possibly_dangerous]                          0.0075      0.058      0.130      0.897      -0.106       0.121
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17B01_possibly_dangerous]            -0.0036      0.055     -0.065      0.948      -0.110       0.103
# warning_severity[T.Red]:C(fall_category_group)[17D04_not_alert]                                     -0.0379      0.227     -0.167      0.867      -0.482       0.406
# warning_severity[T.Yellow]:C(fall_category_group)[17D04_not_alert]                                   0.0060      0.074      0.081      0.936      -0.140       0.152
# warning_severity[T.no_weather_severity]:C(fall_category_group)[17D04_not_alert]                     -0.0195      0.070     -0.278      0.781      -0.157       0.118
# C(region)[T.HSE Dublin and North East]:C(fall_category_group)[T.17A03_injuries_excluding_distal]     0.0032      0.072      0.044      0.965      -0.137       0.144
# C(region)[T.HSE Dublin and South East]:C(fall_category_group)[T.17A03_injuries_excluding_distal]    -0.0599      0.073     -0.817      0.414      -0.203       0.084
# C(region)[T.HSE Mid West]:C(fall_category_group)[T.17A03_injuries_excluding_distal]                  0.1091      0.085      1.281      0.200      -0.058       0.276
# C(region)[T.HSE South West]:C(fall_category_group)[T.17A03_injuries_excluding_distal]               -0.2181      0.067     -3.239      0.001      -0.350      -0.086
# C(region)[T.HSE West and North West]:C(fall_category_group)[T.17A03_injuries_excluding_distal]      -0.1761      0.067     -2.627      0.009      -0.308      -0.045
# C(region)[T.HSE Dublin and North East]:C(fall_category_group)[T.17A04_public_assistance]            -0.0377      0.072     -0.523      0.601      -0.179       0.103
# C(region)[T.HSE Dublin and South East]:C(fall_category_group)[T.17A04_public_assistance]            -0.0144      0.068     -0.212      0.832      -0.148       0.119
# C(region)[T.HSE Mid West]:C(fall_category_group)[T.17A04_public_assistance]                          0.0594      0.090      0.660      0.509      -0.117       0.236
# C(region)[T.HSE South West]:C(fall_category_group)[T.17A04_public_assistance]                       -0.3501      0.072     -4.879      0.000      -0.491      -0.209
# C(region)[T.HSE West and North West]:C(fall_category_group)[T.17A04_public_assistance]              -0.2522      0.068     -3.730      0.000      -0.385      -0.120
# C(region)[T.HSE Dublin and North East]:C(fall_category_group)[T.17B00_bravo_override]                0.0221      0.058      0.380      0.704      -0.092       0.136
# C(region)[T.HSE Dublin and South East]:C(fall_category_group)[T.17B00_bravo_override]               -0.0107      0.057     -0.187      0.852      -0.123       0.102
# C(region)[T.HSE Mid West]:C(fall_category_group)[T.17B00_bravo_override]                             0.0374      0.066      0.570      0.569      -0.091       0.166
# C(region)[T.HSE South West]:C(fall_category_group)[T.17B00_bravo_override]                           0.0612      0.054      1.138      0.255      -0.044       0.166
# C(region)[T.HSE West and North West]:C(fall_category_group)[T.17B00_bravo_override]                 -0.1366      0.055     -2.475      0.013      -0.245      -0.028
# C(region)[T.HSE Dublin and North East]:C(fall_category_group)[T.17B01_possibly_dangerous]            0.0794      0.051      1.560      0.119      -0.020       0.179
# C(region)[T.HSE Dublin and South East]:C(fall_category_group)[T.17B01_possibly_dangerous]            0.1602      0.050      3.177      0.001       0.061       0.259
# C(region)[T.HSE Mid West]:C(fall_category_group)[T.17B01_possibly_dangerous]                        -0.2012      0.058     -3.479      0.001      -0.315      -0.088
# C(region)[T.HSE South West]:C(fall_category_group)[T.17B01_possibly_dangerous]                       0.0288      0.049      0.593      0.553      -0.066       0.124
# C(region)[T.HSE West and North West]:C(fall_category_group)[T.17B01_possibly_dangerous]              0.0003      0.049      0.006      0.995      -0.095       0.096
# C(region)[T.HSE Dublin and North East]:C(fall_category_group)[T.17D04_not_alert]                    -0.0192      0.058     -0.333      0.739      -0.132       0.094
# C(region)[T.HSE Dublin and South East]:C(fall_category_group)[T.17D04_not_alert]                     0.0202      0.057      0.357      0.721      -0.091       0.131
# C(region)[T.HSE Mid West]:C(fall_category_group)[T.17D04_not_alert]                                 -0.0044      0.066     -0.067      0.946      -0.133       0.124
# C(region)[T.HSE South West]:C(fall_category_group)[T.17D04_not_alert]                               -0.0657      0.054     -1.221      0.222      -0.171       0.040
# C(region)[T.HSE West and North West]:C(fall_category_group)[T.17D04_not_alert]                      -0.1815      0.055     -3.307      0.001      -0.289      -0.074
# C(year)[T.2017]:C(region)[T.HSE Dublin and North East]                                              -0.0283      0.079     -0.358      0.720      -0.183       0.127
# C(year)[T.2018]:C(region)[T.HSE Dublin and North East]                                               0.0018      0.078      0.023      0.982      -0.150       0.154
# C(year)[T.2019]:C(region)[T.HSE Dublin and North East]                                              -0.0054      0.077     -0.070      0.944      -0.156       0.145
# C(year)[T.2020]:C(region)[T.HSE Dublin and North East]                                              -0.0020      0.076     -0.027      0.979      -0.151       0.147
# C(year)[T.2021]:C(region)[T.HSE Dublin and North East]                                               0.0384      0.076      0.508      0.611      -0.110       0.186
# C(year)[T.2022]:C(region)[T.HSE Dublin and North East]                                               0.0391      0.074      0.527      0.598      -0.106       0.184
# C(year)[T.2023]:C(region)[T.HSE Dublin and North East]                                               0.0044      0.073      0.060      0.952      -0.139       0.148
# C(year)[T.2017]:C(region)[T.HSE Dublin and South East]                                              -0.0525      0.076     -0.691      0.489      -0.201       0.096
# C(year)[T.2018]:C(region)[T.HSE Dublin and South East]                                               0.0098      0.074      0.132      0.895      -0.136       0.156
# C(year)[T.2019]:C(region)[T.HSE Dublin and South East]                                              -0.0081      0.074     -0.110      0.912      -0.152       0.136
# C(year)[T.2020]:C(region)[T.HSE Dublin and South East]                                              -0.0374      0.073     -0.508      0.611      -0.181       0.107
# C(year)[T.2021]:C(region)[T.HSE Dublin and South East]                                               0.0079      0.073      0.109      0.914      -0.135       0.151
# C(year)[T.2022]:C(region)[T.HSE Dublin and South East]                                              -0.0085      0.072     -0.118      0.906      -0.149       0.132
# C(year)[T.2023]:C(region)[T.HSE Dublin and South East]                                              -0.0545      0.071     -0.764      0.445      -0.194       0.085
# C(year)[T.2017]:C(region)[T.HSE Mid West]                                                           -0.0530      0.091     -0.581      0.561      -0.232       0.126
# C(year)[T.2018]:C(region)[T.HSE Mid West]                                                           -0.0330      0.089     -0.370      0.711      -0.208       0.142
# C(year)[T.2019]:C(region)[T.HSE Mid West]                                                           -0.0888      0.089     -0.997      0.319      -0.263       0.086
# C(year)[T.2020]:C(region)[T.HSE Mid West]                                                           -0.0587      0.088     -0.668      0.504      -0.231       0.114
# C(year)[T.2021]:C(region)[T.HSE Mid West]                                                           -0.0085      0.086     -0.098      0.922      -0.178       0.161
# C(year)[T.2022]:C(region)[T.HSE Mid West]                                                           -0.0309      0.085     -0.364      0.716      -0.197       0.136
# C(year)[T.2023]:C(region)[T.HSE Mid West]                                                           -0.1140      0.085     -1.347      0.178      -0.280       0.052
# C(year)[T.2017]:C(region)[T.HSE South West]                                                         -0.0320      0.074     -0.435      0.663      -0.176       0.112
# C(year)[T.2018]:C(region)[T.HSE South West]                                                          0.0190      0.072      0.262      0.793      -0.123       0.160
# C(year)[T.2019]:C(region)[T.HSE South West]                                                          0.0356      0.072      0.497      0.619      -0.105       0.176
# C(year)[T.2020]:C(region)[T.HSE South West]                                                          0.0153      0.071      0.214      0.831      -0.124       0.155
# C(year)[T.2021]:C(region)[T.HSE South West]                                                          0.0867      0.071      1.225      0.220      -0.052       0.225
# C(year)[T.2022]:C(region)[T.HSE South West]                                                          0.0842      0.070      1.211      0.226      -0.052       0.220
# C(year)[T.2023]:C(region)[T.HSE South West]                                                          0.0902      0.069      1.313      0.189      -0.044       0.225
# C(year)[T.2017]:C(region)[T.HSE West and North West]                                                 0.0018      0.074      0.024      0.980      -0.144       0.148
# C(year)[T.2018]:C(region)[T.HSE West and North West]                                                 0.0129      0.073      0.176      0.861      -0.131       0.157
# C(year)[T.2019]:C(region)[T.HSE West and North West]                                                 0.0524      0.073      0.721      0.471      -0.090       0.195
# C(year)[T.2020]:C(region)[T.HSE West and North West]                                                 0.0423      0.072      0.586      0.558      -0.099       0.184
# C(year)[T.2021]:C(region)[T.HSE West and North West]                                                 0.0938      0.072      1.310      0.190      -0.047       0.234
# C(year)[T.2022]:C(region)[T.HSE West and North West]                                                 0.1004      0.070      1.430      0.153      -0.037       0.238
# C(year)[T.2023]:C(region)[T.HSE West and North West]                                                 0.0670      0.070      0.962      0.336      -0.069       0.204
# callout_count_lag30                                                                                  0.0027      0.004      0.722      0.471      -0.005       0.010
# ====================================================================================================================================================================
#
# ============================================================
# MODEL COMPARISON - PREDICTION METRICS
# ============================================================
#
# Poisson Model:
#   MSE: 1.2836, RMSE: 1.1330
#   MAE: 0.8332, MAPE: 48.93%
#
# Generalized Poisson Model:
#   MSE: 1.2870, RMSE: 1.1345
#   MAE: 0.8268, MAPE: 48.26%
#
# Negative Binomial Model:
#   MSE: 1.2855, RMSE: 1.1338
#   MAE: 0.8340, MAPE: 48.98%
#
# ============================================================
# CHECKING PREDICTION DIFFERENCES
# ============================================================
#
# Poisson vs Generalized Poisson:
#   Mean absolute difference: 0.056943
#   Max absolute difference: 0.283758
#
# Poisson vs Negative Binomial:
#   Mean absolute difference: 0.016013
#   Max absolute difference: 0.130894
#
# Generalized Poisson vs Negative Binomial:
#   Mean absolute difference: 0.063837
#   Max absolute difference: 0.372264
# ============================================================
# DETAILED MODEL DIAGNOSTICS
# ============================================================
#
# Poisson Model:
#   Mean Residual: -0.0000
#   Std Dev of Residuals: 1.1330
#   Min/Max Residual: -3.5203 / 11.0939
#   % Predictions within ±1 of actual: 72.2%
#   % Predictions within ±2 of actual: 92.4%
#
# Generalized Poisson Model:
#   Mean Residual: -0.0000
#   Std Dev of Residuals: 1.1345
#   Min/Max Residual: -3.7350 / 10.8884
#   % Predictions within ±1 of actual: 71.5%
#   % Predictions within ±2 of actual: 92.3%
#
# Negative Binomial Model:
#   Mean Residual: 0.0013
#   Std Dev of Residuals: 1.1338
#   Min/Max Residual: -3.4438 / 11.1299
#   % Predictions within ±1 of actual: 72.3%
#   % Predictions within ±2 of actual: 92.4%
#
# ============================================================
# DISPERSION ANALYSIS
# ============================================================
# Poisson model dispersion parameter: 0.5085
# Strong evidence of underdispersion - Generalized Poisson should perform better than standard Poisson
#
# ============================================================
# MODEL SELECTION RECOMMENDATION
# ============================================================
#
# Based on MSE, the best model is: Poisson
# Based on MAPE, the best model is: Generalized Poisson
#
# Generalized Poisson dispersion parameter (alpha): -0.1934
# Negative alpha confirms underdispersion in the data
#
# ============================================================
# DATA INFORMATION
# ============================================================
# Total rows in df_model: 63478
# Rows used in model (after removing NAs): 63298
# Rows dropped due to lag variables: 180
# Date range in model: 2016-01-11 00:00:00 to 2023-12-31 00:00:00
# Regions included: ['HSE Dublin and Midlands' 'HSE Dublin and North East'
#  'HSE Dublin and South East' 'HSE Mid West' 'HSE South West'
#  'HSE West and North West']
# /tmp/ipykernel_61618/4005745967.py:391: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gp_alpha = gp_results.params[-1]  # Last parameter is usually dispersion

# %%
def extract_coefficients_direct(gp_results):
    """Extract coefficients directly from GeneralizedPoisson results object"""
    coef_data = {}
    
    # Get parameter names
    param_names = gp_results.model.exog_names
    
    # Extract coefficient data
    coefficients = gp_results.params
    std_errors = gp_results.bse
    z_values = gp_results.tvalues
    p_values = gp_results.pvalues
    conf_int = gp_results.conf_int()
    
    # Build the coefficient dictionary
    for i, name in enumerate(param_names):
        coef_data[name] = {
            'coef': coefficients[i],
            'std_err': std_errors[i],
            'z': z_values[i],
            'p_value': p_values[i],
            'ci_lower': conf_int.iloc[i, 0],  # Changed from conf_int[i, 0]
            'ci_upper': conf_int.iloc[i, 1]   # Changed from conf_int[i, 1]
        }
    
    # Also extract the dispersion parameter if available
    if hasattr(gp_results, 'alpha'):
        coef_data['alpha (dispersion)'] = {
            'coef': gp_results.alpha,
            'std_err': None,
            'z': None,
            'p_value': None,
            'ci_lower': None,
            'ci_upper': None
        }
    
    print(f"Extracted {len(coef_data)} coefficients:")
    for i, (key, value) in enumerate(list(coef_data.items())[:5]):
        print(f"  {key}: {value['coef']:.4f}")
    if len(coef_data) > 5:
        print(f"  ... and {len(coef_data) - 5} more")
    
    return coef_data


# Extract coefficients from the model summary
coefficients = extract_coefficients_direct(gp_results)

# Set the style
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_context("talk")


# 1. Year effects visualization
years = [2017, 2018, 2019, 2020, 2021, 2022, 2023]
year_coefs = [coefficients[f'C(year)[T.{year}]']['coef'] for year in years]
year_ci_lower = [coefficients[f'C(year)[T.{year}]']['ci_lower'] for year in years]
year_ci_upper = [coefficients[f'C(year)[T.{year}]']['ci_upper'] for year in years]

years_df = pd.DataFrame({
    'Year': years,
    'Coefficient': year_coefs,
    'Lower_CI': year_ci_lower,
    'Upper_CI': year_ci_upper
})

plt.figure(figsize=(12, 6))
plt.plot(years_df['Year'], years_df['Coefficient'], marker='o', linewidth=2, color='#1f77b4')
plt.fill_between(years_df['Year'], years_df['Lower_CI'], years_df['Upper_CI'], alpha=0.2, color='#1f77b4')
plt.title('Yearly Trend in Hip Fracture Ambulance Callouts (2017-2023)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Coefficient (Effect Size)', fontsize=14)
plt.grid(True, alpha=0.3)
plt.xticks(years)
plt.axhline(y=0, color='gray', linestyle='--', alpha=0.7)
for i, year in enumerate(years):
    plt.annotate(f"{year_coefs[i]:.3f}", (year, year_coefs[i]), 
                 textcoords="offset points", xytext=(0,10), ha='center')
plt.tight_layout()
plt.savefig('/home/paulharford/college/project/ul_project_Msc_AI/analysis/processed_data/visual_outputs/nas_weather/yearly_trend.png', dpi=300, bbox_inches='tight')
plt.show()

# 2. Month effects visualization
months = list(range(1, 13))
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# January is the reference category (coef = 0)
month_coefs = [0.0]  
month_p = [1.0]  # Reference category p-value set to 1

# Add coefficients for months 2-12
for i in range(2, 13):
    key = f'C(month)[T.{i}]'
    if key in coefficients:
        month_coefs.append(coefficients[key]['coef'])
        month_p.append(coefficients[key]['p_value'])

months_df = pd.DataFrame({
    'Month': month_names,
    'Coefficient': month_coefs,
    'Significant': [p < 0.05 for p in month_p]
})

plt.figure(figsize=(14, 6))
bars = plt.bar(months_df['Month'], months_df['Coefficient'], 
       color=[sns.color_palette("rocket_r")[0] if sig else 'lightgray' for sig in months_df['Significant']])
plt.title('Monthly Patterns in Hip Fracture Ambulance Callouts', fontsize=16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Coefficient (Effect Size)', fontsize=14)
plt.axhline(y=0, color='gray', linestyle='--', alpha=0.7)
plt.grid(True, axis='y', alpha=0.3)

# Add coefficient values above each bar
for bar in bars:
    height = bar.get_height()
    if height > 0:
        plt.text(bar.get_x() + bar.get_width()/2., height + 0.01,
                f'{height:.3f}', ha='center', va='bottom')
    else:
        plt.text(bar.get_x() + bar.get_width()/2., height - 0.02,
                f'{height:.3f}', ha='center', va='top')

plt.tight_layout()
plt.savefig('monthly_pattern.png', dpi=300, bbox_inches='tight')
plt.show()

# 3. Extract fall categories base effects
# Out:
# /tmp/ipykernel_61618/1101057443.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'coef': coefficients[i],
# /tmp/ipykernel_61618/1101057443.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'std_err': std_errors[i],
# /tmp/ipykernel_61618/1101057443.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'z': z_values[i],
# /tmp/ipykernel_61618/1101057443.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'p_value': p_values[i],
# Extracted 109 coefficients:
#   Intercept: -11.8050
#   C(year)[T.2017]: 0.0965
#   C(year)[T.2018]: 0.1095
#   C(year)[T.2019]: 0.1442
#   C(year)[T.2020]: 0.1358
#   ... and 104 more
# Found 0 weather interaction coefficients out of 7
# No seasonal weather interaction coefficients found in the model
# All visualizations have been created successfully.
#
# --- Debug: Available interaction coefficients ---
#   warning_severity[T.Red]:C(fall_category_group)[17A02_not_dangerous_proximal]: -0.1879
#   warning_severity[T.Yellow]:C(fall_category_group)[17A02_not_dangerous_proximal]: -0.0279
#   warning_severity[T.no_weather_severity]:C(fall_category_group)[17A02_not_dangerous_proximal]: 0.0139
#   warning_severity[T.Red]:C(fall_category_group)[17A03_injuries_excluding_distal]: 0.0301
#   warning_severity[T.Yellow]:C(fall_category_group)[17A03_injuries_excluding_distal]: 0.0280
#   warning_severity[T.no_weather_severity]:C(fall_category_group)[17A03_injuries_excluding_distal]: 0.0193
#   warning_severity[T.Red]:C(fall_category_group)[17A04_public_assistance]: 0.1951
#   warning_severity[T.Yellow]:C(fall_category_group)[17A04_public_assistance]: 0.0533
#   warning_severity[T.no_weather_severity]:C(fall_category_group)[17A04_public_assistance]: 0.0644
#   warning_severity[T.Red]:C(fall_category_group)[17B00_bravo_override]: -0.0094
#   warning_severity[T.Yellow]:C(fall_category_group)[17B00_bravo_override]: -0.0741
#   warning_severity[T.no_weather_severity]:C(fall_category_group)[17B00_bravo_override]: -0.1290
#   warning_severity[T.Red]:C(fall_category_group)[17B01_possibly_dangerous]: -0.2705
#   warning_severity[T.Yellow]:C(fall_category_group)[17B01_possibly_dangerous]: 0.0006
#   warning_severity[T.no_weather_severity]:C(fall_category_group)[17B01_possibly_dangerous]: -0.0065
#   warning_severity[T.Red]:C(fall_category_group)[17D04_not_alert]: -0.0356
#   warning_severity[T.Yellow]:C(fall_category_group)[17D04_not_alert]: 0.0085
#   warning_severity[T.no_weather_severity]:C(fall_category_group)[17D04_not_alert]: -0.0107
