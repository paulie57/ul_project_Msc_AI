# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# For inline plots in Jupyter
# %matplotlib inline
import pandas as pd
import matplotlib as plt
import glob
import os
import xml.etree.ElementTree as ET
from datetime import datetime, timezone
from tqdm import tqdm
import codecs
import csv
import openpyxl

# %%
data_directory_weather = "/home/paulharford/college/project/project_data/processed/WEATHERED_warnings_2014-2023_cleaned.csv"
data_directory_nas = "/home/paulharford/college/project/project_data/nas/nas_clean.csv"
data_directory_census = "/home/paulharford/college/project/project_data/processed/census_estimated_per_region_2014_2023.csv"
full_path_nas = os.path.abspath(data_directory_nas)
full_path_weather = os.path.abspath(data_directory_weather)
full_path_census = os.path.abspath(data_directory_census)

# %%
df_nas = pd.read_csv(full_path_nas)
df_weather = pd.read_csv(full_path_weather)
df_census = pd.read_csv(full_path_census)

# %%
df_weather["Valid From"] = pd.to_datetime(df_weather["Valid From"])
df_weather["date"] = df_weather["Valid From"].dt.date
df_weather["date"] = pd.to_datetime(df_weather["date"])
df_weather["Valid To"] = pd.to_datetime(df_weather["Valid To"])

# %%
#add column for lag
df_weather['lag_valid_to'] = df_weather['Valid To'] + pd.Timedelta(hours=12)

# %%
weather_region_cols = [
    "HSE Dublin and North East",
    "HSE Dublin and Midlands",
    "HSE Dublin and South East",
    "HSE Mid West",
    "HSE South West",
    "HSE West and North West",
    # any others you have
]

df_weather_full = df_weather.melt(
    id_vars=["date", "Issue Time", "Valid From", "Valid To", "lag_valid_to", "Warning Colour", 
             "Warning Element", "Warning Text", "Duration_hours"],
    value_vars=weather_region_cols,
    var_name="region",
    value_name="weather_flag"
)

# %%
df_weather_full.head(10)
# Out:
#         date                 Issue Time                Valid From  \
# 0 2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 1 2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 2 2014-01-03  2014-01-02 09:00:00+00:00 2014-01-03 14:00:00+00:00
# 3 2014-01-04  2014-01-04 03:00:00+00:00 2014-01-04 03:00:00+00:00
# 4 2014-01-05  2014-01-04 10:00:00+00:00 2014-01-05 08:00:00+00:00
# 5 2014-01-05  2014-01-04 16:00:00+00:00 2014-01-05 08:00:00+00:00
# 6 2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 7 2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 8 2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 9 2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 12:00:00+00:00
#
#                    Valid To              lag_valid_to Warning Colour  \
# 0 2014-01-03 14:00:00+00:00 2014-01-04 02:00:00+00:00         Orange
# 1 2014-01-03 14:00:00+00:00 2014-01-04 02:00:00+00:00         Yellow
# 2 2014-01-03 19:00:00+00:00 2014-01-04 07:00:00+00:00         Yellow
# 3 2014-01-04 14:00:00+00:00 2014-01-05 02:00:00+00:00         Yellow
# 4 2014-01-05 20:00:00+00:00 2014-01-06 08:00:00+00:00         Yellow
# 5 2014-01-05 18:00:00+00:00 2014-01-06 06:00:00+00:00         Yellow
# 6 2014-01-06 12:00:00+00:00 2014-01-07 00:00:00+00:00         Yellow
# 7 2014-01-06 12:00:00+00:00 2014-01-07 00:00:00+00:00         Yellow
# 8 2014-01-06 12:00:00+00:00 2014-01-07 00:00:00+00:00         Orange
# 9 2014-01-06 12:00:00+00:00 2014-01-07 00:00:00+00:00         Orange
#
#   Warning Element                                       Warning Text  \
# 0            Wind  Becoming stormy this evening and tonight and c...
# 1            Wind  Becoming extremely windy or stormy this evenin...
# 2            Wind  Blustery for the rest of the afternoon with so...
# 3        Snow/Ice  Scattered outbreaks of rain and sleet spreadin...
# 4            Wind  Southeast winds mean speeds of 50 to 65 km/h w...
# 5            Wind  Becoming windy again on Sunday morning with st...
# 6            Wind  UpdateStrong south to southeast winds, with gu...
# 7            Wind  UndateStrong south to southeast winds, with gu...
# 8            Wind  Update Strong south to southeast winds, with g...
# 9            Wind  Update Strong south to southeast winds, with g...
#
#    Duration_hours                     region  weather_flag
# 0            21.0  HSE Dublin and North East             0
# 1            21.0  HSE Dublin and North East             1
# 2             5.0  HSE Dublin and North East             1
# 3            11.0  HSE Dublin and North East             1
# 4            12.0  HSE Dublin and North East             1
# 5            10.0  HSE Dublin and North East             1
# 6            25.0  HSE Dublin and North East             1
# 7            25.0  HSE Dublin and North East             1
# 8            25.0  HSE Dublin and North East             0
# 9            24.0  HSE Dublin and North East             0

# %%
fill_values = {
    'Issue Time': 0,
    'Valid From': 0,
    'Valid To': 0,
    'lag_valid_to': 0,
    'Warning Colour': 0,
    'Warning Element': 0,
    # For text fields you want a specific string, e.g. 'noevent':
    'Warning Text': 'noevent',
    'Duration_hours': 0,
    'region': 'noevent',
    'weather_flag': 2.0
}

# Fill NaN values for these columns using fillna().
df_weather_full.fillna(value=fill_values, inplace=True)

# %%
df_weather_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16398 entries, 0 to 16397
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             16398 non-null  datetime64[ns]
#  1   Issue Time       16398 non-null  object
#  2   Valid From       16398 non-null  datetime64[ns, UTC]
#  3   Valid To         16398 non-null  object
#  4   lag_valid_to     16398 non-null  object
#  5   Warning Colour   16398 non-null  object
#  6   Warning Element  16398 non-null  object
#  7   Warning Text     16398 non-null  object
#  8   Duration_hours   16398 non-null  float64
#  9   region           16398 non-null  object
#  10  weather_flag     16398 non-null  int64
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 1.4+ MB

# %%
df_weather_full.head(15)
# Out:
#          date                 Issue Time                Valid From  \
# 0  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 1  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 2  2014-01-03  2014-01-02 09:00:00+00:00 2014-01-03 14:00:00+00:00
# 3  2014-01-04  2014-01-04 03:00:00+00:00 2014-01-04 03:00:00+00:00
# 4  2014-01-05  2014-01-04 10:00:00+00:00 2014-01-05 08:00:00+00:00
# 5  2014-01-05  2014-01-04 16:00:00+00:00 2014-01-05 08:00:00+00:00
# 6  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 7  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 8  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 9  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 12:00:00+00:00
# 10 2014-01-05  2014-01-05 12:00:00+00:00 2014-01-05 12:00:00+00:00
# 11 2014-01-05  2014-01-05 12:00:00+00:00 2014-01-05 12:00:00+00:00
# 12 2014-01-06  2014-01-06 09:00:00+00:00 2014-01-06 09:00:00+00:00
# 13 2014-01-06  2014-01-06 19:00:00+00:00 2014-01-06 19:00:00+00:00
# 14 2014-01-06  2014-01-06 21:00:00+00:00 2014-01-06 21:00:00+00:00
#
#                      Valid To               lag_valid_to Warning Colour  \
# 0   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 1   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
# 2   2014-01-03 19:00:00+00:00  2014-01-04 07:00:00+00:00         Yellow
# 3   2014-01-04 14:00:00+00:00  2014-01-05 02:00:00+00:00         Yellow
# 4   2014-01-05 20:00:00+00:00  2014-01-06 08:00:00+00:00         Yellow
# 5   2014-01-05 18:00:00+00:00  2014-01-06 06:00:00+00:00         Yellow
# 6   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 7   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 8   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Orange
# 9   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Orange
# 10  2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 11  2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 12  2014-01-06 19:00:00+00:00  2014-01-07 07:00:00+00:00         Orange
# 13  2014-01-06 23:59:00+00:00  2014-01-07 11:59:00+00:00         Yellow
# 14  2014-01-07 05:00:00+00:00  2014-01-07 17:00:00+00:00         Yellow
#
#    Warning Element                                       Warning Text  \
# 0             Wind  Becoming stormy this evening and tonight and c...
# 1             Wind  Becoming extremely windy or stormy this evenin...
# 2             Wind  Blustery for the rest of the afternoon with so...
# 3         Snow/Ice  Scattered outbreaks of rain and sleet spreadin...
# 4             Wind  Southeast winds mean speeds of 50 to 65 km/h w...
# 5             Wind  Becoming windy again on Sunday morning with st...
# 6             Wind  UpdateStrong south to southeast winds, with gu...
# 7             Wind  UndateStrong south to southeast winds, with gu...
# 8             Wind  Update Strong south to southeast winds, with g...
# 9             Wind  Update Strong south to southeast winds, with g...
# 10            Wind  UpdateStrong south to southeast winds, with gu...
# 11            Wind  Update Strong south to southeast winds, with g...
# 12            Wind  Widespread gales continuing today with gusts r...
# 13            Wind  Widespread gales continuing this evening and t...
# 14            Wind  Strong to gale force south to southwest winds ...
#
#     Duration_hours                     region  weather_flag
# 0        21.000000  HSE Dublin and North East             0
# 1        21.000000  HSE Dublin and North East             1
# 2         5.000000  HSE Dublin and North East             1
# 3        11.000000  HSE Dublin and North East             1
# 4        12.000000  HSE Dublin and North East             1
# 5        10.000000  HSE Dublin and North East             1
# 6        25.000000  HSE Dublin and North East             1
# 7        25.000000  HSE Dublin and North East             1
# 8        25.000000  HSE Dublin and North East             0
# 9        24.000000  HSE Dublin and North East             0
# 10       24.000000  HSE Dublin and North East             1
# 11       24.000000  HSE Dublin and North East             0
# 12       10.000000  HSE Dublin and North East             1
# 13        4.983333  HSE Dublin and North East             1
# 14        8.000000  HSE Dublin and North East             0

# %%
df_weather_filtered = df_weather_full[
    (df_weather_full['date'] >= '2016-01-01') & 
    (df_weather_full['date'] <= '2023-12-31').copy()
]

# %% [markdown]
# ## NAS Data

# %%
# convert to a pandas datetime if you prefer consistency
df_nas["date"] = pd.to_datetime(df_nas["date"])

# %%
df_nas.head()
# Out:
#         date Time of Day         PickupTown DespatchCode  \
# 0 2016-01-01       Night            DUNGLOE       17B01P
# 1 2016-01-01       Night  BEAUMONT DUBLIN 9       17B01G
# 2 2016-01-01       Night           DROGHEDA        17B01
# 3 2016-01-01       Night        BORRISOKANE       17B01P
# 4 2016-01-01       Night            WEXFORD       17B01G
#
#                                  DespCodeDescription  \
# 0  Falls - Possibly Dangerous body Area - Public ...
# 1  Falls - Possibly Dangerous body Area - On the ...
# 2             Falls - Possibly Dangerous body Area -
# 3  Falls - Possibly Dangerous body Area - Public ...
# 4  Falls - Possibly Dangerous body Area - On the ...
#
#               Hospital Attended                     region
# 0  LETTERKENNY GENERAL HOSPITAL    HSE West and North West
# 1             BEAUMONT HOSPITAL  HSE Dublin and North East
# 2     LOURDES HOSPITAL DROGHEDA  HSE Dublin and North East
# 3  PORTIUNCULA GENERAL HOSPITAL    HSE West and North West
# 4                       Unknown                    Unknown

# %%
df_nas_filtered = df_nas[
    (df_nas['date'] >= '2016-01-01') & 
    (df_nas['date'] <= '2023-12-31').copy()
]

# %%
df_nas_season = df_nas_filtered.copy()

# %%
def month_to_season(month):
    # Convert month to an integer if it isn't already.
    month = int(month)
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Autumn'
    else:
        return 'unknown'

# %%
df_nas_season['month'] = df_nas_season['date'].dt.month

# %%
df_weather_full['month'] = df_weather_full['date'].dt.month

# %%
df_weather_full['season'] = df_weather_full['month'].apply(month_to_season)

# %%
df_nas_season['season'] = df_nas_season['month'].apply(month_to_season)

# %%
print(df_nas_season['season'].unique())
# Out:
# ['Winter' 'Spring' 'Summer' 'Autumn']

# %%
print(df_weather_full['season'].unique())
# Out:
# ['Winter' 'Spring' 'Summer' 'Autumn']

# %%
print(df_nas_season['season'].value_counts())
# Out:
# season
# Summer    39667
# Autumn    39217
# Winter    39196
# Spring    37126
# Name: count, dtype: int64

# %%
nan_counts = df_nas_season.isna().sum()
print(nan_counts)
# Out:
# date                   0
# Time of Day            0
# PickupTown             0
# DespatchCode           0
# DespCodeDescription    0
# Hospital Attended      0
# region                 0
# month                  0
# season                 0
# dtype: int64

# %% [markdown]
# ## merging

# %%
nas_agg = (
    df_nas_season
    .groupby(['region', 'date','season'])
    .agg(hip_fracture_callout=('date', 'count'))
    .reset_index()
)

# %%
nas_agg.head()
# Out:
#                     region       date  season  hip_fracture_callout
# 0  HSE Dublin and Midlands 2016-01-01  Winter                     8
# 1  HSE Dublin and Midlands 2016-01-02  Winter                     5
# 2  HSE Dublin and Midlands 2016-01-03  Winter                     2
# 3  HSE Dublin and Midlands 2016-01-04  Winter                     5
# 4  HSE Dublin and Midlands 2016-01-05  Winter                     2

# %%
##add full date calandar to the aggregation 
# 1a. Identify all unique regions
regions = nas_agg['region'].unique()

# 1b. Identify the full date range
min_date = nas_agg['date'].min()
max_date = nas_agg['date'].max()

# %%
all_dates = pd.date_range(start=min_date, end=max_date, freq='D')

multi_index = pd.MultiIndex.from_product([regions, all_dates], names=['region', 'date'])
df_region_date = pd.DataFrame(index=multi_index).reset_index()

# %%
df_region_date.head(15)
# Out:
#                      region       date
# 0   HSE Dublin and Midlands 2016-01-01
# 1   HSE Dublin and Midlands 2016-01-02
# 2   HSE Dublin and Midlands 2016-01-03
# 3   HSE Dublin and Midlands 2016-01-04
# 4   HSE Dublin and Midlands 2016-01-05
# 5   HSE Dublin and Midlands 2016-01-06
# 6   HSE Dublin and Midlands 2016-01-07
# 7   HSE Dublin and Midlands 2016-01-08
# 8   HSE Dublin and Midlands 2016-01-09
# 9   HSE Dublin and Midlands 2016-01-10
# 10  HSE Dublin and Midlands 2016-01-11
# 11  HSE Dublin and Midlands 2016-01-12
# 12  HSE Dublin and Midlands 2016-01-13
# 13  HSE Dublin and Midlands 2016-01-14
# 14  HSE Dublin and Midlands 2016-01-15

# %%
df_nas_final = pd.merge(
    df_region_date,          # all region-date combos
    nas_agg,               # your aggregated counts
    on=['region', 'date'],   # merge keys
    how='left'               # left-join so we keep all rows from df_region_date
)

# %%
df_nas_final['month'] = df_nas_final['date'].dt.month

# %%
df_nas_final.head(10)
# Out:
#                     region       date  season  hip_fracture_callout  month
# 0  HSE Dublin and Midlands 2016-01-01  Winter                   8.0      1
# 1  HSE Dublin and Midlands 2016-01-02  Winter                   5.0      1
# 2  HSE Dublin and Midlands 2016-01-03  Winter                   2.0      1
# 3  HSE Dublin and Midlands 2016-01-04  Winter                   5.0      1
# 4  HSE Dublin and Midlands 2016-01-05  Winter                   2.0      1
# 5  HSE Dublin and Midlands 2016-01-06  Winter                   6.0      1
# 6  HSE Dublin and Midlands 2016-01-07  Winter                   4.0      1
# 7  HSE Dublin and Midlands 2016-01-08  Winter                   8.0      1
# 8  HSE Dublin and Midlands 2016-01-09  Winter                   4.0      1
# 9  HSE Dublin and Midlands 2016-01-10  Winter                   3.0      1

# %%
df_nas_final['year'] = df_nas_final['date'].dt.year

# %%
severity_map = {
    'Yellow': 1,
    'Orange': 2,
    'Red': 3
}

df_weather_full['severity_num'] = df_weather_full['Warning Colour'].map(severity_map)

# %%
df_weather_full['severity_num'] = df_weather_full['severity_num'].fillna(0)

# %%
df_weather_full.head(15)
# Out:
#          date                 Issue Time                Valid From  \
# 0  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 1  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 2  2014-01-03  2014-01-02 09:00:00+00:00 2014-01-03 14:00:00+00:00
# 3  2014-01-04  2014-01-04 03:00:00+00:00 2014-01-04 03:00:00+00:00
# 4  2014-01-05  2014-01-04 10:00:00+00:00 2014-01-05 08:00:00+00:00
# 5  2014-01-05  2014-01-04 16:00:00+00:00 2014-01-05 08:00:00+00:00
# 6  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 7  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 8  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 11:00:00+00:00
# 9  2014-01-05  2014-01-05 11:00:00+00:00 2014-01-05 12:00:00+00:00
# 10 2014-01-05  2014-01-05 12:00:00+00:00 2014-01-05 12:00:00+00:00
# 11 2014-01-05  2014-01-05 12:00:00+00:00 2014-01-05 12:00:00+00:00
# 12 2014-01-06  2014-01-06 09:00:00+00:00 2014-01-06 09:00:00+00:00
# 13 2014-01-06  2014-01-06 19:00:00+00:00 2014-01-06 19:00:00+00:00
# 14 2014-01-06  2014-01-06 21:00:00+00:00 2014-01-06 21:00:00+00:00
#
#                      Valid To               lag_valid_to Warning Colour  \
# 0   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 1   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
# 2   2014-01-03 19:00:00+00:00  2014-01-04 07:00:00+00:00         Yellow
# 3   2014-01-04 14:00:00+00:00  2014-01-05 02:00:00+00:00         Yellow
# 4   2014-01-05 20:00:00+00:00  2014-01-06 08:00:00+00:00         Yellow
# 5   2014-01-05 18:00:00+00:00  2014-01-06 06:00:00+00:00         Yellow
# 6   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 7   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 8   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Orange
# 9   2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Orange
# 10  2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 11  2014-01-06 12:00:00+00:00  2014-01-07 00:00:00+00:00         Yellow
# 12  2014-01-06 19:00:00+00:00  2014-01-07 07:00:00+00:00         Orange
# 13  2014-01-06 23:59:00+00:00  2014-01-07 11:59:00+00:00         Yellow
# 14  2014-01-07 05:00:00+00:00  2014-01-07 17:00:00+00:00         Yellow
#
#    Warning Element                                       Warning Text  \
# 0             Wind  Becoming stormy this evening and tonight and c...
# 1             Wind  Becoming extremely windy or stormy this evenin...
# 2             Wind  Blustery for the rest of the afternoon with so...
# 3         Snow/Ice  Scattered outbreaks of rain and sleet spreadin...
# 4             Wind  Southeast winds mean speeds of 50 to 65 km/h w...
# 5             Wind  Becoming windy again on Sunday morning with st...
# 6             Wind  UpdateStrong south to southeast winds, with gu...
# 7             Wind  UndateStrong south to southeast winds, with gu...
# 8             Wind  Update Strong south to southeast winds, with g...
# 9             Wind  Update Strong south to southeast winds, with g...
# 10            Wind  UpdateStrong south to southeast winds, with gu...
# 11            Wind  Update Strong south to southeast winds, with g...
# 12            Wind  Widespread gales continuing today with gusts r...
# 13            Wind  Widespread gales continuing this evening and t...
# 14            Wind  Strong to gale force south to southwest winds ...
#
#     Duration_hours                     region  weather_flag  month  season  \
# 0        21.000000  HSE Dublin and North East             0      1  Winter
# 1        21.000000  HSE Dublin and North East             1      1  Winter
# 2         5.000000  HSE Dublin and North East             1      1  Winter
# 3        11.000000  HSE Dublin and North East             1      1  Winter
# 4        12.000000  HSE Dublin and North East             1      1  Winter
# 5        10.000000  HSE Dublin and North East             1      1  Winter
# 6        25.000000  HSE Dublin and North East             1      1  Winter
# 7        25.000000  HSE Dublin and North East             1      1  Winter
# 8        25.000000  HSE Dublin and North East             0      1  Winter
# 9        24.000000  HSE Dublin and North East             0      1  Winter
# 10       24.000000  HSE Dublin and North East             1      1  Winter
# 11       24.000000  HSE Dublin and North East             0      1  Winter
# 12       10.000000  HSE Dublin and North East             1      1  Winter
# 13        4.983333  HSE Dublin and North East             1      1  Winter
# 14        8.000000  HSE Dublin and North East             0      1  Winter
#
#     severity_num
# 0            2.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# 5            1.0
# 6            1.0
# 7            1.0
# 8            2.0
# 9            2.0
# 10           1.0
# 11           1.0
# 12           2.0
# 13           1.0
# 14           1.0

# %%
df_weather_full.query(
    "date == '2014-01-02'"
)
# Out:
# /tmp/ipykernel_577663/1394423637.py:1: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   df_weather_full.query(
#             date                 Issue Time                Valid From  \
# 0     2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 1     2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 2733  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 2734  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 5466  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 5467  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 8199  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 8200  2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 10932 2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 10933 2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 13665 2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
# 13666 2014-01-02  2014-01-02 09:00:00+00:00 2014-01-02 17:00:00+00:00
#
#                         Valid To               lag_valid_to Warning Colour  \
# 0      2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 1      2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
# 2733   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 2734   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
# 5466   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 5467   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
# 8199   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 8200   2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
# 10932  2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 10933  2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
# 13665  2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Orange
# 13666  2014-01-03 14:00:00+00:00  2014-01-04 02:00:00+00:00         Yellow
#
#       Warning Element                                       Warning Text  \
# 0                Wind  Becoming stormy this evening and tonight and c...
# 1                Wind  Becoming extremely windy or stormy this evenin...
# 2733             Wind  Becoming stormy this evening and tonight and c...
# 2734             Wind  Becoming extremely windy or stormy this evenin...
# 5466             Wind  Becoming stormy this evening and tonight and c...
# 5467             Wind  Becoming extremely windy or stormy this evenin...
# 8199             Wind  Becoming stormy this evening and tonight and c...
# 8200             Wind  Becoming extremely windy or stormy this evenin...
# 10932            Wind  Becoming stormy this evening and tonight and c...
# 10933            Wind  Becoming extremely windy or stormy this evenin...
# 13665            Wind  Becoming stormy this evening and tonight and c...
# 13666            Wind  Becoming extremely windy or stormy this evenin...
#
#        Duration_hours                     region  weather_flag  month  season  \
# 0                21.0  HSE Dublin and North East             0      1  Winter
# 1                21.0  HSE Dublin and North East             1      1  Winter
# 2733             21.0    HSE Dublin and Midlands             0      1  Winter
# 2734             21.0    HSE Dublin and Midlands             1      1  Winter
# 5466             21.0  HSE Dublin and South East             0      1  Winter
# 5467             21.0  HSE Dublin and South East             1      1  Winter
# 8199             21.0               HSE Mid West             1      1  Winter
# 8200             21.0               HSE Mid West             1      1  Winter
# 10932            21.0             HSE South West             1      1  Winter
# 10933            21.0             HSE South West             0      1  Winter
# 13665            21.0    HSE West and North West             1      1  Winter
# 13666            21.0    HSE West and North West             0      1  Winter
#
#        severity_num
# 0               2.0
# 1               1.0
# 2733            2.0
# 2734            1.0
# 5466            2.0
# 5467            1.0
# 8199            2.0
# 8200            1.0
# 10932           2.0
# 10933           1.0
# 13665           2.0
# 13666           1.0

# %%
df_weather_final = (
    df_weather_full
    .groupby(['region', 'date', 'severity_num'], as_index=False)
    .agg({
        'weather_flag': 'max',  # any day with a warning => 1
        'Warning Element': lambda s: list(s.unique())
    })
)

# %%
df_weather_final.head(15)
# Out:
#                      region       date  severity_num  weather_flag  \
# 0   HSE Dublin and Midlands 2014-01-02           1.0             1
# 1   HSE Dublin and Midlands 2014-01-02           2.0             0
# 2   HSE Dublin and Midlands 2014-01-03           1.0             1
# 3   HSE Dublin and Midlands 2014-01-04           1.0             1
# 4   HSE Dublin and Midlands 2014-01-05           1.0             1
# 5   HSE Dublin and Midlands 2014-01-05           2.0             0
# 6   HSE Dublin and Midlands 2014-01-06           1.0             1
# 7   HSE Dublin and Midlands 2014-01-06           2.0             1
# 8   HSE Dublin and Midlands 2014-01-12           1.0             1
# 9   HSE Dublin and Midlands 2014-01-16           2.0             1
# 10  HSE Dublin and Midlands 2014-01-25           1.0             1
# 11  HSE Dublin and Midlands 2014-01-25           2.0             0
# 12  HSE Dublin and Midlands 2014-01-26           1.0             1
# 13  HSE Dublin and Midlands 2014-01-26           2.0             0
# 14  HSE Dublin and Midlands 2014-01-31           1.0             1
#
#             Warning Element
# 0                    [Wind]
# 1                    [Wind]
# 2                    [Wind]
# 3                [Snow/Ice]
# 4                    [Wind]
# 5                    [Wind]
# 6                    [Wind]
# 7                    [Wind]
# 8              [Rain, Wind]
# 9   [Fog (or freezing fog)]
# 10                   [Wind]
# 11                   [Wind]
# 12                   [Wind]
# 13                   [Wind]
# 14             [Wind, Rain]

# %%
merged = pd.merge(df_nas_final, df_weather_final , on=['region', 'date'], how='left')

# %%
# Fill missing weather_flag values with 0 (indicating no adverse weather event)
merged['weather_flag'] = merged['weather_flag'].fillna(0)
merged['severity_num'] = merged['severity_num'].fillna(0)
merged['Warning Element'] = merged['Warning Element'].fillna('Unknown')

# %% [markdown]
# merged['hip_adv_event'] = ((merged['hip_fracture_count'] > 0) & (merged['weather_flag'] == 1)).astype(int)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24051 entries, 0 to 24050
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   region                24051 non-null  object
#  1   date                  24051 non-null  datetime64[ns]
#  2   season                21076 non-null  object
#  3   hip_fracture_callout  21076 non-null  float64
#  4   month                 24051 non-null  int32
#  5   year                  24051 non-null  int32
#  6   severity_num          24051 non-null  float64
#  7   weather_flag          24051 non-null  float64
#  8   Warning Element       24051 non-null  object
# dtypes: datetime64[ns](1), float64(3), int32(2), object(3)
# memory usage: 1.5+ MB

# %%
merged.isna().sum()
# Out:
# region                     0
# date                       0
# season                  2975
# hip_fracture_callout    2975
# month                      0
# year                       0
# severity_num               0
# weather_flag               0
# Warning Element            0
# dtype: int64

# %%
merged['hip_fracture_callout'] = merged['hip_fracture_callout'].fillna(0)

# %%
merged['season'] = merged['month'].apply(month_to_season)

# %%
print(merged['season'].value_counts())
# Out:
# season
# Winter    6076
# Autumn    5994
# Spring    5993
# Summer    5988
# Name: count, dtype: int64

# %%
merged.head(10)
# Out:
#                     region       date  season  hip_fracture_callout  month  \
# 0  HSE Dublin and Midlands 2016-01-01  Winter                   8.0      1
# 1  HSE Dublin and Midlands 2016-01-02  Winter                   5.0      1
# 2  HSE Dublin and Midlands 2016-01-03  Winter                   2.0      1
# 3  HSE Dublin and Midlands 2016-01-04  Winter                   5.0      1
# 4  HSE Dublin and Midlands 2016-01-05  Winter                   2.0      1
# 5  HSE Dublin and Midlands 2016-01-06  Winter                   6.0      1
# 6  HSE Dublin and Midlands 2016-01-07  Winter                   4.0      1
# 7  HSE Dublin and Midlands 2016-01-08  Winter                   8.0      1
# 8  HSE Dublin and Midlands 2016-01-09  Winter                   4.0      1
# 9  HSE Dublin and Midlands 2016-01-10  Winter                   3.0      1
#
#    year  severity_num  weather_flag Warning Element
# 0  2016           1.0           1.0          [Rain]
# 1  2016           0.0           0.0         Unknown
# 2  2016           1.0           0.0          [Rain]
# 3  2016           0.0           0.0         Unknown
# 4  2016           0.0           0.0         Unknown
# 5  2016           1.0           1.0          [Rain]
# 6  2016           0.0           0.0         Unknown
# 7  2016           0.0           0.0         Unknown
# 8  2016           0.0           0.0         Unknown
# 9  2016           0.0           0.0         Unknown

# %%
merged['year'] = merged['date'].dt.year

# %%
unique_regions_census = df_census['region'].unique()
print("Unique regions in df_census:", unique_regions_census)
# Out:
# Unique regions in df_census: ['HSE Dublin and Midlands' 'HSE Dublin and North East'
#  'HSE Dublin and South East' 'HSE Midwest' 'HSE South West'
#  'HSE West and North West']

# %%
unique_regions_census = merged['region'].unique()
print("Unique regions in df_census:", unique_regions_census)
# Out:
# Unique regions in df_census: ['HSE Dublin and Midlands' 'HSE Dublin and North East'
#  'HSE Dublin and South East' 'HSE Mid West' 'HSE South East'
#  'HSE West and North West' 'Hospital Unknown' 'Unknown']

# %%
##naming corrections 
df_census['region'] = df_census['region'].replace({'HSE Midwest': 'HSE Mid West'})

# %%
merged['region'] = merged['region'].replace({'HSE South East': 'HSE South West'})

# %%
df_with_pop = pd.merge(
    merged,     # your merged daily data (weather + hip fractures)
    df_census,     # population per region-year
    how='left', # keep all rows from merged even if no match found
    on=['region','year']
)

# %%
df_with_pop.head(15)
# Out:
#                      region       date  season  hip_fracture_callout  month  \
# 0   HSE Dublin and Midlands 2016-01-01  Winter                   8.0      1
# 1   HSE Dublin and Midlands 2016-01-02  Winter                   5.0      1
# 2   HSE Dublin and Midlands 2016-01-03  Winter                   2.0      1
# 3   HSE Dublin and Midlands 2016-01-04  Winter                   5.0      1
# 4   HSE Dublin and Midlands 2016-01-05  Winter                   2.0      1
# 5   HSE Dublin and Midlands 2016-01-06  Winter                   6.0      1
# 6   HSE Dublin and Midlands 2016-01-07  Winter                   4.0      1
# 7   HSE Dublin and Midlands 2016-01-08  Winter                   8.0      1
# 8   HSE Dublin and Midlands 2016-01-09  Winter                   4.0      1
# 9   HSE Dublin and Midlands 2016-01-10  Winter                   3.0      1
# 10  HSE Dublin and Midlands 2016-01-11  Winter                   1.0      1
# 11  HSE Dublin and Midlands 2016-01-12  Winter                   5.0      1
# 12  HSE Dublin and Midlands 2016-01-13  Winter                   2.0      1
# 13  HSE Dublin and Midlands 2016-01-14  Winter                   2.0      1
# 14  HSE Dublin and Midlands 2016-01-14  Winter                   2.0      1
#
#     year  severity_num  weather_flag Warning Element  population
# 0   2016           1.0           1.0          [Rain]    327547.0
# 1   2016           0.0           0.0         Unknown    327547.0
# 2   2016           1.0           0.0          [Rain]    327547.0
# 3   2016           0.0           0.0         Unknown    327547.0
# 4   2016           0.0           0.0         Unknown    327547.0
# 5   2016           1.0           1.0          [Rain]    327547.0
# 6   2016           0.0           0.0         Unknown    327547.0
# 7   2016           0.0           0.0         Unknown    327547.0
# 8   2016           0.0           0.0         Unknown    327547.0
# 9   2016           0.0           0.0         Unknown    327547.0
# 10  2016           0.0           0.0         Unknown    327547.0
# 11  2016           0.0           0.0         Unknown    327547.0
# 12  2016           0.0           0.0         Unknown    327547.0
# 13  2016           1.0           1.0      [Snow/Ice]    327547.0
# 14  2016           2.0           0.0      [Snow/Ice]    327547.0

# %%
# Create a dictionary from df_census that maps (region, year) to population
pop_dict = df_census.set_index(['region', 'year'])['population'].to_dict()

def update_population(row):
    # Build a key from the current row
    key = (row['region'], row['year'])
    # If population is missing and the key exists in pop_dict, update it; otherwise, return current value.
    return pop_dict.get(key, row['population'])

# %%
df_census['year'] = df_census['year'].astype(int)
df_with_pop['year'] = df_with_pop['year'].astype(int)
df_census['region'] = df_census['region'].astype(str)
df_with_pop['region'] = df_with_pop['region'].astype(str)

# %%
df_with_pop['population'] = df_with_pop.apply(update_population, axis=1)

# %%
# Count entries with either 'Hospital Unknown' or 'Unknown'
count = df_with_pop[df_with_pop['region'].isin(['Hospital Unknown', 'Unknown'])].shape[0]
print("Count of entries with 'Hospital Unknown' or 'Unknown':", count)
# Out:
# Count of entries with 'Hospital Unknown' or 'Unknown': 5844

# %%
# Filter out rows where region is 'Hospital Unknown' or 'Unknown'
df_with_pop = df_with_pop[~df_with_pop['region'].isin(['Hospital Unknown', 'Unknown'])]

# Verify by checking unique values
print(df_with_pop['region'].unique())
# Out:
# ['HSE Dublin and Midlands' 'HSE Dublin and North East'
#  'HSE Dublin and South East' 'HSE Mid West' 'HSE South West'
#  'HSE West and North West']

# %%
nan_rows = df_with_pop[df_with_pop['log_population'].isna()]
print(nan_rows.head())
# Out:
# Empty DataFrame
# Columns: [region, date, season, hip_fracture_callout, month, year, severity_num, weather_flag, Warning Element, population, log_population]
# Index: []

# %%
df_with_pop['log_population'] = np.log(df_with_pop['population'])

# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
print(merged['severity_num'].apply(type).value_counts())
# Out:
# severity_num
# <class 'float'>    24051
# Name: count, dtype: int64

# %%
import statsmodels.formula.api as smf

# Expanded formula with additional predictors and an interaction term.
formula = "hip_fracture_callout ~ weather_flag * +C(region)"

# Fit the Poisson regression model (without an offset for this example)
poisson_model = smf.glm(formula=formula, data=df_with_pop, family=sm.families.Poisson(),offset=df_with_pop['log_population']).fit()


# Print the summary of the model
print("Poisson Regression Results:")
print(poisson_model.summary())

# Optionally, check for overdispersion:
print("Residual Deviance:", poisson_model.deviance)
print("Degrees of Freedom:", poisson_model.df_resid)
# Out:
# Poisson Regression Results:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     hip_fracture_callout   No. Observations:                18207
# Model:                              GLM   Df Residuals:                    18196
# Model Family:                   Poisson   Df Model:                           10
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:                -46423.
# Date:                  Sun, 16 Feb 2025   Deviance:                       25594.
# Time:                          18:18:04   Pearson chi2:                 2.50e+04
# No. Iterations:                       5   Pseudo R-squ. (CS):             0.3680
# Covariance Type:              nonrobust
# =======================================================================================================================
#                                                           coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                             -10.9331      0.008  -1387.774      0.000     -10.949     -10.918
# C(region)[T.HSE Dublin and North East]                 -0.0332      0.011     -3.074      0.002      -0.054      -0.012
# C(region)[T.HSE Dublin and South East]                  0.5524      0.010     55.957      0.000       0.533       0.572
# C(region)[T.HSE Mid West]                               0.2649      0.013     20.821      0.000       0.240       0.290
# C(region)[T.HSE South West]                             0.4015      0.010     38.865      0.000       0.381       0.422
# C(region)[T.HSE West and North West]                    0.5439      0.010     53.354      0.000       0.524       0.564
# weather_flag                                           -0.0327      0.021     -1.550      0.121      -0.074       0.009
# weather_flag:C(region)[T.HSE Dublin and North East]    -0.0111      0.030     -0.375      0.708      -0.069       0.047
# weather_flag:C(region)[T.HSE Dublin and South East]     0.0158      0.026      0.598      0.550      -0.036       0.067
# weather_flag:C(region)[T.HSE Mid West]                  0.0235      0.035      0.679      0.497      -0.044       0.091
# weather_flag:C(region)[T.HSE South West]                     0          0        nan        nan           0           0
# weather_flag:C(region)[T.HSE West and North West]       0.0235      0.026      0.902      0.367      -0.028       0.074
# =======================================================================================================================
# Residual Deviance: 25593.78601015591
# Degrees of Freedom: 18196

# %%
import statsmodels.formula.api as smf

# Define the model formula
formula = "hip_fracture_callout ~ weather_flag * + C(season) + C(region)"

# Fit the Negative Binomial model
nb_model = smf.glm(formula=formula, data=df_with_pop,
                   family=sm.families.NegativeBinomial()).fit()

# Print the summary of the model
print(nb_model.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     hip_fracture_callout   No. Observations:                18207
# Model:                              GLM   Df Residuals:                    18194
# Model Family:          NegativeBinomial   Df Model:                           12
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:                -55093.
# Date:                  Sun, 16 Feb 2025   Deviance:                       3905.6
# Time:                          18:18:07   Pearson chi2:                 3.34e+03
# No. Iterations:                       5   Pseudo R-squ. (CS):            0.08971
# Covariance Type:              nonrobust
# ==========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                  1.8361      0.025     74.728      0.000       1.788       1.884
# C(season)[T.Spring]                       -0.0731      0.024     -3.087      0.002      -0.120      -0.027
# C(season)[T.Summer]                       -0.0025      0.024     -0.104      0.917      -0.049       0.044
# C(season)[T.Winter]                       -0.0042      0.024     -0.172      0.864      -0.052       0.044
# C(region)[T.HSE Dublin and North East]     0.1118      0.027      4.069      0.000       0.058       0.166
# C(region)[T.HSE Dublin and South East]     0.5648      0.027     20.786      0.000       0.512       0.618
# C(region)[T.HSE Mid West]                 -0.4833      0.028    -17.145      0.000      -0.539      -0.428
# C(region)[T.HSE South West]                0.2200      0.028      7.878      0.000       0.165       0.275
# C(region)[T.HSE West and North West]       0.4447      0.027     16.313      0.000       0.391       0.498
# weather_flag                              -0.0525      0.052     -1.016      0.310      -0.154       0.049
# weather_flag:C(season)[T.Spring]          -0.0661      0.078     -0.847      0.397      -0.219       0.087
# weather_flag:C(season)[T.Summer]           0.0530      0.076      0.702      0.483      -0.095       0.201
# weather_flag:C(season)[T.Winter]           0.0453      0.064      0.705      0.481      -0.081       0.171
# ==========================================================================================================
# /home/paulharford/anaconda3/envs/msc/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "

# %%
import statsmodels.api as sm
from statsmodels.discrete.discrete_model import Poisson
from patsy import dmatrices

# Define your formula
formula = "hip_fracture_callout ~ weather_flag * + C(season) + C(region)"

# Create design matrices using patsy
y, X = dmatrices(formula, data=df_with_pop, return_type='dataframe')

# Extract the offset (for example, log_population)
offset = df_with_pop['log_population']

# Fit the discrete Poisson model
poisson_discrete = Poisson(y, X, offset=offset)
result = poisson_discrete.fit()

# Print the summary of the results
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 2.545209
#          Iterations 5
#                            Poisson Regression Results
# ================================================================================
# Dep. Variable:     hip_fracture_callout   No. Observations:                18207
# Model:                          Poisson   Df Residuals:                    18194
# Method:                             MLE   Df Model:                           12
# Date:                  Sun, 16 Feb 2025   Pseudo R-squ.:                 0.08419
# Time:                          18:22:57   Log-Likelihood:                -46341.
# converged:                         True   LL-Null:                       -50601.
# Covariance Type:              nonrobust   LLR p-value:                     0.000
# ==========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                -10.9166      0.009  -1228.789      0.000     -10.934     -10.899
# C(season)[T.Spring]                       -0.0707      0.008     -8.667      0.000      -0.087      -0.055
# C(season)[T.Summer]                        0.0006      0.008      0.071      0.943      -0.015       0.016
# C(season)[T.Winter]                       -0.0016      0.008     -0.196      0.844      -0.018       0.015
# C(region)[T.HSE Dublin and North East]    -0.0348      0.010     -3.461      0.001      -0.055      -0.015
# C(region)[T.HSE Dublin and South East]     0.5548      0.009     60.613      0.000       0.537       0.573
# C(region)[T.HSE Mid West]                  0.2682      0.012     22.663      0.000       0.245       0.291
# C(region)[T.HSE South West]                0.4026      0.010     40.362      0.000       0.383       0.422
# C(region)[T.HSE West and North West]       0.5479      0.009     58.473      0.000       0.530       0.566
# weather_flag                              -0.0464      0.018     -2.627      0.009      -0.081      -0.012
# weather_flag:C(season)[T.Spring]          -0.0535      0.028     -1.940      0.052      -0.107       0.001
# weather_flag:C(season)[T.Summer]           0.0451      0.026      1.760      0.078      -0.005       0.095
# weather_flag:C(season)[T.Winter]           0.0418      0.022      1.912      0.056      -0.001       0.085
# ==========================================================================================================

# %%
#print(df_with_pop['log_population'].describe())
print(df_with_pop['log_population'].isna().sum())
# Out:
# 11823
