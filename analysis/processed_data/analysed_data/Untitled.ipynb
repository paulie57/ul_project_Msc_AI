# %% [markdown]
# \section{Data Processing Methodology}
# This section outlines the detailed processing steps for each data format used in the study.
# \subsection{ODS Data Format Processing}
# \begin{table}[htb]
# \centering
# \begin{tabular}{|p{0.15\textwidth}|p{0.75\textwidth}|}
# \hline
# \multicolumn{2}{|l|}{\textbf{ODS Data Format Processing}} \\
# \hline
# \hline
# \textbf{Step} & \textbf{Description} \\
# \hline
# Step 1 & Save conda environment file to .yml for portability and other users \\
# \hline
# Step 2 & Import required modules for processing the ODS data \\
# \hline
# Step 3 & Import data from file into Pandas data frame (df\_ods). Perform initial checks to confirm successful creation \\
# \hline
# Step 4.1 & Test and remove provinces as study will map to HSE regions. Verified that county selection aligns with province selection \\
# \hline
# Step 4.2 & Merge Tipperary SR (3 events) to simplify county breakdown \\
# \hline
# Step 4.3 & Convert True/False to 0/1 for ML models \\
# \hline
# Step 4.4 & Ensure consistent UTC date/time settings \\
# \hline
# Step 4.5 & Filter dates for full years available in dataset (2013-2020) \\
# \hline
# Step 5 & Check for missing values and duplicates \\
# \hline
# Step 6 & Save filtered data to CSV files for later dataset combination \\
# \hline
# \end{tabular}
# \caption{Data Processing Steps for Met Éireann ODS Data Format}
# \label{tab:ods-processing-steps}
# \end{table}
#
# \begin{table}[htb]
# \centering
# \begin{tabular}{|p{0.15\textwidth}|p{0.75\textwidth}|}
# \hline
# \multicolumn{2}{|l|}{\textbf{XML Data Format Processing}} \\
# \hline
# \hline
# \textbf{Step} & \textbf{Description} \\
# \hline
# Step 1 & Save conda environment file to .yml for portability and other users \\
# \hline
# Step 2 & Import required modules for processing \\
# \hline
# Step 3 & Process XML data from automated notification system using Python class functions \\
# \hline
# Step 4.1 & Test and remove provinces, mapping to HSE regions instead \\
# \hline
# Step 4.2 & Check for missing values and duplicates \\
# \hline
# Step 4.3 & Aggregate duplicate events into individual per county events  \\
# \hline
# Step 4.4 & Convert True/False to 1/0 for ML models \\
# \hline
# Step 4.5 & confirm date/time settings, check date ranges \\
# \hline
# Step 4.6 & filter data for dates of interest \\
# \hline
# Step 5 & Save filtered data to CSV files for later combination \\
# \hline
# \end{tabular}
# \caption{Data Processing Steps for Met Éireann XML Data Format}
# \label{tab:xml-processing-steps}
# \end{table}
#
# \begin{table}[htb]
# \centering
# \begin{tabular}{|p{0.15\textwidth}|p{0.75\textwidth}|}
# \hline
# \multicolumn{2}{|l|}{\textbf{Excel Data Format Processing}} \\
# \hline
# \hline
# \textbf{Step} & \textbf{Description} \\
# \hline
# Step 1 & Save conda environment file to .yml for portability and other users \\
# \hline
# Step 2 & Import required modules for processing \\
# \hline
# Step 3 & Import excel data\\
# \hline
# Step 4 & Process Excel data into the same format as ODs and XML \\
# \hline
# Step 5.1 & Test and remove provinces, mapping to HSE regions instead \\
# \hline
# Step 4.3 & Aggregate duplicate events into individual per county events  \\
# \hline
# Step 4.4 & Convert True/False to 1/0 for ML models \\
# \hline
# Step 4.5 & confirm date/time settings, check date ranges \\
# \hline
# Step 4.6 & filter data for dates of interest \\
# \hline
# Step 5 & Save filtered data to CSV files for later combination \\
# \hline
# \end{tabular}
# \caption{Data Processing Steps for Met Éireann XLSX Data Format}
# \label{tab:xlsx-processing-steps}
# \end{table}
#
# \begin{table}[htb]
# \centering
# \begin{tabular}{|p{0.15\textwidth}|p{0.75\textwidth}|}
# \hline
# \multicolumn{2}{|l|}{\textbf{Combining datasets steps}} \\
# \hline
# \hline
# \textbf{Step} & \textbf{Description} \\
# \hline
# Step 1 & Save conda environment file to .yml for portability and other users \\
# \hline
# Step 2 & Import csv files \\
# \hline
# Step 3 & Compare overlapping dates ranegs from different datasets as an accuracy check of processing output\\
# \hline
# Step 4 & Ensure date time columns are consistently UTC across the 3 datasets\\
# \hline
# Step 5.1 & Drop unnecessary columns and reorder columns\\
# \hline
# Step 5.2 & Filter date ranges before combining \\
# \hline
# Step 5.3 & Create combined dataset \\
# \hline
# Step 5.4 & Remove events that have no "Warning Colour" or "Valid To" time \\combined datasets to csv \\
# \hline
# Step 5.5 & Standardize the weather types across severities  \\
# \hline
# Step 5.6& Check All counties have at least 1 selected (if not its deemed an all of Ireland event)\\
# \hline
# Step 5.7 & Categorise all events into their respective HSE region \\
# \hline
# Step 6.0 & Save combined datasets to csv \\
# \hline
# \end{tabular}
# \caption{Steps for combining the 3 Met Éireann Datasets}
# \label{tab:combining-datasets-processing-steps}
# \end{table}
